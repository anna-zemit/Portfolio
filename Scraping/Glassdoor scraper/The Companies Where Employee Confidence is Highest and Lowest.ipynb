# %%
import pandas as pd
import numpy as np
import requests
import os
import time
import math
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
from datetime import datetime, timedelta

# %% [markdown]
# # Add industries

# %%
seed_list = pd.read_excel('Company seed list with categories.xlsx')

# %%
seed_list['Company'] = seed_list['Company'].apply(lambda x: x.split('\n')[0])

# %%
seed_list_scraping = seed_list.drop_duplicates(subset = ['Company']).reset_index(drop=True)

# %%
seed_list_scraping[seed_list_scraping.Company=='Booking Holdings (Booking.com)']
# Out:
#                            Company  \
# 21  Booking Holdings (Booking.com)
#
#                                        Market_Cap_URL     Listing  \
# 21  https://companiesmarketcap.com/booking-holding...  Top 100 US
#
#     Glassdoor ID Categories
# 21        256653       Tech

# %%
seed_list = seed_list.drop_duplicates(subset = ['Company']).reset_index(drop=True)

# %%
seed_list.drop(columns=['Market_Cap_URL','Listing','Glassdoor ID'], inplace=True)

# %%
seed_list.columns = ['Company', 'Industry']

# %%
seed_list
# Out:
#                     Company                                      Industry
# 0       Abbott Laboratories  Pharmaceuticals, Healthcare, Medical devices
# 1                    AbbVie  Pharmaceuticals, Healthcare, Medical devices
# 2                     Adobe                                          Tech
# 3                    Airbnb                                          Tech
# 4         Alphabet (Google)                                          Tech
# ..                      ...                                           ...
# 100  Cadence Design Systems                                          Tech
# 101                    Dell                                          Tech
# 102                 Equinix                                          Tech
# 103                  Fiserv                                          Tech
# 104                Synopsys                                          Tech
#
# [105 rows x 2 columns]

# %%
categories = pd.read_excel('Categories.xlsx')

# %%
categories = categories[categories.Categories!='🇺🇸 Dow jones']

# %%
categories = categories.groupby('Market_Cap_URL')['Categories'].first().reset_index()

# %%
seed_list = seed_list.merge(categories, on='Market_Cap_URL', how='left')

# %% [markdown]
# # Develop the scraper

# %% [markdown]
# ## Example

# %%
# JS

url = "https://www.glassdoor.com/graph"

payload = [
    {
        "operationName": "RecordPageView",
        "variables": {
            "employerId": "11159",
            "metaData": [],
            "pageIdent": "INFOSITE_REVIEWS"
        },
        "query": "mutation RecordPageView($employerId: String!, $pageIdent: String!) {recordPageView(pageIdent: $pageIdent metaData: {key: \"employerId\", value: $employerId}) {totalCount  __typename  }"
    },
    {
        "operationName": "GetEmployerReviews",
        "variables": {
            "applyDefaultCriteria": True,
            "employerId": 11159,
            "employmentStatuses": [],
            "goc": None,
            "jobTitle": None,
            "language": "eng",
            "location": {
                "countryId": None,
                "stateId": None,
                "metroId": None,
                "cityId": None
            },
            "locationName": "",
            "mlHighlightSearch": None,
            "onlyCurrentEmployees": False,
            "page": 2,
            "preferredTldId": 0,
            "reviewCategories": [],
            "sort": "RELEVANCE",
            "textSearch": "",
            "worldwideFilter": False,
            "dynamicProfileId": 919129,
            "useRowProfileTldForRatings": True,
            "enableKeywordSearch": False
        },
        "query": "query GetEmployerReviews($applyDefaultCriteria: Boolean, $dynamicProfileId: Int, $employerId: Int!, $employmentStatuses: [EmploymentStatusEnum], $enableKeywordSearch: Boolean!, $goc: GOCIdent, $isRowProfileEnabled: Boolean, $jobTitle: JobTitleIdent, $language: String, $location: LocationIdent, $onlyCurrentEmployees: Boolean, $page: Int!, $preferredTldId: Int, $reviewCategories: [ReviewCategoriesEnum], $sort: ReviewsSortOrderEnum, $textSearch: String, $useRowProfileTldForRatings: Boolean, $worldwideFilter: Boolean) {employerReviews: employerReviewsRG( employerReviewsInput: {applyDefaultCriteria: $applyDefaultCriteria, dynamicProfileId: $dynamicProfileId, employer: {id: $employerId}, employmentStatuses: $employmentStatuses, onlyCurrentEmployees: $onlyCurrentEmployees, goc: $goc, isRowProfileEnabled: $isRowProfileEnabled, jobTitle: $jobTitle, language: $language, location: $location, page: {num: $page, size: 10}, preferredTldId: $preferredTldId, reviewCategories: $reviewCategories, sort: $sort, textSearch: $textSearch, useRowProfileTldForRatings: $useRowProfileTldForRatings, worldwideFilter: $worldwideFilter}) {allReviewsCount currentPage filteredReviewsCount   lastReviewDateTime   numberOfPages queryJobTitle {   id    text     __typename   }  queryLocation {     id     longName    shortName      type    __typename} ratedReviewsCount ratings {   businessOutlookRating     careerOpportunitiesRating   ceoRating    compensationAndBenefitsRating    cultureAndValuesRating  diversityAndInclusionRating     overallRating  ratedCeo {      id      largePhoto: photoUrl(size: LARGE)      name      regularPhoto: photoUrl(size: REGULAR)       title      __typename    }    recommendToFriendRating    reviewCount    seniorManagementRating    workLifeBalanceRating     __typename    }  reviews {advice     adviceOriginal    cons     consOriginal     countHelpful    countNotHelpful    employer {      id       largeLogoUrl: squareLogoUrl(size: LARGE)       regularLogoUrl: squareLogoUrl(size: REGULAR)        shortName       __typename     }     employerResponses {      id       countHelpful        countNotHelpful       languageId       originalLanguageId       response       responseDateTime(format: ISO)      responseOriginal       translationMethod       __typename      }     employmentStatus    featured     isCurrentJob    jobTitle {     id       text       __typename     }     languageId     lengthOfEmployment    location {       id       type       name      __typename     }     originalLanguageId     pros      prosOriginal      ratingBusinessOutlook      ratingCareerOpportunities     ratingCeo    ratingCompensationAndBenefits      ratingCultureAndValues     ratingDiversityAndInclusion     ratingOverall      ratingRecommendToFriend    ratingSeniorLeadership    ratingWorkLifeBalance      reviewDateTime    reviewId      summary     summaryOriginal     textSearchHighlightPhrases @include(if: $enableKeywordSearch) {        field       phrases {        length          position: pos        __typename       }       __typename     }     translationMethod    __typename    }   ratingCountDistribution {     overall {       _5       _4       _3       _2       _1      __typename     }     cultureAndValues {      _5       _4       _3        _2      _1      __typename    }     careerOpportunities {       _5       _4       _3      _2       _1       __typename     }      workLifeBalance {        _5       _4       _3       _2       _1       __typename     }     seniorManagement {       _5       _4       _3       _2      _1      __typename     }      compensationAndBenefits {       _5       _4       _3       _2      _1       __typename     }      diversityAndInclusion {        _5        _4       _3      _2       _1        __typename     }      recommendToFriend {        WONT_RECOMMEND     RECOMMEND      __typename   }    __typename   }   __typename}}"
    }
]
headers = {
    "authority": "www.glassdoor.com",
    "accept": "*/*",
    "apollographql-client-name": "ei-reviews-next",
    "apollographql-client-version": "1.27.13",
    "content-type": "application/json",
    "origin": "https://www.glassdoor.com",
    "referer": "https://www.glassdoor.com/",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
}

response = requests.request("POST", url, json=payload, headers=headers)

print(response.text)
# Out:
# [{"errors":[{"message":"Syntax Error: Expected Name, found <EOF>.","locations":[{"line":1,"column":183}],"extensions":{"code":"GRAPHQL_PARSE_FAILED"}}]}
# ,{"data":{"employerReviews":{"allReviewsCount":19696,"currentPage":2,"filteredReviewsCount":17093,"lastReviewDateTime":"2024-03-23T15:02:10.757","numberOfPages":1710,"queryJobTitle":null,"queryLocation":null,"ratedReviewsCount":17986,"ratings":{"businessOutlookRating":0.71,"careerOpportunitiesRating":3.9,"ceoRating":0.8,"compensationAndBenefitsRating":4.3,"cultureAndValuesRating":4,"diversityAndInclusionRating":4.3,"overallRating":4.1,"ratedCeo":{"id":568377,"largePhoto":"https://media.glassdoor.com/people/sqll/11159/salesforce-ceo1684713833445.png","name":"Marc Benioff","regularPhoto":"https://media.glassdoor.com/people/sql/11159/salesforce-ceo1684713833445.png","title":"CEO ","__typename":"Ceo"},"recommendToFriendRating":0.79,"reviewCount":17986,"seniorManagementRating":3.6,"workLifeBalanceRating":3.9,"__typename":"EmployerRatings"},"reviews":[{"advice":"Leadership Overhaul: It's crucial for Salesforce's management to critically evaluate the current leadership framework. Embracing new leadership styles and perspectives can invigorate the company's strategic direction. Actively seeking out and promoting leaders from diverse backgrounds and with varied experiences can foster innovation, resilience, and a more inclusive company culture.\n\nEmbrace Diversity of Thought: Encourage and cultivate diversity of thought and experience within all levels of the company. This diversity can lead to more creative solutions to problems, a better understanding of customer needs, and a more dynamic and adaptable business strategy.\n\nRealign Priorities: Shift the company's focus towards genuinely meeting and exceeding customer needs, rather than primarily driving sales and quotas. Building a reputation for genuinely prioritising customer success can lead to more sustainable growth and stronger, more loyal customer relationships.","adviceOriginal":null,"cons":"Stale Leadership: A significant challenge at Salesforce is the presence of leadership that seems to be stuck in time, recycling the same outdated ideas without adapting to the changing business landscape. This can hinder innovation and responsiveness to market shifts.\n\nMisaligned Prioritisation: There's a noticeable emphasis on meeting sales targets and quotas, sometimes at the expense of truly addressing customer needs and ensuring their success. This short-sighted approach can undermine long-term relationships and the company's reputation for customer-centricity.","consOriginal":null,"countHelpful":2,"countNotHelpful":0,"employer":{"id":11159,"largeLogoUrl":"https://media.glassdoor.com/sqll/11159/salesforce-com-squarelogo-1413910133565.png","regularLogoUrl":"https://media.glassdoor.com/sql/11159/salesforce-com-squarelogo-1413910133565.png","shortName":"Salesforce","__typename":"Employer"},"employerResponses":[],"employmentStatus":"REGULAR","featured":false,"isCurrentJob":true,"jobTitle":{"id":623637,"text":"Lead Solution Engineer","__typename":"JobTitle"},"languageId":"eng","lengthOfEmployment":4,"location":{"id":2671300,"type":"CITY","name":"London, England","__typename":"City"},"originalLanguageId":null,"pros":"Abundance of Resources: Salesforce provides its employees with a wealth of resources, ensuring they have access to the tools and support necessary to excel in their roles. This empowers team members to innovate, solve problems efficiently, and deliver outstanding results.\n\nExceptional Colleagues: The company is home to an incredibly talented pool of individual contributors, who are not only skilled in their respective fields but also collaborative and supportive. This creates a stimulating work environment where learning and growth are constant.","prosOriginal":null,"ratingBusinessOutlook":"POSITIVE","ratingCareerOpportunities":3,"ratingCeo":"NO_OPINION","ratingCompensationAndBenefits":4,"ratingCultureAndValues":4,"ratingDiversityAndInclusion":3,"ratingOverall":4,"ratingRecommendToFriend":"POSITIVE","ratingSeniorLeadership":2,"ratingWorkLifeBalance":4,"reviewDateTime":"202 ...
# ]

# %%
# Mine 
url = "https://www.glassdoor.com/graph"

payload = [
    {
        "operationName":"RecordPageView",
        "variables":{
            "employerId": "1557", #"1138",
            "metaData":[],
            "pageIdent":"INFOSITE_REVIEWS"},
        "query":"mutation RecordPageView($employerId: String!, $pageIdent: String!) {\n  recordPageView(\n    pageIdent: $pageIdent\n    metaData: {key: \"employerId\", value: $employerId}\n  ) {\n    totalCount\n    __typename\n  }\n}\n".replace('\n', '')},
    {"operationName":"GetEmployerReviews",
     "variables":{"applyDefaultCriteria":False,
                  "employerId":1557, #1138
                  "employmentStatuses":["REGULAR","PART_TIME"],
                  "goc":None,
                  "jobTitle":None,
                  "language":"eng",
                  "location":{"countryId":1,
                              "stateId":None,
                              "metroId":None,
                              "cityId":None},
                  "locationName":"US",
                  "mlHighlightSearch":None,
                  "onlyCurrentEmployees":False,
                  "page":0,
                  "preferredTldId":0,
                  "reviewCategories":[],
                  "sort":"DATE",
                  "textSearch":"",
                  "worldwideFilter":False,
                  "dynamicProfileId":1140,
                  "useRowProfileTldForRatings":False,
                  "enableKeywordSearch":False},
     "query":"query GetEmployerReviews($applyDefaultCriteria: Boolean, $dynamicProfileId: Int, $employerId: Int!, $employmentStatuses: [EmploymentStatusEnum], $enableKeywordSearch: Boolean!, $goc: GOCIdent, $isRowProfileEnabled: Boolean, $jobTitle: JobTitleIdent, $language: String, $location: LocationIdent, $onlyCurrentEmployees: Boolean, $page: Int!, $preferredTldId: Int, $reviewCategories: [ReviewCategoriesEnum], $sort: ReviewsSortOrderEnum, $textSearch: String, $useRowProfileTldForRatings: Boolean, $worldwideFilter: Boolean) {\n  employerReviews: employerReviewsRG(\n    employerReviewsInput: {applyDefaultCriteria: $applyDefaultCriteria, dynamicProfileId: $dynamicProfileId, employer: {id: $employerId}, employmentStatuses: $employmentStatuses, onlyCurrentEmployees: $onlyCurrentEmployees, goc: $goc, isRowProfileEnabled: $isRowProfileEnabled, jobTitle: $jobTitle, language: $language, location: $location, page: {num: $page, size: 1000}, preferredTldId: $preferredTldId, reviewCategories: $reviewCategories, sort: $sort, textSearch: $textSearch, useRowProfileTldForRatings: $useRowProfileTldForRatings, worldwideFilter: $worldwideFilter}\n  ) {\n    allReviewsCount\n    currentPage\n    filteredReviewsCount\n    lastReviewDateTime\n    numberOfPages\n    queryJobTitle {\n      id\n      text\n      __typename\n    }\n    queryLocation {\n      id\n      longName\n      shortName\n      type\n      __typename\n    }\n    ratedReviewsCount\n    ratings {\n      businessOutlookRating\n      careerOpportunitiesRating\n      ceoRating\n      compensationAndBenefitsRating\n      cultureAndValuesRating\n      diversityAndInclusionRating\n      overallRating\n      ratedCeo {\n        id\n        largePhoto: photoUrl(size: LARGE)\n        name\n        regularPhoto: photoUrl(size: REGULAR)\n        title\n        __typename\n      }\n      recommendToFriendRating\n      reviewCount\n      seniorManagementRating\n      workLifeBalanceRating\n      __typename\n    }\n    reviews {\n      advice\n      adviceOriginal\n      cons\n      consOriginal\n      countHelpful\n      countNotHelpful\n      employer {\n        id\n        largeLogoUrl: squareLogoUrl(size: LARGE)\n        regularLogoUrl: squareLogoUrl(size: REGULAR)\n        shortName\n        __typename\n      }\n      employerResponses {\n        id\n        countHelpful\n        countNotHelpful\n        languageId\n        originalLanguageId\n        response\n        responseDateTime(format: ISO)\n        responseOriginal\n        translationMethod\n        __typename\n      }\n      employmentStatus\n      featured\n      isCurrentJob\n      jobTitle {\n        id\n        text\n        __typename\n      }\n      languageId\n      lengthOfEmployment\n      location {\n        id\n        type\n        name\n        __typename\n      }\n      originalLanguageId\n      pros\n      prosOriginal\n      ratingBusinessOutlook\n      ratingCareerOpportunities\n      ratingCeo\n      ratingCompensationAndBenefits\n      ratingCultureAndValues\n      ratingDiversityAndInclusion\n      ratingOverall\n      ratingRecommendToFriend\n      ratingSeniorLeadership\n      ratingWorkLifeBalance\n      reviewDateTime\n      reviewId\n      summary\n      summaryOriginal\n      textSearchHighlightPhrases @include(if: $enableKeywordSearch) {\n        field\n        phrases {\n          length\n          position: pos\n          __typename\n        }\n        __typename\n      }\n      translationMethod\n      __typename\n    }\n    ratingCountDistribution {\n      overall {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      cultureAndValues {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      careerOpportunities {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      workLifeBalance {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      seniorManagement {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      compensationAndBenefits {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      diversityAndInclusion {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      recommendToFriend {\n        WONT_RECOMMEND\n        RECOMMEND\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n".replace('\n', '')
    }]






response = requests.request("POST", url, json=payload, headers=headers)

print(response.text)
# Out:
# [{"data":{"recordPageView":{"totalCount":1,"__typename":"PageViewSummary"}}}
# ,{"data":{"employerReviews":{"allReviewsCount":1738,"currentPage":0,"filteredReviewsCount":639,"lastReviewDateTime":"2024-03-23T14:08:11.480","numberOfPages":1,"queryJobTitle":null,"queryLocation":{"id":1,"longName":"United States of America","shortName":"US","type":"COUNTRY","__typename":"Country"},"ratedReviewsCount":639,"ratings":{"businessOutlookRating":0.81,"careerOpportunitiesRating":3.8,"ceoRating":0.87,"compensationAndBenefitsRating":3.6,"cultureAndValuesRating":3.9,"diversityAndInclusionRating":3.9,"overallRating":4.1,"ratedCeo":{"id":65676,"largePhoto":"https://media.glassdoor.com/people/sqll/1557/kla-ceo1671041120103.png","name":"Rick Wallace","regularPhoto":"https://media.glassdoor.com/people/sql/1557/kla-ceo1671041120103.png","title":"President and Chief Executive Officer","__typename":"Ceo"},"recommendToFriendRating":0.83,"reviewCount":639,"seniorManagementRating":3.6,"workLifeBalanceRating":3.4,"__typename":"EmployerRatings"},"reviews":[{"advice":"Run fast, run far.","adviceOriginal":null,"cons":"If your manager is an idiot, you’re doomed. And in fact, this company’s idiot rate is very high. Sometimes when you finished a demo, the manager would even steal the results away and present it without informing you.\nSome managers are really incompetent and the promotion works fully based on how many years you stayed in the company.","consOriginal":null,"countHelpful":0,"countNotHelpful":0,"employer":{"id":1557,"largeLogoUrl":"https://media.glassdoor.com/sqll/1557/kla-tencor-squarelogo-1547126498959.png","regularLogoUrl":"https://media.glassdoor.com/sql/1557/kla-tencor-squarelogo-1547126498959.png","shortName":"KLA","__typename":"Employer"},"employerResponses":[],"employmentStatus":"REGULAR","featured":false,"isCurrentJob":false,"jobTitle":{"id":23992,"text":"Applications Developer","__typename":"JobTitle"},"languageId":"eng","lengthOfEmployment":1,"location":{"id":1134560,"type":"CITY","name":"Ann Arbor, MI","__typename":"City"},"originalLanguageId":null,"pros":"Man, what can I say.","prosOriginal":null,"ratingBusinessOutlook":"NEUTRAL","ratingCareerOpportunities":3,"ratingCeo":"NO_OPINION","ratingCompensationAndBenefits":4,"ratingCultureAndValues":2,"ratingDiversityAndInclusion":2,"ratingOverall":1,"ratingRecommendToFriend":"NEGATIVE","ratingSeniorLeadership":1,"ratingWorkLifeBalance":3,"reviewDateTime":"2024-03-23T14:08:11.480","reviewId":85638339,"summary":"Toxic work environment ","summaryOriginal":null,"translationMethod":null,"__typename":"EmployerReviewRG"},{"advice":"Creat rotational programs/leadership track","adviceOriginal":null,"cons":"High Stress, Not a clear careers path to progress","consOriginal":null,"countHelpful":0,"countNotHelpful":0,"employer":{"id":1557,"largeLogoUrl":"https://media.glassdoor.com/sqll/1557/kla-tencor-squarelogo-1547126498959.png","regularLogoUrl":"https://media.glassdoor.com/sql/1557/kla-tencor-squarelogo-1547126498959.png","shortName":"KLA","__typename":"Employer"},"employerResponses":[],"employmentStatus":"REGULAR","featured":false,"isCurrentJob":true,"jobTitle":{"id":3409522,"text":"Buyer/Planner 2","__typename":"JobTitle"},"languageId":"eng","lengthOfEmployment":2,"location":{"id":1134560,"type":"CITY","name":"Ann Arbor, MI","__typename":"City"},"originalLanguageId":null,"pros":"Silicon Valley tech in AA, competitive pay, Stock options, LTI, and amazing office.","prosOriginal":null,"ratingBusinessOutlook":"POSITIVE","ratingCareerOpportunities":4,"ratingCeo":"APPROVE","ratingCompensationAndBenefits":4,"ratingCultureAndValues":4,"ratingDiversityAndInclusion":5,"ratingOverall":5,"ratingRecommendToFriend":"POSITIVE","ratingSeniorLeadership":4,"ratingWorkLifeBalance":3,"reviewDateTime":"2024-03-22T13:06:01.490","reviewId":85615791,"summary":"AA is a great place to work","summaryOriginal":null,"translationMethod":null,"__typename":"EmployerReviewRG"},{"advice":null,"adviceOriginal":null,"cons":"have to support customer around the world","consOriginal":null,"countHelpful":0,"countNo ...
# ]

# %% [markdown]
# ## Scraper

# %%
headers = {
    "apollographql-client-name": "ei-reviews-next",
    "content-type": "application/json",
    "origin": "https://www.glassdoor.com",
    "referer": "https://www.glassdoor.com/",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"macOS\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
}

# %%
for index, row in seed_list_scraping.iloc[21:22].iterrows():
    
    company = row['Company']
    glassdoor_id = int(row['Glassdoor ID'])
    page_number = 0
    current_date = datetime.now()
    
    while current_date >= two_years_ago: 
    
        payload = [
        {
            "operationName":"RecordPageView",
            "variables":{
                "employerId": f"{glassdoor_id}", #Glassdoor ID
                "metaData":[],
                "pageIdent":"INFOSITE_REVIEWS"},
            "query":"mutation RecordPageView($employerId: String!, $pageIdent: String!) {\n  recordPageView(\n    pageIdent: $pageIdent\n    metaData: {key: \"employerId\", value: $employerId}\n  ) {\n    totalCount\n    __typename\n  }\n}\n".replace('\n', '')},
        {"operationName":"GetEmployerReviews",
         "variables":{"applyDefaultCriteria":False,
                      "employerId":glassdoor_id, # Glassdoor ID
                      "employmentStatuses":["REGULAR","PART_TIME"],
                      "goc":None,
                      "jobTitle":None,
                      "language":"eng",
                      "location":{"countryId":1,
                                  "stateId":None,
                                  "metroId":None,
                                  "cityId":None},
                      "locationName":"US",
                      "mlHighlightSearch":None,
                      "onlyCurrentEmployees":False,
                      "page":page_number,
                      "preferredTldId":0,
                      "reviewCategories":[],
                      "sort":"DATE",
                      "textSearch":"",
                      "worldwideFilter":False,
                      "dynamicProfileId":1140,
                      "useRowProfileTldForRatings":False,
                      "enableKeywordSearch":False},
         "query":"query GetEmployerReviews($applyDefaultCriteria: Boolean, $dynamicProfileId: Int, $employerId: Int!, $employmentStatuses: [EmploymentStatusEnum], $enableKeywordSearch: Boolean!, $goc: GOCIdent, $isRowProfileEnabled: Boolean, $jobTitle: JobTitleIdent, $language: String, $location: LocationIdent, $onlyCurrentEmployees: Boolean, $page: Int!, $preferredTldId: Int, $reviewCategories: [ReviewCategoriesEnum], $sort: ReviewsSortOrderEnum, $textSearch: String, $useRowProfileTldForRatings: Boolean, $worldwideFilter: Boolean) {\n  employerReviews: employerReviewsRG(\n    employerReviewsInput: {applyDefaultCriteria: $applyDefaultCriteria, dynamicProfileId: $dynamicProfileId, employer: {id: $employerId}, employmentStatuses: $employmentStatuses, onlyCurrentEmployees: $onlyCurrentEmployees, goc: $goc, isRowProfileEnabled: $isRowProfileEnabled, jobTitle: $jobTitle, language: $language, location: $location, page: {num: $page, size: 1000}, preferredTldId: $preferredTldId, reviewCategories: $reviewCategories, sort: $sort, textSearch: $textSearch, useRowProfileTldForRatings: $useRowProfileTldForRatings, worldwideFilter: $worldwideFilter}\n  ) {\n    allReviewsCount\n    currentPage\n    filteredReviewsCount\n    lastReviewDateTime\n    numberOfPages\n    queryJobTitle {\n      id\n      text\n      __typename\n    }\n    queryLocation {\n      id\n      longName\n      shortName\n      type\n      __typename\n    }\n    ratedReviewsCount\n    ratings {\n      businessOutlookRating\n      careerOpportunitiesRating\n      ceoRating\n      compensationAndBenefitsRating\n      cultureAndValuesRating\n      diversityAndInclusionRating\n      overallRating\n      ratedCeo {\n        id\n        largePhoto: photoUrl(size: LARGE)\n        name\n        regularPhoto: photoUrl(size: REGULAR)\n        title\n        __typename\n      }\n      recommendToFriendRating\n      reviewCount\n      seniorManagementRating\n      workLifeBalanceRating\n      __typename\n    }\n    reviews {\n      advice\n      adviceOriginal\n      cons\n      consOriginal\n      countHelpful\n      countNotHelpful\n      employer {\n        id\n        largeLogoUrl: squareLogoUrl(size: LARGE)\n        regularLogoUrl: squareLogoUrl(size: REGULAR)\n        shortName\n        __typename\n      }\n      employerResponses {\n        id\n        countHelpful\n        countNotHelpful\n        languageId\n        originalLanguageId\n        response\n        responseDateTime(format: ISO)\n        responseOriginal\n        translationMethod\n        __typename\n      }\n      employmentStatus\n      featured\n      isCurrentJob\n      jobTitle {\n        id\n        text\n        __typename\n      }\n      languageId\n      lengthOfEmployment\n      location {\n        id\n        type\n        name\n        __typename\n      }\n      originalLanguageId\n      pros\n      prosOriginal\n      ratingBusinessOutlook\n      ratingCareerOpportunities\n      ratingCeo\n      ratingCompensationAndBenefits\n      ratingCultureAndValues\n      ratingDiversityAndInclusion\n      ratingOverall\n      ratingRecommendToFriend\n      ratingSeniorLeadership\n      ratingWorkLifeBalance\n      reviewDateTime\n      reviewId\n      summary\n      summaryOriginal\n      textSearchHighlightPhrases @include(if: $enableKeywordSearch) {\n        field\n        phrases {\n          length\n          position: pos\n          __typename\n        }\n        __typename\n      }\n      translationMethod\n      __typename\n    }\n    ratingCountDistribution {\n      overall {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      cultureAndValues {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      careerOpportunities {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      workLifeBalance {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      seniorManagement {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      compensationAndBenefits {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      diversityAndInclusion {\n        _5\n        _4\n        _3\n        _2\n        _1\n        __typename\n      }\n      recommendToFriend {\n        WONT_RECOMMEND\n        RECOMMEND\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n".replace('\n', '')
        }]

        try:
            response = requests.request("POST", url, json=payload, headers=headers)
            response.raise_for_status()
            time.sleep(max(25.564878, 26.091354 + 2*np.random.randn()))

            json_company = response.json()
            file_path = os.path.join(folder_path, f'{company}_{page_number}.json')

                # Save the JSON data 
            with open(file_path, 'w', encoding='utf-8') as json_file:
                json.dump(json_company, json_file, ensure_ascii=False, indent=4)

            print('Done row ', index, ' ', company, page_number)
            page_number +=1
            try:
                current_date = datetime.strptime(json_company[1]['data']['employerReviews']['reviews'][-1]['reviewDateTime'], '%Y-%m-%dT%H:%M:%S.%f')

            except:
                current_date = datetime.strptime(json_company[1]['data']['employerReviews']['reviews'][-1]['reviewDateTime'], '%Y-%m-%dT%H:%M:%S')

        except:
            print('Exception: ', index, ' ', company, page_number)
            time.sleep(max(5.564878, 10.091354 + 2*np.random.randn()))
# Out:
# Done row  21   Booking Holdings (Booking.com) 0

# %% [markdown]
# # Read scraped data

# %%
json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

# %%
data = []

# %%
for file in json_files:
    with open(os.path.join(folder_path, file), 'r') as json_file:
        json_data = json.load(json_file)
        company_name = file.split('.json')[0].split('_')[0]
        reviews = json_data[1]['data']['employerReviews']['reviews']
        for review in reviews:
            reviewId = review.get('reviewId')
            ratingOverall = review.get('ratingOverall')
            location = review.get('location').get('name')
            ratingBusinessOutlook = review.get('ratingBusinessOutlook')
            reviewDateTime = review.get('reviewDateTime')
            
            data.append({'review_id': reviewId, 'rating_overall': ratingOverall,
                    'location': location, 'business_outlook': ratingBusinessOutlook,
                        'review_date': reviewDateTime, 'Company': company_name})

# %%
df = pd.DataFrame(data)

# %%
df = df.drop_duplicates('review_id')

# %%
df['review_date'] = df['review_date'].apply(lambda x: datetime.strptime(x.split('T')[0], '%Y-%m-%d'))

# %%
current_date = datetime.strptime('2024-03-23', '%Y-%m-%d')
two_years_ago = current_date - timedelta(days=365 * 2)

# %%
one_year_ago = current_date - timedelta(days=365)

# %%
df = df[df['review_date'] >= two_years_ago].reset_index(drop=True)

# %%
abbreviations = pd.read_excel('/Users/anna.zemit/Desktop/Programming/2023/09. The Highest-Rated Independent Restaurants in Every State/State and Territory Abbreviations.xlsx')

# %%
for i in df['location']:
    try:
        i.split(',')[-1].strip()
    except:
        print(i)

# %%
df['Postal'] = df['location'].apply(lambda x: x.split(',')[-1].strip())

# %%
city_to_state = {
    'Chicago Hts': 'IL',  # Assuming Chicago Hts refers to Chicago Heights, IL
    #'Manatí': 'PR',  # Assuming Manatí is in Puerto Rico
    'Tri-Cities': 'WA',  # Assuming Tri-Cities refers to cities in Washington State
    'Los Angeles': 'CA',
    'Long Island-Queens': 'NY',  # Assuming Long Island-Queens refers to New York
    'San Tan Valley': 'AZ',
    'Minneapolis-Saint Paul': 'MN',
    'San Diego Country Estates': 'CA',
    'Las Vegas': 'NV',
    #'Gold Coast': 'QLD',  # Assuming Gold Coast refers to Queensland, Australia
    'Las Vegas Valley': 'NV',
    'Remote': None,  # Assuming Remote means outside any specific state or country
    'Midtown New York': 'NY',
    'Sacramento Valley': 'CA',
    'SoHo': 'NY',
    'San Antonio': 'TX',
    #'Las Piñas': 'PH',  # Assuming Las Piñas refers to the city in the Philippines
    #'Australia Island': 'AU',  # Assuming Australia Island refers to the whole country
    'Sacramento Canyon': 'CA',
    'Vegas': 'NV',
    'Emerson Hill': 'NY',
    'Island of Hawai‘i': 'HI',
    
}

# Define a dictionary to map city names to state codes
city_to_state.update({
    'Midtown New York': 'NY',
    'Sacramento Valley': 'CA',
    'SoHo': 'NY',
    'San Antonio': 'TX',
    'Sacramento Canyon': 'CA',
    'Vegas': 'NV',
    'Emerson Hill': 'NY',
    'Island of Hawai‘i': 'HI',
    'North Chesterfield': 'VA',
    'Massachusetts Avenue Heights': 'MA',
    'Lansdowne-Baltimore Highlands': 'MD',
    'San Jose': 'CA',
    'Jurupa Valley': 'CA',
    'Nashville-Davidson': 'TN',
    'Miami Township': 'OH',
    'Brooklyn Heights': 'NY',
    'Oahu Island': 'HI',
    'Irvine': 'CA',
    'Inland Empire': 'CA',
    'Bushwick': 'NY',
    'LaGrange': 'GA',
    'Shelby Charter Township': 'MI',
    'Mission Valley': 'CA',
    'Township of Ocean': 'NJ',
    'Connecticut Park': 'CT',
    'Honolulu District': 'HI',
    'Dupont Circle': 'DC',
    'Texarkana': 'TX',
    #'St. John': 'VI',  # Assuming St. John refers to the Virgin Islands
    'Lookout Valley': 'TN',
    'Brickell Point': 'FL',
})

city_to_state.update({
    'Sheepshead Bay': 'NY',
    'Town of Perinton': 'NY',
    'Town of Clarkstown': 'NY',
    'Township of Millcreek': 'PA',
    'Powdersville': 'SC',
    'Harlem': 'NY',
    'Eltingville': 'NY',
    'Otay Mesa': 'CA',
    'Chicago Lawn': 'IL',
    'Cotswold': 'NC',
    'Virgin Island': 'VI',
    'Kearny Mesa': 'CA',
    'Scottsdale': 'AZ',
    'Salt Lake International Center': 'UT',
    'Saratoga': 'CA',
    'Campo Rico': 'PR',
    'Union City': 'CA',
    'Porters Neck': 'NC',
    "Hell's Kitchen": 'NY',
    'Menominee': 'MI',
    'Candelaria': 'PR',
    'Los Feliz': 'CA',
    'Manhattan': 'NY',
    'Upper West Side': 'NY',
    'Santa Clara Valley': 'CA',
    'Pilsen': 'IL',
    'San Fernando Valley': 'CA',
    'Utahna': 'UT',
    'Township of Lawrence': 'NJ',
    'Lincoln Park': 'IL',
    'Cherry Hill Mall': 'NJ',
})

city_to_state.update({
    'United States Coast Guard - Air Station Sacramento': 'CA',
    'Eastvale': 'CA',
    'Dallas-Fort Worth': 'TX',
    'Oyster Point': 'VA',
    'Lemmon Valley-Golden Valley': 'NV',
    'Moorestown-Lenola': 'NJ',
    'Patuxent River Naval Air Station': 'MD',
    'Wallingford Center': 'CT',
    'Seacliff': 'NY',
    'Capitol Hill': 'DC',
    'Brookpark Estates': 'OH',
    'Steinway': 'NY',
    'Wall Street': 'NY',
    'Kent Island': 'MD',
    'Peapack and Gladstone': 'NJ',
    'Chula Vista-Orason': 'CA',
    'Queen Anne': 'WA',
    'Coconut Point': 'FL',
    'Pryor Creek': 'OK',
    'Ft. Worth Naval Air Station Joint Reserve Base': 'TX',
    #'Brasilia': 'BR',
    'Berkley Heights': 'NJ',
    'Tucson Estates': 'AZ',
    'Summerlin': 'NV',
    #'Bowmanville': 'ON',
    'Alderwood': 'WA',
    'Greenburgh': 'NY',
    'Los Angeles Subdivision': 'CA',
    'Boca Chica': 'TX'
})
city_to_state.update({
    'Temecula Valley': 'CA',
    'Bay Terrace': 'NY',
    'St. Charles': 'IL',
    'Lynhaven': 'VA',
    'Oxon Hill-Glassmanor': 'MD',
    'Bay Ridge': 'NY',
    'James Island': 'SC',
    'Georgetown': 'DC',
    'Fort Devens': 'MA',
    'WDM': 'IA',
    'Greenbriar': 'VA',
    'Dulles Town Center': 'VA',
    'Lansdale': 'PA',
    'Quad Cities': 'IA',
    'Tinicum Township': 'PA',
    'Ocracoke Island': 'NC',
    'Robinson Township': 'PA',
    #'Venezuela': 'VE',
    'East Honolulu': 'HI',
    'Camp Creek Estates': 'GA',
    'Barrigada Heights': 'GU',
    'Yakima Valley': 'WA',
    'Chula Vista': 'CA',
    'Township of Hamilton': 'NJ',
    'Outer Banks': 'NC',
    'St. James': 'NY',
    'Fruitridge Pocket': 'CA',
    'Koreatown': 'CA',
    'Hog Island': 'VA',
    "Martha's Vineyard": 'MA',
    'Arlington Hts': 'IL',
    'San Ramon Valley': 'CA',
    'Sheridan': 'WY'
})

# %%
df['Postal'] = df['Postal'].replace(city_to_state)

# %%
drop_locations = ['Manatí', 'Las Piñas', 'Australia Island', 'QLD', 'St. John',
                 'GU','AS', 'Brasilia','Bowmanville', 'Venezuela', 'PR', 'VI']

# %%
df = df[~df['Postal'].isin(drop_locations)]

# %%
len(df['Postal'].unique())
# Out:
# 53

# %%
df[df['Postal']=='Gold Coast']
# Out:
#       review_id  rating_overall    location business_outlook review_date  \
# 5386   78630117               4  Gold Coast         POSITIVE  2023-07-27
#
#              Company      Postal
# 5386  JPMorgan Chase  Gold Coast

# %%
df['Postal'].unique()
# Out:
# array(['FL', 'CA', 'TX', 'TN', 'KY', 'DE', 'IL', 'DC', 'VA', 'WA', 'IN',
#        'CT', 'NV', 'CO', 'OH', 'NC', 'WI', 'MD', 'NE', 'OR', 'GA', 'NJ',
#        'MI', 'AZ', 'PA', 'KS', 'NY', 'ID', 'MA', 'AL', 'MN', 'MO', 'OK',
#        'UT', 'SC', 'MS', 'NM', 'IA', 'ND', 'MT', 'AR', 'RI', 'ME', 'NH',
#        'LA', 'WV', 'VT', 'SD', 'Gold Coast', None, 'WY', 'AK', 'HI'],
#       dtype=object)

# %%
df = df.merge(abbreviations, on='Postal', how='left')

# %%
df.State.unique()
# Out:
# array(['Florida', 'California', 'Texas', 'Tennessee', 'Kentucky',
#        'Delaware', 'Illinois', 'District of Columbia', 'Virginia',
#        'Washington', 'Indiana', 'Connecticut', 'Nevada', 'Colorado',
#        'Ohio', 'North Carolina', 'Wisconsin', 'Maryland', 'Nebraska',
#        'Oregon', 'Georgia', 'New Jersey', 'Michigan', 'Arizona',
#        'Pennsylvania', 'Kansas', 'New York', 'Idaho', 'Massachusetts',
#        'Alabama', 'Minnesota', 'Missouri', 'Oklahoma', 'Utah',
#        'South Carolina', 'Mississippi', 'New Mexico', 'Iowa',
#        'North Dakota', 'Montana', 'Arkansas', 'Rhode Island', 'Maine',
#        'New Hampshire', 'Louisiana', 'West Virginia', 'Vermont',
#        'South Dakota', nan, 'Wyoming', 'Alaska', 'Hawaii'], dtype=object)

# %%
len(df.State.unique())
# Out:
# 52

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198617 entries, 0 to 198616
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   review_id         198617 non-null  int64
#  1   rating_overall    198617 non-null  int64
#  2   location          198617 non-null  object
#  3   business_outlook  110573 non-null  object
#  4   review_date       198617 non-null  datetime64[ns]
#  5   Company           198617 non-null  object
#  6   Postal            198560 non-null  object
#  7   State             198559 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 13.6+ MB

# %%
df.drop(columns=['location', 'Postal'], inplace=True)

# %%
df = df.merge(seed_list, on='Company', how='left')

# %%
df
# Out:
#         review_id  rating_overall business_outlook review_date Company  \
# 0        79012884               4             None  2023-08-09  Amazon
# 1        79011408               4          NEUTRAL  2023-08-09  Amazon
# 2        79011236               1          NEUTRAL  2023-08-09  Amazon
# 3        79010569               4         POSITIVE  2023-08-09  Amazon
# 4        79010303               1         NEGATIVE  2023-08-09  Amazon
# ...           ...             ...              ...         ...     ...
# 198612   61759513               2             None  2022-03-25  Oracle
# 198613   61741825               5         POSITIVE  2022-03-24  Oracle
# 198614   61733583               3             None  2022-03-24  Oracle
# 198615   61718820               5         POSITIVE  2022-03-24  Oracle
# 198616   61712605               3             None  2022-03-24  Oracle
#
#              State Industry
# 0          Florida     Tech
# 1       California     Tech
# 2            Texas     Tech
# 3        Tennessee     Tech
# 4       California     Tech
# ...            ...      ...
# 198612       Texas     Tech
# 198613  California     Tech
# 198614  California     Tech
# 198615       Texas     Tech
# 198616  California     Tech
#
# [198617 rows x 7 columns]

# %% [markdown]
# # Analysis

# %%
import os

# Path to the folder containing the .webp images

# List all files in the folder
file_list = os.listdir(folder_path)

# Iterate through each file and rename it
for filename in file_list:
    # Check if the file is a .webp image
    if filename.endswith(".webp"):
        # Extract the new filename by removing the prefix and suffix
        new_filename = filename.replace("https___companiesmarketcap.com_", "").replace("_marketcap_.webp", ".webp")
        
        # Construct the old and new file paths
        old_filepath = os.path.join(folder_path, filename)
        new_filepath = os.path.join(folder_path, new_filename)
        
        # Rename the file
        os.rename(old_filepath, new_filepath)

# %% [markdown]
#  Rank companies overall and per industry on the percentage of employees with positive business outlook for the most recent 12 months

# %%
number_of_reviews = df.groupby('Company')['review_id'].count().reset_index()
number_of_reviews.columns = ['Company', 'reviews_total']
number_of_reviews
# Out:
#                     Company  reviews_total
# 0                       AMD            260
# 1                      AT&T           4422
# 2                    AbbVie            620
# 3       Abbott Laboratories            890
# 4                     Adobe            550
# ..                      ...            ...
# 99   Vertex Pharmaceuticals            209
# 100                    Visa            465
# 101                 Walmart          17431
# 102             Walt Disney           1907
# 103             Wells Fargo           5461
#
# [104 rows x 2 columns]

# %%
number_of_reviews_last_year = df[df.review_date >= one_year_ago].groupby('Company')['review_id'].count().reset_index()
number_of_reviews_last_year.columns = ['Company', 'reviews_total']

# %%
len(df[df.review_date >= one_year_ago])
# Out:
# 112804

# %%
number_of_reviews_two_years_ago =  df[df.review_date < one_year_ago].groupby('Company')['review_id'].count().reset_index()
number_of_reviews_two_years_ago.columns = ['Company', 'reviews_total']

# %%
len(df[df.review_date <= one_year_ago])
# Out:
# 86153

# %%
quantile_25_two_years_ago = number_of_reviews_two_years_ago.reviews_total.quantile(0.25)
quantile_25_two_years_ago
# Out:
# 122.0

# %%
quantile_25_last_year = number_of_reviews_last_year.reviews_total.quantile(0.25)
quantile_25_last_year
# Out:
# 170.75

# %%
(quantile_25_last_year + quantile_25_two_years_ago)/2
# Out:
# 146.375

# %%
quantile_25 = number_of_reviews.reviews_total.quantile(0.25)
quantile_25
# Out:
# 283.25

# %% [markdown]
# # Organise Tabs and Rankings

# %% [markdown]
# ## Top 10

# %% [markdown]
# Top 10: Top 10 companies on % of employees with positive business outlook
#
# Columns: Company, % of employees with positive business outlook, sample size of employees, company logo image link

# %%
#top_10 = df[df.review_date >= one_year_ago]

# %%
top_10 = df[df.business_outlook=='POSITIVE'].groupby('Company')['review_id'].count().reset_index()

# %%
top_10.columns = ['Company', 'Number of Positive reviews']

# %%
top_10 = top_10.merge(number_of_reviews, on='Company', how='left')

# %%
top_10['positive business outlook %'] = top_10['Number of Positive reviews']/top_10['reviews_total']

# %%
top_10 = top_10[top_10.reviews_total >=quantile_25]

# %%
top_10 = top_10.sort_values(by='positive business outlook %', ascending=False).head(10)

# %%
top_10['company logo image name'] = top_10['Company'].apply(lambda x: x.lower().replace(' ', '-') +'.webp')

# %%
top_10
# Out:
#                Company  Number of Positive reviews  reviews_total  \
# 85          ServiceNow                         347            500
# 68              NVIDIA                         253            365
# 52              Intuit                         648           1013
# 73  Palo Alto Networks                         179            288
# 4                Adobe                         331            550
# 60          Mastercard                         228            399
# 22   Boston Scientific                         260            486
# 92   Texas Instruments                         219            431
# 49           Honeywell                         754           1497
# 41           Eli Lilly                         182            369
#
#     positive business outlook %  company logo image name
# 85                     0.694000          servicenow.webp
# 68                     0.693151              nvidia.webp
# 52                     0.639684              intuit.webp
# 73                     0.621528  palo-alto-networks.webp
# 4                      0.601818               adobe.webp
# 60                     0.571429          mastercard.webp
# 22                     0.534979   boston-scientific.webp
# 92                     0.508121   texas-instruments.webp
# 49                     0.503674           honeywell.webp
# 41                     0.493225           eli-lilly.webp

# %% [markdown]
# ## Bottom 10

# %% [markdown]
# Bottom 10: Bottom 10 companies on % of employees with positive business outlook
#
# Columns: Company, % of employees with positive business outlook, sample size of employees, company logo image link

# %%
#bottom_10 = df[df.review_date >= one_year_ago]
bottom_10 = df[df.business_outlook=='POSITIVE'].groupby('Company')['review_id'].count().reset_index()

bottom_10.columns = ['Company', 'Number of Positive reviews']

bottom_10 = bottom_10.merge(number_of_reviews, on='Company', how='left')

bottom_10['positive business outlook %'] = bottom_10['Number of Positive reviews']/bottom_10['reviews_total']
bottom_10 = bottom_10[bottom_10.reviews_total >=quantile_25]

bottom_10 = bottom_10.sort_values(by='positive business outlook %', ascending=True).head(10)

# %%
bottom_10['company logo image name'] = bottom_10['Company'].apply(lambda x: x.lower().replace('\'', '').replace('(facebook)', '').replace('&', '').replace(' ', '-') +'.webp')

# %%
bottom_10
# Out:
#                        Company  Number of Positive reviews  reviews_total  \
# 61                    McDonald                        2509          13485
# 95   Union Pacific Corporation                          75            357
# 25                  CVS Health                        1501           7067
# 101                    Walmart                        3888          17431
# 86                   Starbucks                        2635          10907
# 103                Wells Fargo                        1362           5461
# 44                      Fiserv                         252            946
# 47               Goldman Sachs                         459           1595
# 63   Meta Platforms (Facebook)                         741           2562
# 102                Walt Disney                         553           1907
#
#      positive business outlook %         company logo image name
# 61                      0.186059                   mcdonald.webp
# 95                      0.210084  union-pacific-corporation.webp
# 25                      0.212396                 cvs-health.webp
# 101                     0.223051                    walmart.webp
# 86                      0.241588                  starbucks.webp
# 103                     0.249405                wells-fargo.webp
# 44                      0.266385                     fiserv.webp
# 47                      0.287774              goldman-sachs.webp
# 63                      0.289227            meta-platforms-.webp
# 102                     0.289984                walt-disney.webp

# %% [markdown]
# ## Overall Change

# %% [markdown]
# Overall Change: Top 10 & bottom 10 companies with most positive and negative year-on-year change in % of employees with positive business outlook
#
# Columns: Company,  (2022-2023) % of employees with positive business outlook, (2023-2024) % of employees with positive business outlook, sample size of employees (2022/23), sample size of employees (2023/24)

# %%
last_year = df[df.review_date >= one_year_ago]

# %%
last_year.review_date.min()
# Out:
# Timestamp('2023-03-24 00:00:00')

# %%
last_year.review_date.max()
# Out:
# Timestamp('2024-03-24 00:00:00')

# %%
last_year = last_year[last_year.business_outlook=='POSITIVE'].groupby('Company')['review_id'].count().reset_index()

last_year.columns = ['Company', 'Number of Positive reviews']

last_year = last_year.merge(number_of_reviews_last_year, on='Company', how='left')

last_year['positive business outlook %'] = last_year['Number of Positive reviews']/last_year['reviews_total']

#last_year = last_year[last_year.reviews_total >=220]
last_year.columns = ['Company', 'Number of Positive reviews (2023-2024)', 
                     'reviews_total (2023-2024)', 'positive business outlook % (2023-2024)']
last_year_average_percent = last_year['positive business outlook % (2023-2024)']
last_year['average_percent (2023-2024)'] = last_year['positive business outlook % (2023-2024)'].mean()
last_year
# Out:
#                     Company  Number of Positive reviews (2023-2024)  \
# 0                       AMD                                      88
# 1                      AT&T                                     660
# 2                    AbbVie                                     131
# 3       Abbott Laboratories                                     178
# 4                     Adobe                                     174
# ..                      ...                                     ...
# 99   Vertex Pharmaceuticals                                      57
# 100                    Visa                                     108
# 101                 Walmart                                    2010
# 102             Walt Disney                                     314
# 103             Wells Fargo                                     665
#
#      reviews_total (2023-2024)  positive business outlook % (2023-2024)  \
# 0                          171                                 0.514620
# 1                         2522                                 0.261697
# 2                          354                                 0.370056
# 3                          513                                 0.346979
# 4                          301                                 0.578073
# ..                         ...                                      ...
# 99                          92                                 0.619565
# 100                        270                                 0.400000
# 101                       9813                                 0.204830
# 102                       1120                                 0.280357
# 103                       3007                                 0.221151
#
#      average_percent (2023-2024)
# 0                       0.388784
# 1                       0.388784
# 2                       0.388784
# 3                       0.388784
# 4                       0.388784
# ..                           ...
# 99                      0.388784
# 100                     0.388784
# 101                     0.388784
# 102                     0.388784
# 103                     0.388784
#
# [104 rows x 5 columns]

# %%
two_years_ago = df[df.review_date < one_year_ago]

# %%
two_years_ago.review_date.min()
# Out:
# Timestamp('2022-03-24 00:00:00')

# %%
two_years_ago.review_date.max()
# Out:
# Timestamp('2023-03-23 00:00:00')

# %%
two_years_ago = two_years_ago[two_years_ago.business_outlook=='POSITIVE'].groupby('Company')['review_id'].count().reset_index()

two_years_ago.columns = ['Company', 'Number of Positive reviews']

two_years_ago = two_years_ago.merge(number_of_reviews_two_years_ago, on='Company', how='left')

two_years_ago['positive business outlook %'] = two_years_ago['Number of Positive reviews']/two_years_ago['reviews_total']

#two_years_ago = two_years_ago[two_years_ago.reviews_total >=220]
two_years_ago.columns = ['Company', 'Number of Positive reviews (2022-2023)', 
                     'reviews_total (2022-2023)', 'positive business outlook % (2022-2023)']
two_years_ago['average_percent (2022-2023)'] = two_years_ago['positive business outlook % (2022-2023)'].mean()

two_years_ago
# Out:
#                     Company  Number of Positive reviews (2022-2023)  \
# 0                       AMD                                      49
# 1                      AT&T                                     696
# 2                    AbbVie                                      98
# 3       Abbott Laboratories                                     160
# 4                     Adobe                                     157
# ..                      ...                                     ...
# 99   Vertex Pharmaceuticals                                      81
# 100                    Visa                                      93
# 101                 Walmart                                    1878
# 102             Walt Disney                                     239
# 103             Wells Fargo                                     697
#
#      reviews_total (2022-2023)  positive business outlook % (2022-2023)  \
# 0                           89                                 0.550562
# 1                         1900                                 0.366316
# 2                          266                                 0.368421
# 3                          377                                 0.424403
# 4                          249                                 0.630522
# ..                         ...                                      ...
# 99                         117                                 0.692308
# 100                        195                                 0.476923
# 101                       7618                                 0.246521
# 102                        787                                 0.303685
# 103                       2454                                 0.284026
#
#      average_percent (2022-2023)
# 0                       0.448821
# 1                       0.448821
# 2                       0.448821
# 3                       0.448821
# 4                       0.448821
# ..                           ...
# 99                      0.448821
# 100                     0.448821
# 101                     0.448821
# 102                     0.448821
# 103                     0.448821
#
# [104 rows x 5 columns]

# %%
overall_change = last_year.merge(two_years_ago, on='Company', how='left')

# %%
overall_change['change'] = overall_change['positive business outlook % (2023-2024)'] - overall_change['positive business outlook % (2022-2023)']

# %%
overall_change.dropna(subset=['change'], inplace=True)

# %%
overall_change = overall_change[(overall_change['reviews_total (2023-2024)'] > 146.375) & (overall_change['reviews_total (2022-2023)'] > 220)]

# %%
overall_change
# Out:
#                        Company  Number of Positive reviews (2023-2024)  \
# 1                         AT&T                                     660
# 2                       AbbVie                                     131
# 3          Abbott Laboratories                                     178
# 4                        Adobe                                     174
# 6            Alphabet (Google)                                     929
# 7                       Amazon                                    3068
# 8             American Express                                     230
# 12                       Apple                                    1013
# 15   Automatic Data Processing                                     457
# 16             Bank of America                                     708
# 20                      Boeing                                     317
# 23        Bristol-Myers Squibb                                     129
# 25                  CVS Health                                     805
# 27                 Caterpillar                                     127
# 28              Charles Schwab                                     289
# 30                       Cigna                                     180
# 31                       Cisco                                     354
# 32                   Citigroup                                     399
# 34                     Comcast                                     353
# 36                      Costco                                     488
# 39                        Dell                                     377
# 40             Elevance Health                                     239
# 43                 Exxon Mobil                                      89
# 44                      Fiserv                                     148
# 45            General Electric                                     113
# 47               Goldman Sachs                                     237
# 48                  Home Depot                                    1331
# 49                   Honeywell                                     329
# 50                         IBM                                     465
# 51                       Intel                                     393
# 52                      Intuit                                     373
# 54              JPMorgan Chase                                    1106
# 55           Johnson & Johnson                                     158
# 58             Lockheed Martin                                     456
# 59            Lowe's Companies                                     966
# 61                    McDonald                                    1395
# 62                       Merck                                     168
# 63   Meta Platforms (Facebook)                                     482
# 65                   Microsoft                                     979
# 67              Morgan Stanley                                     274
# 71                        Nike                                     115
# 72                      Oracle                                     474
# 74                     Pepsico                                     313
# 75                      Pfizer                                     145
# 77            Procter & Gamble                                     158
# 78                 Progressive                                     470
# 81       Raytheon Technologies                                     157
# 84                  Salesforce                                     563
# 86                   Starbucks                                    1500
# 87         Stryker Corporation                                     206
# 89                 T-Mobile US                                     641
# 90               TJX Companies                                     137
# 91                       Tesla                                     410
# 93    Thermo Fisher Scientific                                     295
# 94                        Uber                                     240
# 96       United Parcel Service                                     659
# 98                     Verizon                                     455
# 101                    Walmart                                    2010
# 102                Walt Disney                                     314
# 103                Wells Fargo                                     665
#
#      reviews_total (2023-2024)  positive business outlook % (2023-2024)  \
# 1                         2522                                 0.261697
# 2                          354                                 0.370056
# 3                          513                                 0.346979
# 4                          301                                 0.578073
# 6                         2963                                 0.313534
# 7                        12276                                 0.249919
# 8                          651                                 0.353303
# 12                        2496                                 0.405849
# 15                        1165                                 0.392275
# 16                        2196                                 0.322404
# 20                         900                                 0.352222
# 23                         402                                 0.320896
# 25                        3977                                 0.202414
# 27                         300                                 0.423333
# 28                         847                                 0.341204
# 30                         537                                 0.335196
# 31                         846                                 0.418440
# 32                        1318                                 0.302731
# 34                         987                                 0.357649
# 36                        1255                                 0.388845
# 39                        1162                                 0.324441
# 40                         624                                 0.383013
# 43                         251                                 0.354582
# 44                         550                                 0.269091
# 45                         363                                 0.311295
# 47                         895                                 0.264804
# 48                        4065                                 0.327429
# 49                         725                                 0.453793
# 50                        1499                                 0.310207
# 51                        1136                                 0.345951
# 52                         601                                 0.620632
# 54                        2747                                 0.402621
# 55                         444                                 0.355856
# 58                        1077                                 0.423398
# 59                        3342                                 0.289048
# 61                        8271                                 0.168662
# 62                         351                                 0.478632
# 63                        1487                                 0.324143
# 65                        2149                                 0.455561
# 67                         882                                 0.310658
# 71                         379                                 0.303430
# 72                        1631                                 0.290619
# 74                         856                                 0.365654
# 75                         491                                 0.295316
# 77                         352                                 0.448864
# 78                        1004                                 0.468127
# 81                         479                                 0.327766
# 84                        1243                                 0.452936
# 86                        6880                                 0.218023
# 87                         473                                 0.435518
# 89                        2019                                 0.317484
# 90                         350                                 0.391429
# 91                        1050                                 0.390476
# 93                         884                                 0.333710
# 94                         827                                 0.290206
# 96                        2437                                 0.270414
# 98                        1583                                 0.287429
# 101                       9813                                 0.204830
# 102                       1120                                 0.280357
# 103                       3007                                 0.221151
#
#      average_percent (2023-2024)  Number of Positive reviews (2022-2023)  \
# 1                       0.388784                                     696
# 2                       0.388784                                      98
# 3                       0.388784                                     160
# 4                       0.388784                                     157
# 6                       0.388784                                     731
# 7                       0.388784                                    4030
# 8                       0.388784                                     176
# 12                      0.388784                                     848
# 15                      0.388784                                     370
# 16                      0.388784                                     676
# 20                      0.388784                                     335
# 23                      0.388784                                     123
# 25                      0.388784                                     696
# 27                      0.388784                                     106
# 28                      0.388784                                     252
# 30                      0.388784                                     176
# 31                      0.388784                                     322
# 32                      0.388784                                     360
# 34                      0.388784                                     315
# 36                      0.388784                                     467
# 39                      0.388784                                     358
# 40                      0.388784                                     197
# 43                      0.388784                                     102
# 44                      0.388784                                     104
# 45                      0.388784                                      71
# 47                      0.388784                                     222
# 48                      0.388784                                    1234
# 49                      0.388784                                     425
# 50                      0.388784                                     507
# 51                      0.388784                                     300
# 52                      0.388784                                     275
# 54                      0.388784                                     808
# 55                      0.388784                                     162
# 58                      0.388784                                     409
# 59                      0.388784                                     871
# 61                      0.388784                                    1114
# 62                      0.388784                                     128
# 63                      0.388784                                     259
# 65                      0.388784                                     744
# 67                      0.388784                                     272
# 71                      0.388784                                     233
# 72                      0.388784                                     406
# 74                      0.388784                                     252
# 75                      0.388784                                     147
# 77                      0.388784                                     139
# 78                      0.388784                                     330
# 81                      0.388784                                      92
# 84                      0.388784                                     393
# 86                      0.388784                                    1135
# 87                      0.388784                                     170
# 89                      0.388784                                     573
# 90                      0.388784                                     118
# 91                      0.388784                                     353
# 93                      0.388784                                     262
# 94                      0.388784                                     236
# 96                      0.388784                                     705
# 98                      0.388784                                     480
# 101                     0.388784                                    1878
# 102                     0.388784                                     239
# 103                     0.388784                                     697
#
#      reviews_total (2022-2023)  positive business outlook % (2022-2023)  \
# 1                         1900                                 0.366316
# 2                          266                                 0.368421
# 3                          377                                 0.424403
# 4                          249                                 0.630522
# 6                         1810                                 0.403867
# 7                        11352                                 0.355004
# 8                          401                                 0.438903
# 12                        1817                                 0.466703
# 15                         848                                 0.436321
# 16                        1803                                 0.374931
# 20                         870                                 0.385057
# 23                         286                                 0.430070
# 25                        3090                                 0.225243
# 27                         225                                 0.471111
# 28                         546                                 0.461538
# 30                         395                                 0.445570
# 31                         616                                 0.522727
# 32                         972                                 0.370370
# 34                         792                                 0.397727
# 36                        1054                                 0.443074
# 39                         744                                 0.481183
# 40                         431                                 0.457077
# 43                         243                                 0.419753
# 44                         396                                 0.262626
# 45                         257                                 0.276265
# 47                         700                                 0.317143
# 48                        3299                                 0.374053
# 49                         772                                 0.550518
# 50                        1225                                 0.413878
# 51                         879                                 0.341297
# 52                         412                                 0.667476
# 54                        2028                                 0.398422
# 55                         376                                 0.430851
# 58                         895                                 0.456983
# 59                        2618                                 0.332697
# 61                        5214                                 0.213656
# 62                         257                                 0.498054
# 63                        1075                                 0.240930
# 65                        1454                                 0.511692
# 67                         684                                 0.397661
# 71                         681                                 0.342144
# 72                        1134                                 0.358025
# 74                         599                                 0.420701
# 75                         319                                 0.460815
# 77                         295                                 0.471186
# 78                         637                                 0.518053
# 81                         278                                 0.330935
# 84                         871                                 0.451206
# 86                        4027                                 0.281848
# 87                         357                                 0.476190
# 89                        1443                                 0.397089
# 90                         286                                 0.412587
# 91                         791                                 0.446271
# 93                         538                                 0.486989
# 94                         704                                 0.335227
# 96                        2240                                 0.314732
# 98                        1324                                 0.362538
# 101                       7618                                 0.246521
# 102                        787                                 0.303685
# 103                       2454                                 0.284026
#
#      average_percent (2022-2023)    change
# 1                       0.448821 -0.104619
# 2                       0.448821  0.001635
# 3                       0.448821 -0.077425
# 4                       0.448821 -0.052449
# 6                       0.448821 -0.090334
# 7                       0.448821 -0.105085
# 8                       0.448821 -0.085600
# 12                      0.448821 -0.060854
# 15                      0.448821 -0.044046
# 16                      0.448821 -0.052526
# 20                      0.448821 -0.032835
# 23                      0.448821 -0.109174
# 25                      0.448821 -0.022829
# 27                      0.448821 -0.047778
# 28                      0.448821 -0.120334
# 30                      0.448821 -0.110374
# 31                      0.448821 -0.104288
# 32                      0.448821 -0.067639
# 34                      0.448821 -0.040078
# 36                      0.448821 -0.054229
# 39                      0.448821 -0.156742
# 40                      0.448821 -0.074064
# 43                      0.448821 -0.065171
# 44                      0.448821  0.006465
# 45                      0.448821  0.035030
# 47                      0.448821 -0.052338
# 48                      0.448821 -0.046623
# 49                      0.448821 -0.096725
# 50                      0.448821 -0.103671
# 51                      0.448821  0.004654
# 52                      0.448821 -0.046843
# 54                      0.448821  0.004199
# 55                      0.448821 -0.074995
# 58                      0.448821 -0.033585
# 59                      0.448821 -0.043648
# 61                      0.448821 -0.044994
# 62                      0.448821 -0.019422
# 63                      0.448821  0.083212
# 65                      0.448821 -0.056131
# 67                      0.448821 -0.087003
# 71                      0.448821 -0.038714
# 72                      0.448821 -0.067405
# 74                      0.448821 -0.055047
# 75                      0.448821 -0.165499
# 77                      0.448821 -0.022323
# 78                      0.448821 -0.049926
# 81                      0.448821 -0.003169
# 84                      0.448821  0.001731
# 86                      0.448821 -0.063824
# 87                      0.448821 -0.040673
# 89                      0.448821 -0.079605
# 90                      0.448821 -0.021159
# 91                      0.448821 -0.055794
# 93                      0.448821 -0.153278
# 94                      0.448821 -0.045022
# 96                      0.448821 -0.044318
# 98                      0.448821 -0.075109
# 101                     0.448821 -0.041691
# 102                     0.448821 -0.023328
# 103                     0.448821 -0.062875

# %%
top_10_overall_change = overall_change.sort_values(by='change', ascending=False).head(10)
top_10_overall_change['company logo image name'] = top_10_overall_change['Company'].apply(lambda x: x.lower().replace('\'', '').replace('(facebook)', '').replace('&', '').replace(' ', '-') +'.webp')
top_10_overall_change
# Out:
#                       Company  Number of Positive reviews (2023-2024)  \
# 63  Meta Platforms (Facebook)                                     482
# 45           General Electric                                     113
# 44                     Fiserv                                     148
# 51                      Intel                                     393
# 54             JPMorgan Chase                                    1106
# 84                 Salesforce                                     563
# 2                      AbbVie                                     131
# 81      Raytheon Technologies                                     157
# 62                      Merck                                     168
# 90              TJX Companies                                     137
#
#     reviews_total (2023-2024)  positive business outlook % (2023-2024)  \
# 63                       1487                                 0.324143
# 45                        363                                 0.311295
# 44                        550                                 0.269091
# 51                       1136                                 0.345951
# 54                       2747                                 0.402621
# 84                       1243                                 0.452936
# 2                         354                                 0.370056
# 81                        479                                 0.327766
# 62                        351                                 0.478632
# 90                        350                                 0.391429
#
#     average_percent (2023-2024)  Number of Positive reviews (2022-2023)  \
# 63                     0.388784                                     259
# 45                     0.388784                                      71
# 44                     0.388784                                     104
# 51                     0.388784                                     300
# 54                     0.388784                                     808
# 84                     0.388784                                     393
# 2                      0.388784                                      98
# 81                     0.388784                                      92
# 62                     0.388784                                     128
# 90                     0.388784                                     118
#
#     reviews_total (2022-2023)  positive business outlook % (2022-2023)  \
# 63                       1075                                 0.240930
# 45                        257                                 0.276265
# 44                        396                                 0.262626
# 51                        879                                 0.341297
# 54                       2028                                 0.398422
# 84                        871                                 0.451206
# 2                         266                                 0.368421
# 81                        278                                 0.330935
# 62                        257                                 0.498054
# 90                        286                                 0.412587
#
#     average_percent (2022-2023)    change     company logo image name
# 63                     0.448821  0.083212        meta-platforms-.webp
# 45                     0.448821  0.035030       general-electric.webp
# 44                     0.448821  0.006465                 fiserv.webp
# 51                     0.448821  0.004654                  intel.webp
# 54                     0.448821  0.004199         jpmorgan-chase.webp
# 84                     0.448821  0.001731             salesforce.webp
# 2                      0.448821  0.001635                 abbvie.webp
# 81                     0.448821 -0.003169  raytheon-technologies.webp
# 62                     0.448821 -0.019422                  merck.webp
# 90                     0.448821 -0.021159          tjx-companies.webp

# %%
bottom_10_overall_change = overall_change.sort_values(by='change', ascending=True).head(10)
bottom_10_overall_change['company logo image name'] = bottom_10_overall_change['Company'].apply(lambda x: x.lower().replace('\'', '').replace('(facebook)', '').replace('&', '').replace(' ', '-') +'.webp')
bottom_10_overall_change
# Out:
#                      Company  Number of Positive reviews (2023-2024)  \
# 75                    Pfizer                                     145
# 39                      Dell                                     377
# 93  Thermo Fisher Scientific                                     295
# 28            Charles Schwab                                     289
# 30                     Cigna                                     180
# 23      Bristol-Myers Squibb                                     129
# 7                     Amazon                                    3068
# 1                       AT&T                                     660
# 31                     Cisco                                     354
# 50                       IBM                                     465
#
#     reviews_total (2023-2024)  positive business outlook % (2023-2024)  \
# 75                        491                                 0.295316
# 39                       1162                                 0.324441
# 93                        884                                 0.333710
# 28                        847                                 0.341204
# 30                        537                                 0.335196
# 23                        402                                 0.320896
# 7                       12276                                 0.249919
# 1                        2522                                 0.261697
# 31                        846                                 0.418440
# 50                       1499                                 0.310207
#
#     average_percent (2023-2024)  Number of Positive reviews (2022-2023)  \
# 75                     0.388784                                     147
# 39                     0.388784                                     358
# 93                     0.388784                                     262
# 28                     0.388784                                     252
# 30                     0.388784                                     176
# 23                     0.388784                                     123
# 7                      0.388784                                    4030
# 1                      0.388784                                     696
# 31                     0.388784                                     322
# 50                     0.388784                                     507
#
#     reviews_total (2022-2023)  positive business outlook % (2022-2023)  \
# 75                        319                                 0.460815
# 39                        744                                 0.481183
# 93                        538                                 0.486989
# 28                        546                                 0.461538
# 30                        395                                 0.445570
# 23                        286                                 0.430070
# 7                       11352                                 0.355004
# 1                        1900                                 0.366316
# 31                        616                                 0.522727
# 50                       1225                                 0.413878
#
#     average_percent (2022-2023)    change        company logo image name
# 75                     0.448821 -0.165499                    pfizer.webp
# 39                     0.448821 -0.156742                      dell.webp
# 93                     0.448821 -0.153278  thermo-fisher-scientific.webp
# 28                     0.448821 -0.120334            charles-schwab.webp
# 30                     0.448821 -0.110374                     cigna.webp
# 23                     0.448821 -0.109174      bristol-myers-squibb.webp
# 7                      0.448821 -0.105085                    amazon.webp
# 1                      0.448821 -0.104619                       att.webp
# 31                     0.448821 -0.104288                     cisco.webp
# 50                     0.448821 -0.103671                       ibm.webp

# %% [markdown]
# ## Tech Giants

# %% [markdown]
# Tech Giants: Top 10 and bottom 10 tech companies on % of employees with positive business outlook
#
# Columns: Tech company, % of employees with positive business outlook, sample size of employees, company logo image link

# %%
tech_giants = df[df.Industry == 'Tech']

# %%
tech_giants = tech_giants[tech_giants.business_outlook=='POSITIVE'].groupby('Company')['review_id'].count().reset_index()

tech_giants.columns = ['Company', 'Number of Positive reviews']

tech_giants = tech_giants.merge(number_of_reviews, on='Company', how='left')

tech_giants['positive business outlook %'] = tech_giants['Number of Positive reviews']/tech_giants['reviews_total']

tech_giants = tech_giants[tech_giants.reviews_total >=quantile_25]
tech_giants_top = tech_giants.sort_values(by='positive business outlook %', ascending=False).head(10)

tech_giants_top['company logo image name'] = tech_giants_top['Company'].apply(lambda x: x.lower().replace(' ', '-') +'.webp')

tech_giants_top
# Out:
#                Company  Number of Positive reviews  reviews_total  \
# 31          ServiceNow                         347            500
# 25              NVIDIA                         253            365
# 19              Intuit                         648           1013
# 28  Palo Alto Networks                         179            288
# 1                Adobe                         331            550
# 34   Texas Instruments                         219            431
# 7    Applied Materials                         217            453
# 24           Microsoft                        1723           3603
# 13               Cisco                         676           1462
# 30          Salesforce                         956           2114
#
#     positive business outlook %  company logo image name
# 31                     0.694000          servicenow.webp
# 25                     0.693151              nvidia.webp
# 19                     0.639684              intuit.webp
# 28                     0.621528  palo-alto-networks.webp
# 1                      0.601818               adobe.webp
# 34                     0.508121   texas-instruments.webp
# 7                      0.479029   applied-materials.webp
# 24                     0.478213           microsoft.webp
# 13                     0.462380               cisco.webp
# 30                     0.452223          salesforce.webp

# %%
tech_giants_bottom = tech_giants.sort_values(by='positive business outlook %', ascending=True).head(10)

tech_giants_bottom['company logo image name'] = tech_giants_bottom['Company'].apply(lambda x: x.lower().replace(' ', '-') +'.webp')

tech_giants_bottom
# Out:
#                       Company  Number of Positive reviews  reviews_total  \
# 16                     Fiserv                         252            946
# 22  Meta Platforms (Facebook)                         741           2562
# 4                      Amazon                        7098          23628
# 35                       Uber                         476           1531
# 29                   QUALCOMM                         135            425
# 27                     Oracle                         880           2765
# 18                      Intel                         693           2015
# 3           Alphabet (Google)                        1660           4773
# 17                        IBM                         972           2724
# 14                       Dell                         735           1906
#
#     positive business outlook %         company logo image name
# 16                     0.266385                     fiserv.webp
# 22                     0.289227  meta-platforms-(facebook).webp
# 4                      0.300406                     amazon.webp
# 35                     0.310908                       uber.webp
# 29                     0.317647                   qualcomm.webp
# 27                     0.318264                     oracle.webp
# 18                     0.343921                      intel.webp
# 3                      0.347790          alphabet-(google).webp
# 17                     0.356828                        ibm.webp
# 14                     0.385624                       dell.webp

# %% [markdown]
# ## Tech Change

# %% [markdown]
# Tech Change: Top 10 & bottom 10 tech companies with most positive and negative year-on-year change in % of employees with positive business outlook
#
# Columns: Tech Company,  (2022-2023) % of employees with positive business outlook, (2023-2024) % of employees with positive business outlook, sample size of employees (2022/23), sample size of employees (2023/24)

# %%
tech_change = df[df.Industry == 'Tech']

# %%
tech_change_last_year = tech_change[tech_change.review_date >= one_year_ago]

# %%
tech_change_last_year = tech_change_last_year[tech_change_last_year.business_outlook=='POSITIVE'].groupby('Company')['review_id'].count().reset_index()

tech_change_last_year.columns = ['Company', 'Number of Positive reviews']

tech_change_last_year = tech_change_last_year.merge(number_of_reviews_last_year, on='Company', how='left')

tech_change_last_year['positive business outlook %'] = tech_change_last_year['Number of Positive reviews']/tech_change_last_year['reviews_total']

#last_year = last_year[last_year.reviews_total >=220]
tech_change_last_year.columns = ['Company', 'Number of Positive reviews (2023-2024)', 
                     'reviews_total (2023-2024)', 'positive business outlook % (2023-2024)']
tech_change_last_year['average_percent (2023-2024)'] = tech_change_last_year['positive business outlook % (2023-2024)'].mean()

tech_change_last_year
# Out:
#                            Company  Number of Positive reviews (2023-2024)  \
# 0                              AMD                                      88
# 1                            Adobe                                     174
# 2                           Airbnb                                      19
# 3                Alphabet (Google)                                     929
# 4                           Amazon                                    3068
# 5                   Analog Devices                                      37
# 6                            Apple                                    1013
# 7                Applied Materials                                     123
# 8                  Arista Networks                                      25
# 9        Automatic Data Processing                                     457
# 10  Booking Holdings (Booking.com)                                      19
# 11                        Broadcom                                      82
# 12          Cadence Design Systems                                      44
# 13                           Cisco                                     354
# 14                            Dell                                     377
# 15                         Equinix                                      38
# 16                          Fiserv                                     148
# 17                             IBM                                     465
# 18                           Intel                                     393
# 19                          Intuit                                     373
# 20                             KLA                                      39
# 21                    Lam Research                                      61
# 22       Meta Platforms (Facebook)                                     482
# 23               Micron Technology                                      80
# 24                       Microsoft                                     979
# 25                          NVIDIA                                     119
# 26                         Netflix                                      42
# 27                          Oracle                                     474
# 28              Palo Alto Networks                                     101
# 29                        QUALCOMM                                      81
# 30                      Salesforce                                     563
# 31                      ServiceNow                                     189
# 32                        Synopsys                                      45
# 33                           Tesla                                     410
# 34               Texas Instruments                                     110
# 35                            Uber                                     240
#
#     reviews_total (2023-2024)  positive business outlook % (2023-2024)  \
# 0                         171                                 0.514620
# 1                         301                                 0.578073
# 2                          61                                 0.311475
# 3                        2963                                 0.313534
# 4                       12276                                 0.249919
# 5                         125                                 0.296000
# 6                        2496                                 0.405849
# 7                         250                                 0.492000
# 8                          37                                 0.675676
# 9                        1165                                 0.392275
# 10                         62                                 0.306452
# 11                        185                                 0.443243
# 12                         85                                 0.517647
# 13                        846                                 0.418440
# 14                       1162                                 0.324441
# 15                         77                                 0.493506
# 16                        550                                 0.269091
# 17                       1499                                 0.310207
# 18                       1136                                 0.345951
# 19                        601                                 0.620632
# 20                         73                                 0.534247
# 21                        147                                 0.414966
# 22                       1487                                 0.324143
# 23                        201                                 0.398010
# 24                       2149                                 0.455561
# 25                        195                                 0.610256
# 26                        144                                 0.291667
# 27                       1631                                 0.290619
# 28                        170                                 0.594118
# 29                        294                                 0.275510
# 30                       1243                                 0.452936
# 31                        287                                 0.658537
# 32                         84                                 0.535714
# 33                       1050                                 0.390476
# 34                        253                                 0.434783
# 35                        827                                 0.290206
#
#     average_percent (2023-2024)
# 0                      0.423077
# 1                      0.423077
# 2                      0.423077
# 3                      0.423077
# 4                      0.423077
# 5                      0.423077
# 6                      0.423077
# 7                      0.423077
# 8                      0.423077
# 9                      0.423077
# 10                     0.423077
# 11                     0.423077
# 12                     0.423077
# 13                     0.423077
# 14                     0.423077
# 15                     0.423077
# 16                     0.423077
# 17                     0.423077
# 18                     0.423077
# 19                     0.423077
# 20                     0.423077
# 21                     0.423077
# 22                     0.423077
# 23                     0.423077
# 24                     0.423077
# 25                     0.423077
# 26                     0.423077
# 27                     0.423077
# 28                     0.423077
# 29                     0.423077
# 30                     0.423077
# 31                     0.423077
# 32                     0.423077
# 33                     0.423077
# 34                     0.423077
# 35                     0.423077

# %%
tech_change_two_years_ago = tech_change[tech_change.review_date < one_year_ago]

# %%
tech_change_two_years_ago = tech_change_two_years_ago[tech_change_two_years_ago.business_outlook=='POSITIVE'].groupby('Company')['review_id'].count().reset_index()

tech_change_two_years_ago.columns = ['Company', 'Number of Positive reviews']

tech_change_two_years_ago = tech_change_two_years_ago.merge(number_of_reviews_two_years_ago, on='Company', how='left')

tech_change_two_years_ago['positive business outlook %'] = tech_change_two_years_ago['Number of Positive reviews']/tech_change_two_years_ago['reviews_total']

#two_years_ago = two_years_ago[two_years_ago.reviews_total >=220]
tech_change_two_years_ago.columns = ['Company', 'Number of Positive reviews (2022-2023)', 
                     'reviews_total (2022-2023)', 'positive business outlook % (2022-2023)']
tech_change_two_years_ago['average_percent (2022-2023)'] = tech_change_two_years_ago['positive business outlook % (2022-2023)'].mean()

tech_change_two_years_ago
# Out:
#                            Company  Number of Positive reviews (2022-2023)  \
# 0                              AMD                                      49
# 1                            Adobe                                     157
# 2                           Airbnb                                      25
# 3                Alphabet (Google)                                     731
# 4                           Amazon                                    4030
# 5                   Analog Devices                                      45
# 6                            Apple                                     848
# 7                Applied Materials                                      94
# 8                  Arista Networks                                      15
# 9        Automatic Data Processing                                     370
# 10  Booking Holdings (Booking.com)                                      22
# 11                        Broadcom                                      37
# 12          Cadence Design Systems                                      24
# 13                           Cisco                                     322
# 14                            Dell                                     358
# 15                         Equinix                                      43
# 16                          Fiserv                                     104
# 17                             IBM                                     507
# 18                           Intel                                     300
# 19                          Intuit                                     275
# 20                             KLA                                      30
# 21                    Lam Research                                      53
# 22       Meta Platforms (Facebook)                                     259
# 23               Micron Technology                                      91
# 24                       Microsoft                                     744
# 25                          NVIDIA                                     134
# 26                         Netflix                                      46
# 27                          Oracle                                     406
# 28              Palo Alto Networks                                      78
# 29                        QUALCOMM                                      54
# 30                      Salesforce                                     393
# 31                      ServiceNow                                     158
# 32                        Synopsys                                      26
# 33                           Tesla                                     353
# 34               Texas Instruments                                     109
# 35                            Uber                                     236
#
#     reviews_total (2022-2023)  positive business outlook % (2022-2023)  \
# 0                          89                                 0.550562
# 1                         249                                 0.630522
# 2                          56                                 0.446429
# 3                        1810                                 0.403867
# 4                       11352                                 0.355004
# 5                          86                                 0.523256
# 6                        1817                                 0.466703
# 7                         203                                 0.463054
# 8                          23                                 0.652174
# 9                         848                                 0.436321
# 10                         66                                 0.333333
# 11                         72                                 0.513889
# 12                         48                                 0.500000
# 13                        616                                 0.522727
# 14                        744                                 0.481183
# 15                         65                                 0.661538
# 16                        396                                 0.262626
# 17                       1225                                 0.413878
# 18                        879                                 0.341297
# 19                        412                                 0.667476
# 20                         53                                 0.566038
# 21                        122                                 0.434426
# 22                       1075                                 0.240930
# 23                        218                                 0.417431
# 24                       1454                                 0.511692
# 25                        170                                 0.788235
# 26                        120                                 0.383333
# 27                       1134                                 0.358025
# 28                        118                                 0.661017
# 29                        131                                 0.412214
# 30                        871                                 0.451206
# 31                        213                                 0.741784
# 32                         53                                 0.490566
# 33                        791                                 0.446271
# 34                        178                                 0.612360
# 35                        704                                 0.335227
#
#     average_percent (2022-2023)
# 0                      0.485461
# 1                      0.485461
# 2                      0.485461
# 3                      0.485461
# 4                      0.485461
# 5                      0.485461
# 6                      0.485461
# 7                      0.485461
# 8                      0.485461
# 9                      0.485461
# 10                     0.485461
# 11                     0.485461
# 12                     0.485461
# 13                     0.485461
# 14                     0.485461
# 15                     0.485461
# 16                     0.485461
# 17                     0.485461
# 18                     0.485461
# 19                     0.485461
# 20                     0.485461
# 21                     0.485461
# 22                     0.485461
# 23                     0.485461
# 24                     0.485461
# 25                     0.485461
# 26                     0.485461
# 27                     0.485461
# 28                     0.485461
# 29                     0.485461
# 30                     0.485461
# 31                     0.485461
# 32                     0.485461
# 33                     0.485461
# 34                     0.485461
# 35                     0.485461

# %%
overall_tech_change = tech_change_last_year.merge(tech_change_two_years_ago, on='Company', how='left')

overall_tech_change['change'] = overall_tech_change['positive business outlook % (2023-2024)'] - overall_tech_change['positive business outlook % (2022-2023)']

overall_tech_change.dropna(subset=['change'], inplace=True)

#overall_tech_change = overall_tech_change[(overall_tech_change['reviews_total (2023-2024)'] > 146.375) & (overall_tech_change['reviews_total (2022-2023)'] > 220)]


overall_tech_change
# Out:
#                            Company  Number of Positive reviews (2023-2024)  \
# 0                              AMD                                      88
# 1                            Adobe                                     174
# 2                           Airbnb                                      19
# 3                Alphabet (Google)                                     929
# 4                           Amazon                                    3068
# 5                   Analog Devices                                      37
# 6                            Apple                                    1013
# 7                Applied Materials                                     123
# 8                  Arista Networks                                      25
# 9        Automatic Data Processing                                     457
# 10  Booking Holdings (Booking.com)                                      19
# 11                        Broadcom                                      82
# 12          Cadence Design Systems                                      44
# 13                           Cisco                                     354
# 14                            Dell                                     377
# 15                         Equinix                                      38
# 16                          Fiserv                                     148
# 17                             IBM                                     465
# 18                           Intel                                     393
# 19                          Intuit                                     373
# 20                             KLA                                      39
# 21                    Lam Research                                      61
# 22       Meta Platforms (Facebook)                                     482
# 23               Micron Technology                                      80
# 24                       Microsoft                                     979
# 25                          NVIDIA                                     119
# 26                         Netflix                                      42
# 27                          Oracle                                     474
# 28              Palo Alto Networks                                     101
# 29                        QUALCOMM                                      81
# 30                      Salesforce                                     563
# 31                      ServiceNow                                     189
# 32                        Synopsys                                      45
# 33                           Tesla                                     410
# 34               Texas Instruments                                     110
# 35                            Uber                                     240
#
#     reviews_total (2023-2024)  positive business outlook % (2023-2024)  \
# 0                         171                                 0.514620
# 1                         301                                 0.578073
# 2                          61                                 0.311475
# 3                        2963                                 0.313534
# 4                       12276                                 0.249919
# 5                         125                                 0.296000
# 6                        2496                                 0.405849
# 7                         250                                 0.492000
# 8                          37                                 0.675676
# 9                        1165                                 0.392275
# 10                         62                                 0.306452
# 11                        185                                 0.443243
# 12                         85                                 0.517647
# 13                        846                                 0.418440
# 14                       1162                                 0.324441
# 15                         77                                 0.493506
# 16                        550                                 0.269091
# 17                       1499                                 0.310207
# 18                       1136                                 0.345951
# 19                        601                                 0.620632
# 20                         73                                 0.534247
# 21                        147                                 0.414966
# 22                       1487                                 0.324143
# 23                        201                                 0.398010
# 24                       2149                                 0.455561
# 25                        195                                 0.610256
# 26                        144                                 0.291667
# 27                       1631                                 0.290619
# 28                        170                                 0.594118
# 29                        294                                 0.275510
# 30                       1243                                 0.452936
# 31                        287                                 0.658537
# 32                         84                                 0.535714
# 33                       1050                                 0.390476
# 34                        253                                 0.434783
# 35                        827                                 0.290206
#
#     average_percent (2023-2024)  Number of Positive reviews (2022-2023)  \
# 0                      0.423077                                      49
# 1                      0.423077                                     157
# 2                      0.423077                                      25
# 3                      0.423077                                     731
# 4                      0.423077                                    4030
# 5                      0.423077                                      45
# 6                      0.423077                                     848
# 7                      0.423077                                      94
# 8                      0.423077                                      15
# 9                      0.423077                                     370
# 10                     0.423077                                      22
# 11                     0.423077                                      37
# 12                     0.423077                                      24
# 13                     0.423077                                     322
# 14                     0.423077                                     358
# 15                     0.423077                                      43
# 16                     0.423077                                     104
# 17                     0.423077                                     507
# 18                     0.423077                                     300
# 19                     0.423077                                     275
# 20                     0.423077                                      30
# 21                     0.423077                                      53
# 22                     0.423077                                     259
# 23                     0.423077                                      91
# 24                     0.423077                                     744
# 25                     0.423077                                     134
# 26                     0.423077                                      46
# 27                     0.423077                                     406
# 28                     0.423077                                      78
# 29                     0.423077                                      54
# 30                     0.423077                                     393
# 31                     0.423077                                     158
# 32                     0.423077                                      26
# 33                     0.423077                                     353
# 34                     0.423077                                     109
# 35                     0.423077                                     236
#
#     reviews_total (2022-2023)  positive business outlook % (2022-2023)  \
# 0                          89                                 0.550562
# 1                         249                                 0.630522
# 2                          56                                 0.446429
# 3                        1810                                 0.403867
# 4                       11352                                 0.355004
# 5                          86                                 0.523256
# 6                        1817                                 0.466703
# 7                         203                                 0.463054
# 8                          23                                 0.652174
# 9                         848                                 0.436321
# 10                         66                                 0.333333
# 11                         72                                 0.513889
# 12                         48                                 0.500000
# 13                        616                                 0.522727
# 14                        744                                 0.481183
# 15                         65                                 0.661538
# 16                        396                                 0.262626
# 17                       1225                                 0.413878
# 18                        879                                 0.341297
# 19                        412                                 0.667476
# 20                         53                                 0.566038
# 21                        122                                 0.434426
# 22                       1075                                 0.240930
# 23                        218                                 0.417431
# 24                       1454                                 0.511692
# 25                        170                                 0.788235
# 26                        120                                 0.383333
# 27                       1134                                 0.358025
# 28                        118                                 0.661017
# 29                        131                                 0.412214
# 30                        871                                 0.451206
# 31                        213                                 0.741784
# 32                         53                                 0.490566
# 33                        791                                 0.446271
# 34                        178                                 0.612360
# 35                        704                                 0.335227
#
#     average_percent (2022-2023)    change
# 0                      0.485461 -0.035942
# 1                      0.485461 -0.052449
# 2                      0.485461 -0.134953
# 3                      0.485461 -0.090334
# 4                      0.485461 -0.105085
# 5                      0.485461 -0.227256
# 6                      0.485461 -0.060854
# 7                      0.485461  0.028946
# 8                      0.485461  0.023502
# 9                      0.485461 -0.044046
# 10                     0.485461 -0.026882
# 11                     0.485461 -0.070646
# 12                     0.485461  0.017647
# 13                     0.485461 -0.104288
# 14                     0.485461 -0.156742
# 15                     0.485461 -0.168032
# 16                     0.485461  0.006465
# 17                     0.485461 -0.103671
# 18                     0.485461  0.004654
# 19                     0.485461 -0.046843
# 20                     0.485461 -0.031791
# 21                     0.485461 -0.019460
# 22                     0.485461  0.083212
# 23                     0.485461 -0.019421
# 24                     0.485461 -0.056131
# 25                     0.485461 -0.177979
# 26                     0.485461 -0.091667
# 27                     0.485461 -0.067405
# 28                     0.485461 -0.066899
# 29                     0.485461 -0.136704
# 30                     0.485461  0.001731
# 31                     0.485461 -0.083247
# 32                     0.485461  0.045148
# 33                     0.485461 -0.055794
# 34                     0.485461 -0.177577
# 35                     0.485461 -0.045022

# %%
top_overall_tech_change = overall_tech_change.sort_values(by='change', ascending=False).head(10)
top_overall_tech_change['company logo image name'] = top_overall_tech_change['Company'].apply(lambda x: x.lower().replace('\'', '').replace('(facebook)', '').replace('&', '').replace(' ', '-') +'.webp')
top_overall_tech_change
# Out:
#                       Company  Number of Positive reviews (2023-2024)  \
# 22  Meta Platforms (Facebook)                                     482
# 32                   Synopsys                                      45
# 7           Applied Materials                                     123
# 8             Arista Networks                                      25
# 12     Cadence Design Systems                                      44
# 16                     Fiserv                                     148
# 18                      Intel                                     393
# 30                 Salesforce                                     563
# 23          Micron Technology                                      80
# 21               Lam Research                                      61
#
#     reviews_total (2023-2024)  positive business outlook % (2023-2024)  \
# 22                       1487                                 0.324143
# 32                         84                                 0.535714
# 7                         250                                 0.492000
# 8                          37                                 0.675676
# 12                         85                                 0.517647
# 16                        550                                 0.269091
# 18                       1136                                 0.345951
# 30                       1243                                 0.452936
# 23                        201                                 0.398010
# 21                        147                                 0.414966
#
#     average_percent (2023-2024)  Number of Positive reviews (2022-2023)  \
# 22                     0.423077                                     259
# 32                     0.423077                                      26
# 7                      0.423077                                      94
# 8                      0.423077                                      15
# 12                     0.423077                                      24
# 16                     0.423077                                     104
# 18                     0.423077                                     300
# 30                     0.423077                                     393
# 23                     0.423077                                      91
# 21                     0.423077                                      53
#
#     reviews_total (2022-2023)  positive business outlook % (2022-2023)  \
# 22                       1075                                 0.240930
# 32                         53                                 0.490566
# 7                         203                                 0.463054
# 8                          23                                 0.652174
# 12                         48                                 0.500000
# 16                        396                                 0.262626
# 18                        879                                 0.341297
# 30                        871                                 0.451206
# 23                        218                                 0.417431
# 21                        122                                 0.434426
#
#     average_percent (2022-2023)    change      company logo image name
# 22                     0.485461  0.083212         meta-platforms-.webp
# 32                     0.485461  0.045148                synopsys.webp
# 7                      0.485461  0.028946       applied-materials.webp
# 8                      0.485461  0.023502         arista-networks.webp
# 12                     0.485461  0.017647  cadence-design-systems.webp
# 16                     0.485461  0.006465                  fiserv.webp
# 18                     0.485461  0.004654                   intel.webp
# 30                     0.485461  0.001731              salesforce.webp
# 23                     0.485461 -0.019421       micron-technology.webp
# 21                     0.485461 -0.019460            lam-research.webp

# %%
bottom_overall_tech_change = overall_tech_change.sort_values(by='change', ascending=True).head(10)
bottom_overall_tech_change['company logo image name'] = bottom_overall_tech_change['Company'].apply(lambda x: x.lower().replace('\'', '').replace('(facebook)', '').replace('&', '').replace(' ', '-') +'.webp')
bottom_overall_tech_change
# Out:
#               Company  Number of Positive reviews (2023-2024)  \
# 5      Analog Devices                                      37
# 25             NVIDIA                                     119
# 34  Texas Instruments                                     110
# 15            Equinix                                      38
# 14               Dell                                     377
# 29           QUALCOMM                                      81
# 2              Airbnb                                      19
# 4              Amazon                                    3068
# 13              Cisco                                     354
# 17                IBM                                     465
#
#     reviews_total (2023-2024)  positive business outlook % (2023-2024)  \
# 5                         125                                 0.296000
# 25                        195                                 0.610256
# 34                        253                                 0.434783
# 15                         77                                 0.493506
# 14                       1162                                 0.324441
# 29                        294                                 0.275510
# 2                          61                                 0.311475
# 4                       12276                                 0.249919
# 13                        846                                 0.418440
# 17                       1499                                 0.310207
#
#     average_percent (2023-2024)  Number of Positive reviews (2022-2023)  \
# 5                      0.423077                                      45
# 25                     0.423077                                     134
# 34                     0.423077                                     109
# 15                     0.423077                                      43
# 14                     0.423077                                     358
# 29                     0.423077                                      54
# 2                      0.423077                                      25
# 4                      0.423077                                    4030
# 13                     0.423077                                     322
# 17                     0.423077                                     507
#
#     reviews_total (2022-2023)  positive business outlook % (2022-2023)  \
# 5                          86                                 0.523256
# 25                        170                                 0.788235
# 34                        178                                 0.612360
# 15                         65                                 0.661538
# 14                        744                                 0.481183
# 29                        131                                 0.412214
# 2                          56                                 0.446429
# 4                       11352                                 0.355004
# 13                        616                                 0.522727
# 17                       1225                                 0.413878
#
#     average_percent (2022-2023)    change company logo image name
# 5                      0.485461 -0.227256     analog-devices.webp
# 25                     0.485461 -0.177979             nvidia.webp
# 34                     0.485461 -0.177577  texas-instruments.webp
# 15                     0.485461 -0.168032            equinix.webp
# 14                     0.485461 -0.156742               dell.webp
# 29                     0.485461 -0.136704           qualcomm.webp
# 2                      0.485461 -0.134953             airbnb.webp
# 4                      0.485461 -0.105085             amazon.webp
# 13                     0.485461 -0.104288              cisco.webp
# 17                     0.485461 -0.103671                ibm.webp

# %% [markdown]
# ## Industries

# %% [markdown]
# Industries: Top company and bottom company per industry on % of employees with positive business outlook. Include the US average %.
#
# Columns: Industry, Top company, % of employees with positive business outlook, Bottom company, % of employees with positive business outlook, company logo image link

# %%
industries_count = seed_list.groupby('Industry')['Company'].count().reset_index().sort_values(by='Company', ascending=False)
industries_count = industries_count[industries_count.Company >2]
industries_list = industries_count.Industry.to_list()
industries_list.remove('Tech')

# %%
industries_list.remove('Oil&Gas and Energy',)

# %%
industries_list
# Out:
# ['Pharmaceuticals, Healthcare, Medical devices',
#  'Banks & Financial services',
#  'Food & Beverages',
#  'Aircraft manufacturers & Aerospace',
#  '🛍️ Retail',
#  'Machinery manufacturing',
#  '📡 Telecommunication']

# %%
industries = overall_change.merge(seed_list, on='Company', how='left')

# %%
industries = industries[industries.Industry.isin(industries_list)]

# %%
industries
# Out:
#                      Company  Number of Positive reviews (2023-2024)  \
# 0                       AT&T                                     660
# 1                     AbbVie                                     131
# 2        Abbott Laboratories                                     178
# 6           American Express                                     230
# 9            Bank of America                                     708
# 10                    Boeing                                     317
# 11      Bristol-Myers Squibb                                     129
# 12                CVS Health                                     805
# 13               Caterpillar                                     127
# 14            Charles Schwab                                     289
# 15                     Cigna                                     180
# 17                 Citigroup                                     399
# 19                    Costco                                     488
# 21           Elevance Health                                     239
# 24          General Electric                                     113
# 25             Goldman Sachs                                     237
# 26                Home Depot                                    1331
# 27                 Honeywell                                     329
# 31            JPMorgan Chase                                    1106
# 32         Johnson & Johnson                                     158
# 33           Lockheed Martin                                     456
# 34          Lowe's Companies                                     966
# 35                  McDonald                                    1395
# 36                     Merck                                     168
# 39            Morgan Stanley                                     274
# 42                   Pepsico                                     313
# 43                    Pfizer                                     145
# 45               Progressive                                     470
# 46     Raytheon Technologies                                     157
# 48                 Starbucks                                    1500
# 49       Stryker Corporation                                     206
# 50               T-Mobile US                                     641
# 53  Thermo Fisher Scientific                                     295
# 56                   Verizon                                     455
# 57                   Walmart                                    2010
# 59               Wells Fargo                                     665
#
#     reviews_total (2023-2024)  positive business outlook % (2023-2024)  \
# 0                        2522                                 0.261697
# 1                         354                                 0.370056
# 2                         513                                 0.346979
# 6                         651                                 0.353303
# 9                        2196                                 0.322404
# 10                        900                                 0.352222
# 11                        402                                 0.320896
# 12                       3977                                 0.202414
# 13                        300                                 0.423333
# 14                        847                                 0.341204
# 15                        537                                 0.335196
# 17                       1318                                 0.302731
# 19                       1255                                 0.388845
# 21                        624                                 0.383013
# 24                        363                                 0.311295
# 25                        895                                 0.264804
# 26                       4065                                 0.327429
# 27                        725                                 0.453793
# 31                       2747                                 0.402621
# 32                        444                                 0.355856
# 33                       1077                                 0.423398
# 34                       3342                                 0.289048
# 35                       8271                                 0.168662
# 36                        351                                 0.478632
# 39                        882                                 0.310658
# 42                        856                                 0.365654
# 43                        491                                 0.295316
# 45                       1004                                 0.468127
# 46                        479                                 0.327766
# 48                       6880                                 0.218023
# 49                        473                                 0.435518
# 50                       2019                                 0.317484
# 53                        884                                 0.333710
# 56                       1583                                 0.287429
# 57                       9813                                 0.204830
# 59                       3007                                 0.221151
#
#     average_percent (2023-2024)  Number of Positive reviews (2022-2023)  \
# 0                      0.388784                                     696
# 1                      0.388784                                      98
# 2                      0.388784                                     160
# 6                      0.388784                                     176
# 9                      0.388784                                     676
# 10                     0.388784                                     335
# 11                     0.388784                                     123
# 12                     0.388784                                     696
# 13                     0.388784                                     106
# 14                     0.388784                                     252
# 15                     0.388784                                     176
# 17                     0.388784                                     360
# 19                     0.388784                                     467
# 21                     0.388784                                     197
# 24                     0.388784                                      71
# 25                     0.388784                                     222
# 26                     0.388784                                    1234
# 27                     0.388784                                     425
# 31                     0.388784                                     808
# 32                     0.388784                                     162
# 33                     0.388784                                     409
# 34                     0.388784                                     871
# 35                     0.388784                                    1114
# 36                     0.388784                                     128
# 39                     0.388784                                     272
# 42                     0.388784                                     252
# 43                     0.388784                                     147
# 45                     0.388784                                     330
# 46                     0.388784                                      92
# 48                     0.388784                                    1135
# 49                     0.388784                                     170
# 50                     0.388784                                     573
# 53                     0.388784                                     262
# 56                     0.388784                                     480
# 57                     0.388784                                    1878
# 59                     0.388784                                     697
#
#     reviews_total (2022-2023)  positive business outlook % (2022-2023)  \
# 0                        1900                                 0.366316
# 1                         266                                 0.368421
# 2                         377                                 0.424403
# 6                         401                                 0.438903
# 9                        1803                                 0.374931
# 10                        870                                 0.385057
# 11                        286                                 0.430070
# 12                       3090                                 0.225243
# 13                        225                                 0.471111
# 14                        546                                 0.461538
# 15                        395                                 0.445570
# 17                        972                                 0.370370
# 19                       1054                                 0.443074
# 21                        431                                 0.457077
# 24                        257                                 0.276265
# 25                        700                                 0.317143
# 26                       3299                                 0.374053
# 27                        772                                 0.550518
# 31                       2028                                 0.398422
# 32                        376                                 0.430851
# 33                        895                                 0.456983
# 34                       2618                                 0.332697
# 35                       5214                                 0.213656
# 36                        257                                 0.498054
# 39                        684                                 0.397661
# 42                        599                                 0.420701
# 43                        319                                 0.460815
# 45                        637                                 0.518053
# 46                        278                                 0.330935
# 48                       4027                                 0.281848
# 49                        357                                 0.476190
# 50                       1443                                 0.397089
# 53                        538                                 0.486989
# 56                       1324                                 0.362538
# 57                       7618                                 0.246521
# 59                       2454                                 0.284026
#
#     average_percent (2022-2023)    change  \
# 0                      0.448821 -0.104619
# 1                      0.448821  0.001635
# 2                      0.448821 -0.077425
# 6                      0.448821 -0.085600
# 9                      0.448821 -0.052526
# 10                     0.448821 -0.032835
# 11                     0.448821 -0.109174
# 12                     0.448821 -0.022829
# 13                     0.448821 -0.047778
# 14                     0.448821 -0.120334
# 15                     0.448821 -0.110374
# 17                     0.448821 -0.067639
# 19                     0.448821 -0.054229
# 21                     0.448821 -0.074064
# 24                     0.448821  0.035030
# 25                     0.448821 -0.052338
# 26                     0.448821 -0.046623
# 27                     0.448821 -0.096725
# 31                     0.448821  0.004199
# 32                     0.448821 -0.074995
# 33                     0.448821 -0.033585
# 34                     0.448821 -0.043648
# 35                     0.448821 -0.044994
# 36                     0.448821 -0.019422
# 39                     0.448821 -0.087003
# 42                     0.448821 -0.055047
# 43                     0.448821 -0.165499
# 45                     0.448821 -0.049926
# 46                     0.448821 -0.003169
# 48                     0.448821 -0.063824
# 49                     0.448821 -0.040673
# 50                     0.448821 -0.079605
# 53                     0.448821 -0.153278
# 56                     0.448821 -0.075109
# 57                     0.448821 -0.041691
# 59                     0.448821 -0.062875
#
#                                         Industry
# 0                            📡 Telecommunication
# 1   Pharmaceuticals, Healthcare, Medical devices
# 2   Pharmaceuticals, Healthcare, Medical devices
# 6                     Banks & Financial services
# 9                     Banks & Financial services
# 10            Aircraft manufacturers & Aerospace
# 11  Pharmaceuticals, Healthcare, Medical devices
# 12  Pharmaceuticals, Healthcare, Medical devices
# 13                       Machinery manufacturing
# 14                    Banks & Financial services
# 15  Pharmaceuticals, Healthcare, Medical devices
# 17                    Banks & Financial services
# 19                                     🛍️ Retail
# 21  Pharmaceuticals, Healthcare, Medical devices
# 24                       Machinery manufacturing
# 25                    Banks & Financial services
# 26                                     🛍️ Retail
# 27            Aircraft manufacturers & Aerospace
# 31                    Banks & Financial services
# 32  Pharmaceuticals, Healthcare, Medical devices
# 33            Aircraft manufacturers & Aerospace
# 34                                     🛍️ Retail
# 35                              Food & Beverages
# 36  Pharmaceuticals, Healthcare, Medical devices
# 39                    Banks & Financial services
# 42                              Food & Beverages
# 43  Pharmaceuticals, Healthcare, Medical devices
# 45                    Banks & Financial services
# 46            Aircraft manufacturers & Aerospace
# 48                              Food & Beverages
# 49  Pharmaceuticals, Healthcare, Medical devices
# 50                           📡 Telecommunication
# 53  Pharmaceuticals, Healthcare, Medical devices
# 56                           📡 Telecommunication
# 57                                     🛍️ Retail
# 59                    Banks & Financial services

# %%
highest_change = industries.groupby('Industry').apply(lambda x: x.nlargest(1, 'change'))
lowest_change = industries.groupby('Industry').apply(lambda x: x.nsmallest(1, 'change'))

# %%
result_industries = pd.concat([highest_change, lowest_change])

result_industries.reset_index(drop=True, inplace=True)

result_industries = result_industries.sort_values(by=['Industry', 'change'], ascending=True)
result_industries['company logo image name'] = result_industries['Company'].apply(lambda x: x.lower().replace('\'', '').replace('(facebook)', '').replace('&', '').replace(' ', '-') +'.webp')

result_industries
# Out:
#                   Company  Number of Positive reviews (2023-2024)  \
# 7               Honeywell                                     329
# 0   Raytheon Technologies                                     157
# 8          Charles Schwab                                     289
# 1          JPMorgan Chase                                    1106
# 9               Starbucks                                    1500
# 2                McDonald                                    1395
# 10            Caterpillar                                     127
# 3        General Electric                                     113
# 11                 Pfizer                                     145
# 4                  AbbVie                                     131
# 12                   AT&T                                     660
# 5                 Verizon                                     455
# 13                 Costco                                     488
# 6                 Walmart                                    2010
#
#     reviews_total (2023-2024)  positive business outlook % (2023-2024)  \
# 7                         725                                 0.453793
# 0                         479                                 0.327766
# 8                         847                                 0.341204
# 1                        2747                                 0.402621
# 9                        6880                                 0.218023
# 2                        8271                                 0.168662
# 10                        300                                 0.423333
# 3                         363                                 0.311295
# 11                        491                                 0.295316
# 4                         354                                 0.370056
# 12                       2522                                 0.261697
# 5                        1583                                 0.287429
# 13                       1255                                 0.388845
# 6                        9813                                 0.204830
#
#     average_percent (2023-2024)  Number of Positive reviews (2022-2023)  \
# 7                      0.388784                                     425
# 0                      0.388784                                      92
# 8                      0.388784                                     252
# 1                      0.388784                                     808
# 9                      0.388784                                    1135
# 2                      0.388784                                    1114
# 10                     0.388784                                     106
# 3                      0.388784                                      71
# 11                     0.388784                                     147
# 4                      0.388784                                      98
# 12                     0.388784                                     696
# 5                      0.388784                                     480
# 13                     0.388784                                     467
# 6                      0.388784                                    1878
#
#     reviews_total (2022-2023)  positive business outlook % (2022-2023)  \
# 7                         772                                 0.550518
# 0                         278                                 0.330935
# 8                         546                                 0.461538
# 1                        2028                                 0.398422
# 9                        4027                                 0.281848
# 2                        5214                                 0.213656
# 10                        225                                 0.471111
# 3                         257                                 0.276265
# 11                        319                                 0.460815
# 4                         266                                 0.368421
# 12                       1900                                 0.366316
# 5                        1324                                 0.362538
# 13                       1054                                 0.443074
# 6                        7618                                 0.246521
#
#     average_percent (2022-2023)    change  \
# 7                      0.448821 -0.096725
# 0                      0.448821 -0.003169
# 8                      0.448821 -0.120334
# 1                      0.448821  0.004199
# 9                      0.448821 -0.063824
# 2                      0.448821 -0.044994
# 10                     0.448821 -0.047778
# 3                      0.448821  0.035030
# 11                     0.448821 -0.165499
# 4                      0.448821  0.001635
# 12                     0.448821 -0.104619
# 5                      0.448821 -0.075109
# 13                     0.448821 -0.054229
# 6                      0.448821 -0.041691
#
#                                         Industry     company logo image name
# 7             Aircraft manufacturers & Aerospace              honeywell.webp
# 0             Aircraft manufacturers & Aerospace  raytheon-technologies.webp
# 8                     Banks & Financial services         charles-schwab.webp
# 1                     Banks & Financial services         jpmorgan-chase.webp
# 9                               Food & Beverages              starbucks.webp
# 2                               Food & Beverages               mcdonald.webp
# 10                       Machinery manufacturing            caterpillar.webp
# 3                        Machinery manufacturing       general-electric.webp
# 11  Pharmaceuticals, Healthcare, Medical devices                 pfizer.webp
# 4   Pharmaceuticals, Healthcare, Medical devices                 abbvie.webp
# 12                           📡 Telecommunication                    att.webp
# 5                            📡 Telecommunication                verizon.webp
# 13                                     🛍️ Retail                 costco.webp
# 6                                      🛍️ Retail                walmart.webp

# %% [markdown]
# ## Top State

# %% [markdown]
# Top State: Top company state on % of employees with positive business outlook
#
# Columns: Top company, % of employees with positive business outlook

# %%
top_state = df[df.business_outlook=='POSITIVE'].groupby(['State','Company'])['review_id'].count().reset_index()

# %%
top_state.columns = ['State', 'Company', 'Number of Positive reviews']

# %%
reviews_number_state = df.groupby('State')['review_id'].count().reset_index()
reviews_number_state.columns = ['State', 'reviews_total']
reviews_number_state
# Out:
#                    State  reviews_total
# 0                Alabama           1731
# 1                 Alaska            164
# 2                Arizona           5386
# 3               Arkansas           1535
# 4             California          31142
# 5               Colorado           3181
# 6            Connecticut           1573
# 7               Delaware            957
# 8   District of Columbia           1230
# 9                Florida          12343
# 10               Georgia           8701
# 11                Hawaii            239
# 12                 Idaho            845
# 13              Illinois           7730
# 14               Indiana           2880
# 15                  Iowa           1013
# 16                Kansas           1188
# 17              Kentucky           1827
# 18             Louisiana           1327
# 19                 Maine            409
# 20              Maryland           2651
# 21         Massachusetts           4945
# 22              Michigan           3107
# 23             Minnesota           2147
# 24           Mississippi            688
# 25              Missouri           3250
# 26               Montana            220
# 27              Nebraska            767
# 28                Nevada           1629
# 29         New Hampshire            440
# 30            New Jersey           5691
# 31            New Mexico            527
# 32              New York          17000
# 33        North Carolina           7090
# 34          North Dakota            170
# 35                  Ohio           5108
# 36              Oklahoma           1465
# 37                Oregon           2877
# 38          Pennsylvania           5436
# 39          Rhode Island            584
# 40        South Carolina           1775
# 41          South Dakota            170
# 42             Tennessee           3105
# 43                 Texas          22734
# 44                  Utah           1918
# 45               Vermont             76
# 46              Virginia           4633
# 47            Washington          10977
# 48         West Virginia            374
# 49             Wisconsin           1496
# 50               Wyoming            108

# %%
top_state = top_state.merge(reviews_number_state, on='State', how='left')

top_state['positive business outlook %'] = top_state['Number of Positive reviews']/top_state['reviews_total']

# %%
top_state = top_state.groupby('State').apply(lambda x: x.nlargest(1, 'positive business outlook %'))
top_state.reset_index(drop=True, inplace=True)

# %%
top_state['company logo image name'] = top_state['Company'].apply(lambda x: x.lower().replace('\'', '').replace('(facebook)', '').replace('&', '').replace(' ', '-') +'.webp')

# %%
len(top_state)
# Out:
# 51

# %%
top_state
# Out:
#                    State                Company  Number of Positive reviews  \
# 0                Alabama                Walmart                          88
# 1                 Alaska             Home Depot                           8
# 2                Arizona                 Amazon                         245
# 3               Arkansas                Walmart                         315
# 4             California                 Amazon                         932
# 5               Colorado                 Amazon                         118
# 6            Connecticut             CVS Health                          73
# 7               Delaware         JPMorgan Chase                         148
# 8   District of Columbia                 Amazon                          56
# 9                Florida            Walt Disney                         293
# 10               Georgia             Home Depot                         492
# 11                Hawaii              Starbucks                          12
# 12                 Idaho      Micron Technology                         107
# 13              Illinois                 Amazon                         208
# 14               Indiana              Eli Lilly                         109
# 15                  Iowa        Deere & Company                          85
# 16                Kansas            T-Mobile US                          71
# 17              Kentucky  United Parcel Service                          94
# 18             Louisiana                Walmart                          72
# 19                 Maine                Walmart                          15
# 20              Maryland                 Amazon                         123
# 21         Massachusetts                 Amazon                         131
# 22              Michigan                 Amazon                         125
# 23             Minnesota      Boston Scientific                         129
# 24           Mississippi                Walmart                          38
# 25              Missouri                Walmart                         108
# 26               Montana                Walmart                           9
# 27              Nebraska                 Fiserv                          30
# 28                Nevada                 Amazon                         100
# 29         New Hampshire                Walmart                          23
# 30            New Jersey                 Amazon                         204
# 31            New Mexico                  Intel                          27
# 32              New York                 Amazon                         457
# 33        North Carolina       Lowe's Companies                         278
# 34          North Dakota              Microsoft                          10
# 35                  Ohio                 Amazon                         183
# 36              Oklahoma                Walmart                         102
# 37                Oregon                  Intel                         288
# 38          Pennsylvania                Comcast                         199
# 39          Rhode Island             CVS Health                          93
# 40        South Carolina                Walmart                          76
# 41          South Dakota                Walmart                           9
# 42             Tennessee                 Amazon                         189
# 43                 Texas                 Amazon                         679
# 44                  Utah          Goldman Sachs                          98
# 45               Vermont       Lowe's Companies                           4
# 46              Virginia                 Amazon                         315
# 47            Washington                 Amazon                        1346
# 48         West Virginia                Walmart                          21
# 49             Wisconsin                Walmart                          72
# 50               Wyoming                Walmart                           8
#
#     reviews_total  positive business outlook %     company logo image name
# 0            1731                     0.050838                walmart.webp
# 1             164                     0.048780             home-depot.webp
# 2            5386                     0.045488                 amazon.webp
# 3            1535                     0.205212                walmart.webp
# 4           31142                     0.029927                 amazon.webp
# 5            3181                     0.037095                 amazon.webp
# 6            1573                     0.046408             cvs-health.webp
# 7             957                     0.154650         jpmorgan-chase.webp
# 8            1230                     0.045528                 amazon.webp
# 9           12343                     0.023738            walt-disney.webp
# 10           8701                     0.056545             home-depot.webp
# 11            239                     0.050209              starbucks.webp
# 12            845                     0.126627      micron-technology.webp
# 13           7730                     0.026908                 amazon.webp
# 14           2880                     0.037847              eli-lilly.webp
# 15           1013                     0.083909         deere--company.webp
# 16           1188                     0.059764            t-mobile-us.webp
# 17           1827                     0.051450  united-parcel-service.webp
# 18           1327                     0.054258                walmart.webp
# 19            409                     0.036675                walmart.webp
# 20           2651                     0.046398                 amazon.webp
# 21           4945                     0.026491                 amazon.webp
# 22           3107                     0.040232                 amazon.webp
# 23           2147                     0.060084      boston-scientific.webp
# 24            688                     0.055233                walmart.webp
# 25           3250                     0.033231                walmart.webp
# 26            220                     0.040909                walmart.webp
# 27            767                     0.039113                 fiserv.webp
# 28           1629                     0.061387                 amazon.webp
# 29            440                     0.052273                walmart.webp
# 30           5691                     0.035846                 amazon.webp
# 31            527                     0.051233                  intel.webp
# 32          17000                     0.026882                 amazon.webp
# 33           7090                     0.039210        lowes-companies.webp
# 34            170                     0.058824              microsoft.webp
# 35           5108                     0.035826                 amazon.webp
# 36           1465                     0.069625                walmart.webp
# 37           2877                     0.100104                  intel.webp
# 38           5436                     0.036608                comcast.webp
# 39            584                     0.159247             cvs-health.webp
# 40           1775                     0.042817                walmart.webp
# 41            170                     0.052941                walmart.webp
# 42           3105                     0.060870                 amazon.webp
# 43          22734                     0.029867                 amazon.webp
# 44           1918                     0.051095          goldman-sachs.webp
# 45             76                     0.052632        lowes-companies.webp
# 46           4633                     0.067991                 amazon.webp
# 47          10977                     0.122620                 amazon.webp
# 48            374                     0.056150                walmart.webp
# 49           1496                     0.048128                walmart.webp
# 50            108                     0.074074                walmart.webp

# %% [markdown]
# ## Bottom State

# %% [markdown]
# Bottom State: Top company state on % of employees with positive business outlook
#
# Columns: Bottom company, % of employees with positive business outlook

# %%
bottom_state = df[df.business_outlook=='POSITIVE'].groupby(['State','Company'])['review_id'].count().reset_index()

bottom_state.columns = ['State', 'Company', 'Number of Positive reviews']

bottom_state = bottom_state.merge(reviews_number_state, on='State', how='left')

bottom_state['positive business outlook %'] = bottom_state['Number of Positive reviews']/bottom_state['reviews_total']

bottom_state = bottom_state.groupby('State').apply(lambda x: x.nsmallest(1, 'positive business outlook %'))
bottom_state.reset_index(drop=True, inplace=True)

bottom_state['company logo image name'] = bottom_state['Company'].apply(lambda x: x.lower().replace('\'', '').replace('(facebook)', '').replace('&', '').replace(' ', '-') +'.webp')

# %%
len(bottom_state)
# Out:
# 51

# %%
bottom_state
# Out:
#                    State                    Company  \
# 0                Alabama        Abbott Laboratories
# 1                 Alaska                       AT&T
# 2                Arizona                     AbbVie
# 3               Arkansas             Charles Schwab
# 4             California             American Tower
# 5               Colorado                     Airbnb
# 6            Connecticut          Alphabet (Google)
# 7               Delaware                       AT&T
# 8   District of Columbia        Abbott Laboratories
# 9                Florida                  BlackRock
# 10               Georgia                        AMD
# 11                Hawaii                     Amazon
# 12                 Idaho                       AT&T
# 13              Illinois           Blackstone Group
# 14               Indiana                        AMD
# 15                  Iowa  Automatic Data Processing
# 16                Kansas        Abbott Laboratories
# 17              Kentucky                        AMD
# 18             Louisiana                     AbbVie
# 19                 Maine          Applied Materials
# 20              Maryland                      Adobe
# 21         Massachusetts                     Airbnb
# 22              Michigan           American Express
# 23             Minnesota          Applied Materials
# 24           Mississippi           American Express
# 25              Missouri                        AMD
# 26               Montana                       AT&T
# 27              Nebraska                     Airbnb
# 28                Nevada        Abbott Laboratories
# 29         New Hampshire                     AbbVie
# 30            New Jersey          Applied Materials
# 31            New Mexico                       AT&T
# 32              New York             Analog Devices
# 33        North Carolina        Abbott Laboratories
# 34          North Dakota                       AT&T
# 35                  Ohio                      Adobe
# 36              Oklahoma                     AbbVie
# 37                Oregon                        AMD
# 38          Pennsylvania                     AbbVie
# 39          Rhode Island                       AT&T
# 40        South Carolina        Abbott Laboratories
# 41          South Dakota          Alphabet (Google)
# 42             Tennessee        Abbott Laboratories
# 43                 Texas            Arista Networks
# 44                  Utah                        AMD
# 45               Vermont  Automatic Data Processing
# 46              Virginia                     AbbVie
# 47            Washington                        AMD
# 48         West Virginia           American Express
# 49             Wisconsin                     AbbVie
# 50               Wyoming         Berkshire Hathaway
#
#     Number of Positive reviews  reviews_total  positive business outlook %  \
# 0                            1           1731                     0.000578
# 1                            1            164                     0.006098
# 2                            1           5386                     0.000186
# 3                            1           1535                     0.000651
# 4                            1          31142                     0.000032
# 5                            1           3181                     0.000314
# 6                            1           1573                     0.000636
# 7                            1            957                     0.001045
# 8                            1           1230                     0.000813
# 9                            1          12343                     0.000081
# 10                           1           8701                     0.000115
# 11                           1            239                     0.004184
# 12                           1            845                     0.001183
# 13                           1           7730                     0.000129
# 14                           1           2880                     0.000347
# 15                           1           1013                     0.000987
# 16                           1           1188                     0.000842
# 17                           1           1827                     0.000547
# 18                           1           1327                     0.000754
# 19                           1            409                     0.002445
# 20                           1           2651                     0.000377
# 21                           1           4945                     0.000202
# 22                           1           3107                     0.000322
# 23                           1           2147                     0.000466
# 24                           1            688                     0.001453
# 25                           1           3250                     0.000308
# 26                           1            220                     0.004545
# 27                           1            767                     0.001304
# 28                           1           1629                     0.000614
# 29                           1            440                     0.002273
# 30                           1           5691                     0.000176
# 31                           1            527                     0.001898
# 32                           1          17000                     0.000059
# 33                           1           7090                     0.000141
# 34                           1            170                     0.005882
# 35                           1           5108                     0.000196
# 36                           1           1465                     0.000683
# 37                           1           2877                     0.000348
# 38                           1           5436                     0.000184
# 39                           1            584                     0.001712
# 40                           1           1775                     0.000563
# 41                           1            170                     0.005882
# 42                           1           3105                     0.000322
# 43                           1          22734                     0.000044
# 44                           1           1918                     0.000521
# 45                           1             76                     0.013158
# 46                           1           4633                     0.000216
# 47                           1          10977                     0.000091
# 48                           1            374                     0.002674
# 49                           1           1496                     0.000668
# 50                           1            108                     0.009259
#
#            company logo image name
# 0         abbott-laboratories.webp
# 1                         att.webp
# 2                      abbvie.webp
# 3              charles-schwab.webp
# 4              american-tower.webp
# 5                      airbnb.webp
# 6           alphabet-(google).webp
# 7                         att.webp
# 8         abbott-laboratories.webp
# 9                   blackrock.webp
# 10                        amd.webp
# 11                     amazon.webp
# 12                        att.webp
# 13           blackstone-group.webp
# 14                        amd.webp
# 15  automatic-data-processing.webp
# 16        abbott-laboratories.webp
# 17                        amd.webp
# 18                     abbvie.webp
# 19          applied-materials.webp
# 20                      adobe.webp
# 21                     airbnb.webp
# 22           american-express.webp
# 23          applied-materials.webp
# 24           american-express.webp
# 25                        amd.webp
# 26                        att.webp
# 27                     airbnb.webp
# 28        abbott-laboratories.webp
# 29                     abbvie.webp
# 30          applied-materials.webp
# 31                        att.webp
# 32             analog-devices.webp
# 33        abbott-laboratories.webp
# 34                        att.webp
# 35                      adobe.webp
# 36                     abbvie.webp
# 37                        amd.webp
# 38                     abbvie.webp
# 39                        att.webp
# 40        abbott-laboratories.webp
# 41          alphabet-(google).webp
# 42        abbott-laboratories.webp
# 43            arista-networks.webp
# 44                        amd.webp
# 45  automatic-data-processing.webp
# 46                     abbvie.webp
# 47                        amd.webp
# 48           american-express.webp
# 49                     abbvie.webp
# 50         berkshire-hathaway.webp

# %% [markdown]
# ## California

# %% [markdown]
# California: Top 10 and bottom 10 companies from employees based in California, based on % of employees with positive business outlook
#
# Columns: Top company, % of employees with positive business outlook

# %%
california = df[df.State=='California']

# %%
reviews_number_california = df.groupby('Company')['review_id'].count().reset_index()
reviews_number_california.columns = ['Company', 'reviews_total']
reviews_number_california
# Out:
#                     Company  reviews_total
# 0                       AMD            260
# 1                      AT&T           4422
# 2                    AbbVie            620
# 3       Abbott Laboratories            890
# 4                     Adobe            550
# ..                      ...            ...
# 99   Vertex Pharmaceuticals            209
# 100                    Visa            465
# 101                 Walmart          17431
# 102             Walt Disney           1907
# 103             Wells Fargo           5461
#
# [104 rows x 2 columns]

# %%
quantile_25 = reviews_number_california.reviews_total.quantile(0.25)
quantile_25
# Out:
# 283.25

# %%
california = california[california.business_outlook=='POSITIVE'].groupby('Company')['review_id'].count().reset_index()
california.columns = ['Company', 'Number of Positive reviews']
california = california.merge(reviews_number_california, on='Company', how='left')
california['positive business outlook %'] = california['Number of Positive reviews']/california['reviews_total']
california = california[california.reviews_total >=quantile_25]
california
# Out:
#                 Company  Number of Positive reviews  reviews_total  \
# 1                  AT&T                         150           4422
# 2                AbbVie                          22            620
# 3   Abbott Laboratories                          69            890
# 4                 Adobe                         144            550
# 6     Alphabet (Google)                         830           4773
# ..                  ...                         ...            ...
# 92              Verizon                          59           2907
# 94                 Visa                          73            465
# 95              Walmart                         232          17431
# 96          Walt Disney                         177           1907
# 97          Wells Fargo                         172           5461
#
#     positive business outlook %
# 1                      0.033921
# 2                      0.035484
# 3                      0.077528
# 4                      0.261818
# 6                      0.173895
# ..                          ...
# 92                     0.020296
# 94                     0.156989
# 95                     0.013310
# 96                     0.092816
# 97                     0.031496
#
# [76 rows x 4 columns]

# %%
top_california = california.sort_values(by='positive business outlook %', ascending=False).head(10)

top_california['company logo image name'] = top_california['Company'].apply(lambda x: x.lower().replace(' ', '-') +'.webp')

top_california
# Out:
#                Company  Number of Positive reviews  reviews_total  \
# 65              NVIDIA                         193            365
# 80          ServiceNow                         187            500
# 70  Palo Alto Networks                         107            288
# 76            QUALCOMM                         117            425
# 49              Intuit                         274           1013
# 4                Adobe                         144            550
# 10               Amgen                          76            308
# 86               Tesla                         407           1841
# 30               Cisco                         310           1462
# 13   Applied Materials                          89            453
#
#     positive business outlook %  company logo image name
# 65                     0.528767              nvidia.webp
# 80                     0.374000          servicenow.webp
# 70                     0.371528  palo-alto-networks.webp
# 76                     0.275294            qualcomm.webp
# 49                     0.270484              intuit.webp
# 4                      0.261818               adobe.webp
# 10                     0.246753               amgen.webp
# 86                     0.221076               tesla.webp
# 30                     0.212038               cisco.webp
# 13                     0.196468   applied-materials.webp

# %%
bottom_california = california.sort_values(by='positive business outlook %', ascending=True).head(10)

bottom_california['company logo image name'] = bottom_california['Company'].apply(lambda x: x.lower().replace(' ', '-') +'.webp')

bottom_california
# Out:
#              Company  Number of Positive reviews  reviews_total  \
# 41            Fiserv                           3            946
# 26       Caterpillar                           2            525
# 8   American Express                           6           1052
# 36   Deere & Company                           3            448
# 42  General Electric                           5            620
# 44     Goldman Sachs                          15           1595
# 29             Cigna                           9            932
# 73  Procter & Gamble                           7            647
# 32         Coca-Cola                           5            427
# 74       Progressive                          21           1641
#
#     positive business outlook % company logo image name
# 41                     0.003171             fiserv.webp
# 26                     0.003810        caterpillar.webp
# 8                      0.005703   american-express.webp
# 36                     0.006696    deere-&-company.webp
# 42                     0.008065   general-electric.webp
# 44                     0.009404      goldman-sachs.webp
# 29                     0.009657              cigna.webp
# 73                     0.010819   procter-&-gamble.webp
# 32                     0.011710          coca-cola.webp
# 74                     0.012797        progressive.webp

# %% [markdown]
# # Create an Excel file

# %%
# Create an Excel writer object

writer = pd.ExcelWriter('The Companies Where Employee Confidence is Highest and Lowest.xlsx')

# %%
top_10.to_excel(writer, sheet_name='Top 10', index=False)
bottom_10.to_excel(writer, sheet_name='Bottom 10', index=False)

# %%
top_10_overall_change.to_excel(writer, sheet_name='Overall Change', startrow=0, startcol=0, index=False)
bottom_10_overall_change.to_excel(writer, sheet_name='Overall Change', startrow=0, 
                   startcol=len(top_10_overall_change.columns) + 2, index=False)

# %%
tech_giants_top.to_excel(writer, sheet_name='Tech Giants', startrow=0, startcol=0, index=False)
tech_giants_bottom.to_excel(writer, sheet_name='Tech Giants', startrow=0, 
                   startcol=len(tech_giants_top.columns) + 2, index=False)

# %%
top_overall_tech_change.to_excel(writer, sheet_name='Tech Change', startrow=0, startcol=0, index=False)
bottom_overall_tech_change.to_excel(writer, sheet_name='Tech Change', startrow=0, 
                   startcol=len(top_overall_tech_change.columns) + 2, index=False)

# %%
result_industries.to_excel(writer, sheet_name='Industries', index=False)

# %%
top_state.to_excel(writer, sheet_name='Top State', index=False)
bottom_state.to_excel(writer, sheet_name='Bottom State', index=False)

# %%
top_california.to_excel(writer, sheet_name='California', startrow=0, startcol=0, index=False)
bottom_california.to_excel(writer, sheet_name='California', startrow=0, 
                   startcol=len(top_california.columns) + 2, index=False)

# %%
df.to_excel(writer, sheet_name='Raw Data', index=False)

# %%
# Save the Excel file
writer.save()
