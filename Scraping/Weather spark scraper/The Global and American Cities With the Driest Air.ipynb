# %%
import numpy as np
import pandas as pd
import requests
import re
import json
import time
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
import os

# %% [markdown]
# # Pull all “major places” for each country and US state

# %% [markdown]
# ## World

# %%
countries = pd.read_excel('countries_with_abbreviations.xlsx', index_col=0)

# %%
major_places_world = pd.read_csv('major_places_world.csv', index_col=0)

# %%
major_places_world = major_places_world.merge(countries, on='permalink', how='left')

# %%
major_places_world = major_places_world.drop_duplicates(subset=['major_place_name', 'major_place_link']).reset_index(drop=True)

# %%
major_places_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14665 entries, 0 to 14664
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   major_place_name  14665 non-null  object
#  1   major_place_link  14665 non-null  object
#  2   permalink         14665 non-null  object
#  3   Country           14565 non-null  object
#  4   Continent         14565 non-null  object
#  5   Abbreviation      14522 non-null  object
# dtypes: object(6)
# memory usage: 687.5+ KB

# %%
major_places_world[pd.isna(major_places_world.Country)].permalink.unique()
# Out:
# array(['https://weatherspark.com/countries/GB/SCT'], dtype=object)

# %%
major_places_world['Country'].fillna(value='united kingdom', inplace=True)
major_places_world['Continent '].fillna(value='Europe', inplace=True)

# %%
major_places_world['major_place_link'] = major_places_world['major_place_link'].apply(lambda x: x.replace('https://weatherspark.com', '') if pd.notna(x) else x)

# %%
major_places_world
# Out:
#       major_place_name                                   major_place_link  \
# 0              Abovyan  /y/103429/Average-Weather-in-Abovyan-Armenia-Y...
# 1               Agarak  /y/104077/Average-Weather-in-Agarak-Armenia-Ye...
# 2           Aghavnatun  /y/103426/Average-Weather-in-Aghavnatun-Armeni...
# 3             Akhuryan  /y/102827/Average-Weather-in-Akhuryan-Armenia-...
# 4               Akunk’  /y/103830/Average-Weather-in-Akunk%E2%80%99-Ar...
# ...                ...                                                ...
# 14660     Khawr Fakkān  /y/105545/Average-Weather-in-Khawr-Fakk%C4%81n...
# 14661         Muzayri‘  /y/105282/Average-Weather-in-Muzayri%E2%80%98-...
# 14662   Ras al-Khaimah  /y/105469/Average-Weather-in-Ras-al-Khaimah-Un...
# 14663          Sharjah  /y/105471/Average-Weather-in-Sharjah-United-Ar...
# 14664   Umm al Qaywayn  /y/105468/Average-Weather-in-Umm-al-Qaywayn-Un...
#
#                                    permalink               Country  \
# 0      https://weatherspark.com/countries/AM               armenia
# 1      https://weatherspark.com/countries/AM               armenia
# 2      https://weatherspark.com/countries/AM               armenia
# 3      https://weatherspark.com/countries/AM               armenia
# 4      https://weatherspark.com/countries/AM               armenia
# ...                                      ...                   ...
# 14660  https://weatherspark.com/countries/AE  united arab emirates
# 14661  https://weatherspark.com/countries/AE  united arab emirates
# 14662  https://weatherspark.com/countries/AE  united arab emirates
# 14663  https://weatherspark.com/countries/AE  united arab emirates
# 14664  https://weatherspark.com/countries/AE  united arab emirates
#
#                        Continent  Abbreviation
# 0                          Europe           AM
# 1                          Europe           AM
# 2                          Europe           AM
# 3                          Europe           AM
# 4                          Europe           AM
# ...                           ...          ...
# 14660  Middle East & Central Asia           AE
# 14661  Middle East & Central Asia           AE
# 14662  Middle East & Central Asia           AE
# 14663  Middle East & Central Asia           AE
# 14664  Middle East & Central Asia           AE
#
# [14665 rows x 6 columns]

# %% [markdown]
# ## US

# %%
us_states = pd.read_excel(folder_path + 'State and Territory Abbreviations.xlsx')
us_states['permalink'] = us_states['Postal'].apply(lambda x: 'https://weatherspark.com/countries/US/'+x)

# %%
major_places_us = pd.read_csv('major_places_us.csv', index_col=0)

# %%
major_places_us = major_places_us.merge(us_states, on='permalink', how='left')

# %%
major_places_us = major_places_us.drop_duplicates(subset=['major_place_name', 'major_place_link']).reset_index(drop=True)

# %%
major_places_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5183 entries, 0 to 5182
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   permalink         5183 non-null   object
#  1   major_place_link  5183 non-null   object
#  2   major_place_name  5183 non-null   object
#  3   State             5183 non-null   object
#  4   Postal            5183 non-null   object
# dtypes: object(5)
# memory usage: 202.6+ KB

# %%
major_places_us
# Out:
#                                      permalink  \
# 0     https://weatherspark.com/countries/US/AL
# 1     https://weatherspark.com/countries/US/AL
# 2     https://weatherspark.com/countries/US/AL
# 3     https://weatherspark.com/countries/US/AL
# 4     https://weatherspark.com/countries/US/AL
# ...                                        ...
# 5178  https://weatherspark.com/countries/US/TX
# 5179  https://weatherspark.com/countries/US/TX
# 5180  https://weatherspark.com/countries/US/TX
# 5181  https://weatherspark.com/countries/US/TX
# 5182  https://weatherspark.com/countries/US/TX
#
#                                        major_place_link major_place_name  \
# 0     /y/14608/Average-Weather-in-Alabaster-Alabama-...        Alabaster
# 1     /y/14639/Average-Weather-in-Albertville-Alabam...      Albertville
# 2     /y/15044/Average-Weather-in-Alexander-City-Ala...   Alexander City
# 3     /y/14515/Average-Weather-in-Andalusia-Alabama-...        Andalusia
# 4     /y/15070/Average-Weather-in-Anniston-Alabama-U...         Anniston
# ...                                                 ...              ...
# 5178  /y/7983/Average-Weather-in-Victoria-Texas-Unit...         Victoria
# 5179  /y/8079/Average-Weather-in-Waco-Texas-United-S...             Waco
# 5180  /y/7956/Average-Weather-in-Weslaco-Texas-Unite...          Weslaco
# 5181  /y/7193/Average-Weather-in-Wichita-Falls-Texas...    Wichita Falls
# 5182  /y/8914/Average-Weather-in-Wylie-Texas-United-...            Wylie
#
#         State Postal
# 0     Alabama     AL
# 1     Alabama     AL
# 2     Alabama     AL
# 3     Alabama     AL
# 4     Alabama     AL
# ...       ...    ...
# 5178    Texas     TX
# 5179    Texas     TX
# 5180    Texas     TX
# 5181    Texas     TX
# 5182    Texas     TX
#
# [5183 rows x 5 columns]

# %% [markdown]
# # Scrape weather data

# %% [markdown]
# ## Useful functions

# %%
def convert_path_to_coords(path):
    z = path.get('d').replace('Z','').split('l')
    start = np.array([int(o) for o in z[0][1:].split(',')])
    moves = np.array([[0,0]] + [[int(i) for i in o.split(',')] for o in z[1:]])
    return moves.cumsum(axis=0) + start

def get_muggiest_day(coords_set):
    df = pd.DataFrame([coords[:,1] for coords in coords_set]).transpose()
    return df.sort_values([2,0,4,3,1,5]).index[0]

def interpret_coords(coords_set):
    min_value = min([coords[:,1].min() for coords in coords_set])
    max_value = max([coords[:,1].max() for coords in coords_set])
    for i in range(len(coords_set)):
        coords_set[i] = np.flip(coords_set[i][365:],axis=0)
        
    res = dict()
    
    res['top_values'] = [(max_value - coords[:,1].min()) / (max_value - min_value) for coords in coords_set]
    
    muggiest_day = get_muggiest_day(coords_set)
    res['muggiest_day'] = muggiest_day
    
    muggiest_day_values = [coords[muggiest_day,1] for coords in coords_set]
    res['muggiest_day_values'] = [(max_value - x) / (max_value - min_value) for x in muggiest_day_values]
    
    return res
    
def process_weatherspark(url, sleep_time=1):
    res = dict()
    time.sleep(sleep_time)
    response = requests.get(url)
    response.encoding = 'utf-8'
    page = response.text
    soup = BeautifulSoup(page)
    
    sidebar = soup.find('div',{'id':'Sidebar-Container'})
    res['name'] = sidebar.find('h4').get_text(strip=True)
    res['parents'] = [a.get_text(strip=True) for a in sidebar.find_all('a', recursive=False)]
    
    svg = soup.find('a', {'id':'Figures-Humidity'}).findNextSibling().find('svg')
    paths = svg.find_all('path')
    coords_set = [convert_path_to_coords(path) for path in paths[:6]]
    res['from_chart'] = interpret_coords(coords_set)
    res['from_labels'] = np.array(
        [int(text.text.replace('%',''))/100 for text in svg.find_all('text') if (text.get('text-anchor')=='middle') and '%' in text.text]
    ).max()
    return res

def flatten(d):
    res = dict()
    res['city'] = d['name']
    try:
        res['region'] = d['parents'][-2]
    except:
        res['region'] = ''
    res['country'] = d['parents'][-1]
    for i in range(6):
        res['top_value_{}'.format(i)] = d['from_chart']['top_values'][i]
    for i in range(6):
        res['muggiest_day_value_{}'.format(i)] = d['from_chart']['muggiest_day_values'][i]
    res['label_value'] = d['from_labels']
    res['muggiest_day'] = d['from_chart']['muggiest_day']
    return res

def interpret_coords(coords_set, humid_coord):
    min_value = min([coords[:,1].min() for coords in coords_set])
    max_value = max([coords[:,1].max() for coords in coords_set])
    coords = np.flip(humid_coord[365:],axis=0)
    values = [(max_value - x) / (max_value - min_value) for x in coords[:,1]]
    return values

def calculate_total_weather_time(humid_days):

    # Summing the percentages of all humid days
    total_humid_time = sum(humid_days) 

    # Total time humid or above (as a percentage of a year) 
    total_humid_time_percentage = (total_humid_time / len(humid_days)) * 100
    
    return total_humid_time_percentage

# %%
def save_page(soup, url, folder="/Users/anna.zemit/Desktop/Programming/2024/6. The Global and American Cities With the Driest Air/saved_pages/"):
    
    # Create the folder if it doesn't exist
    if not os.path.exists(folder):
        os.makedirs(folder)

    # Create a file name based on the URL
    file_name = os.path.join(folder, url.replace("://", "_").replace("/", "_").replace(".", "_") + ".html")

    # Open the file in write mode
    with open(file_name, "w", encoding="utf-8") as file:
        # Write the HTML content to the file
        file.write(str(soup))

# %% [markdown]
# ## Experiment

# %%
url = 'https://weatherspark.com' + '/y/143809/Average-Weather-in-Tokyo-Japan-Year-Round'

# %%
res = dict()

# %%
response = requests.get(url)
response.encoding = 'utf-8'
time.sleep(5)
page = response.text
soup = BeautifulSoup(page)
    
sidebar = soup.find('div',{'id':'Sidebar-Container'})
res['name'] = sidebar.find('h4').get_text(strip=True)
res['parents'] = [a.get_text(strip=True) for a in sidebar.find_all('a', recursive=False)]
    
svg = soup.find('a', {'id':'Figures-Humidity'}).findNextSibling().find('svg')
paths = svg.find_all('path')
coords_set = [convert_path_to_coords(path) for path in paths[:6]]

# %%
miserable_days = calculate_total_humid_time(interpret_humid(coords_set, coords_set[0]))
miserable_days
# Out:
# 1.4352337036260754

# %%
oppressive_days = calculate_total_humid_time(interpret_humid(coords_set, coords_set[1]))
oppressive_days
# Out:
# 12.407776147558167

# %%
muggy_days = calculate_total_humid_time(interpret_humid(coords_set, coords_set[2]))
muggy_days
# Out:
# 21.912282540347945

# %%
humid_days = calculate_total_humid_time(interpret_humid(coords_set, coords_set[3]))
humid_days
# Out:
# 31.43963529658353

# %%
comfortable_days = calculate_total_humid_time(interpret_humid(coords_set, coords_set[4]))
comfortable_days
# Out:
# 40.55963110459026

# %%
calculate_total_humid_time(interpret_humid(coords_set, coords_set[5]))
# Out:
# 99.72353804233907

# %%
coords_set_1 = coords_set[0]
coords_set_2 = coords_set[1]
coords_set_3 = coords_set[2]
coords_set_4 = coords_set[3]
coords_set_5 = coords_set[4]
coords_set_6 = coords_set[5]

# %%
# Create a list of colors for each line
colors = ['red', 'pink', 'orange', 'yellow', 'green', 'grey']

# Plot each line with a different color
plt.figure(figsize=(8, 6))  # Adjust figure size if needed

for i, coords_set in enumerate([coords_set_1, coords_set_2, coords_set_3, coords_set_4, coords_set_5, coords_set_6]):
    x, y = zip(*coords_set)
    plt.plot(x, y, label=f'Line {i + 1}', color=colors[i])

# Invert the y-axis
plt.gca().invert_yaxis()

# Add labels, legend, and title
plt.legend()
plt.title('Humidity Comfort Levels in Tokyo')

# Show the plot
plt.show()

# %%
# % of dry days:
calculate_total_humid_time(interpret_humid(coords_set, coords_set[5])) - comfortable_days
# Out:
# 59.16390693774881

# %%
# Convert %’s into “dry days”:
365 * 0.5916390693774881
# Out:
# 215.94826032278317

# %% [markdown]
# ## Scraper

# %% [markdown]
# ### World

# %%
for index, row in major_places_world[18:].iterrows(): 
    
    if pd.isna(row['dry_days']):
        url = 'https://weatherspark.com' + row['major_place_link']
        json_name = row['major_place_name']
        res = dict()

        try: 
            response = requests.get(url)
            response.encoding = 'utf-8'
            time.sleep(5)
            page = response.text
            soup = BeautifulSoup(page)
            save_page(soup, url)

            sidebar = soup.find('div',{'id':'Sidebar-Container'})
            res['name'] = sidebar.find('h4').get_text(strip=True)
            res['parents'] = [a.get_text(strip=True) for a in sidebar.find_all('a', recursive=False)]

            svg = soup.find('a', {'id':'Figures-Humidity'}).findNextSibling().find('svg')
            paths = svg.find_all('path')
            coords_set = [convert_path_to_coords(path) for path in paths[:6]]

            # Humid comfortable percentages
            comfortable_days = calculate_total_weather_time(interpret_coords(coords_set, coords_set[4]))

            dry_time = calculate_total_weather_time(interpret_coords(coords_set, coords_set[5])) - comfortable_days

            dry_days = 365 * (dry_time/100)

            major_places_world.at[index, 'dry_days'] = dry_days

            major_places_world.to_csv('scraped_major_places_world.csv', index=False)

            print('Done ', index)

        except:

            print('Exception ', url)
# Out:
# Done  5958
# Done  11014
# Done  12144
# Done  13009
# Done  13072
# Done  13765
# Done  13766
# Done  13816
# Done  13817
# Done  13818
# Done  13825
# Done  13883
# Done  13884
# Done  13942
# Done  13965
# Exception  https://weatherspark.com/countries/AU/01
# Exception  https://weatherspark.com/countries/AU/02
# Exception  https://weatherspark.com/countries/AU/03
# Exception  https://weatherspark.com/countries/AU/04
# Exception  https://weatherspark.com/countries/AU/05
# Exception  https://weatherspark.com/countries/AU/06
# Exception  https://weatherspark.com/countries/AU/07
# Exception  https://weatherspark.com/countries/AU/08
# Done  14078
# Done  14131
# Done  14132
# Done  14139
# Done  14159
# Done  14161
# Done  14188
# Done  14189
# Done  14276
# Done  14277

# %%
major_places_world.dropna(subset=['dry_days'], inplace=True)

# %%
major_places_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14657 entries, 0 to 14664
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   major_place_name  14657 non-null  object
#  1   major_place_link  14657 non-null  object
#  2   permalink         14657 non-null  object
#  3   Country           14657 non-null  object
#  4   Continent         14657 non-null  object
#  5   Abbreviation      14514 non-null  object
#  6   dry_days          14657 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 916.1+ KB

# %%
major_places_world['Country'] = major_places_world['Country'].apply(lambda x: x.title())

# %%
major_places_world = pd.read_csv('Raw Data World.csv')

# %%
major_places_world
# Out:
#                      Continent  Country  dry_days major_place_name  \
# 0                 South America    Peru     365.0         Ayacucho
# 1                 South America    Peru     365.0          Ayaviri
# 2                 South America    Peru     365.0   Cerro de Pasco
# 3                 South America    Peru     365.0      Chaupimarca
# 4                 South America    Peru     365.0            Cusco
# ...                         ...     ...       ...              ...
# 14652  Rest of Asia and Oceania   Nauru       0.0            Baiti
# 14653  Rest of Asia and Oceania   Nauru       0.0             Ijuw
# 14654  Rest of Asia and Oceania   Nauru       0.0            Uaboe
# 14655  Rest of Asia and Oceania   Nauru       0.0           Yangor
# 14656  Rest of Asia and Oceania   Nauru       0.0            Yaren
#
#                                         major_place_link  \
# 0      /y/23257/Average-Weather-in-Ayacucho-Peru-Year...
# 1      /y/26623/Average-Weather-in-Ayaviri-Peru-Year-...
# 2      /y/21357/Average-Weather-in-Cerro-de-Pasco-Per...
# 3      /y/21356/Average-Weather-in-Chaupimarca-Peru-Y...
# 4      /y/25926/Average-Weather-in-Cusco-Peru-Year-Round
# ...                                                  ...
# 14652  /y/144762/Average-Weather-in-Baiti-Nauru-Year-...
# 14653  /y/144763/Average-Weather-in-Ijuw-Nauru-Year-R...
# 14654  /y/144761/Average-Weather-in-Uaboe-Nauru-Year-...
# 14655  /y/144760/Average-Weather-in-Yangor-Nauru-Year...
# 14656  /y/144766/Average-Weather-in-Yaren-Nauru-Year-...
#
#                                    permalink Abbreviation
# 0      https://weatherspark.com/countries/PE           PE
# 1      https://weatherspark.com/countries/PE           PE
# 2      https://weatherspark.com/countries/PE           PE
# 3      https://weatherspark.com/countries/PE           PE
# 4      https://weatherspark.com/countries/PE           PE
# ...                                      ...          ...
# 14652  https://weatherspark.com/countries/NR           NR
# 14653  https://weatherspark.com/countries/NR           NR
# 14654  https://weatherspark.com/countries/NR           NR
# 14655  https://weatherspark.com/countries/NR           NR
# 14656  https://weatherspark.com/countries/NR           NR
#
# [14657 rows x 7 columns]

# %% [markdown]
# ### US

# %%
for index, row in major_places_us[1:].iterrows(): 
    
    if pd.isna(row['dry_days']):
    
        url = 'https://weatherspark.com' + row['major_place_link']
        json_name = row['major_place_name']
        res = dict()

        try: 
            response = requests.get(url)
            response.encoding = 'utf-8'
            time.sleep(5)
            page = response.text
            soup = BeautifulSoup(page)
            save_page(soup, url)

            sidebar = soup.find('div',{'id':'Sidebar-Container'})
            res['name'] = sidebar.find('h4').get_text(strip=True)
            res['parents'] = [a.get_text(strip=True) for a in sidebar.find_all('a', recursive=False)]

            svg = soup.find('a', {'id':'Figures-Humidity'}).findNextSibling().find('svg')
            paths = svg.find_all('path')
            coords_set = [convert_path_to_coords(path) for path in paths[:6]]

            # Humid comfortable percentages
            comfortable_days = calculate_total_weather_time(interpret_coords(coords_set, coords_set[4]))

            dry_time = calculate_total_weather_time(interpret_coords(coords_set, coords_set[5])) - comfortable_days

            dry_days = 365 * (dry_time/100)

            major_places_us.at[index, 'dry_days'] = dry_days

            major_places_us.to_csv('scraped_major_places_us.csv', index=False)

            print('Done ', index)

        except:

            print('Exception ', url)
# Out:
# Exception  https://weatherspark.com/countries/AU/01
# Exception  https://weatherspark.com/countries/AU/02
# Exception  https://weatherspark.com/countries/AU/03
# Exception  https://weatherspark.com/countries/AU/04
# Exception  https://weatherspark.com/countries/AU/05
# Exception  https://weatherspark.com/countries/AU/06
# Exception  https://weatherspark.com/countries/AU/07
# Exception  https://weatherspark.com/countries/AU/08
# Done  1290
# Done  1291
# Done  1319
# Done  3464
# Done  3472
# Done  3473

# %%
major_places_us.dropna(subset=['dry_days'], inplace=True)

# %%
major_places_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5175 entries, 0 to 5182
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   permalink         5175 non-null   object
#  1   major_place_link  5175 non-null   object
#  2   major_place_name  5175 non-null   object
#  3   State             5175 non-null   object
#  4   Postal            5175 non-null   object
#  5   dry_days          5175 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 283.0+ KB

# %%
major_places_us = pd.read_csv('Raw Data States.csv')

# %%
major_places_us
# Out:
#          State                 major_place_name  dry_days  \
# 0       Alaska                    Sutton-Alpine    364.96
# 1       Alaska                    Lazy Mountain    364.94
# 2     Colorado                            Aspen    364.90
# 3       Alaska                           Barrow    364.87
# 4     Colorado                       Estes Park    364.85
# ...        ...                              ...       ...
# 5170    Hawaii  Marine Corps Base Hawaii - MCBH      4.55
# 5171    Hawaii                  Waimānalo Beach      4.51
# 5172    Hawaii                           Kapaau      4.46
# 5173    Hawaii                             Hāwī      4.31
# 5174    Hawaii                             Hana      3.13
#
#                                      permalink  \
# 0     https://weatherspark.com/countries/US/AK
# 1     https://weatherspark.com/countries/US/AK
# 2     https://weatherspark.com/countries/US/CO
# 3     https://weatherspark.com/countries/US/AK
# 4     https://weatherspark.com/countries/US/CO
# ...                                        ...
# 5170  https://weatherspark.com/countries/US/HI
# 5171  https://weatherspark.com/countries/US/HI
# 5172  https://weatherspark.com/countries/US/HI
# 5173  https://weatherspark.com/countries/US/HI
# 5174  https://weatherspark.com/countries/US/HI
#
#                                        major_place_link Postal
# 0     /y/264/Average-Weather-in-Sutton-Alpine-Alaska...     AK
# 1     /y/265/Average-Weather-in-Lazy-Mountain-Alaska...     AK
# 2     /y/3360/Average-Weather-in-Aspen-Colorado-Unit...     CO
# 3     /y/163/Average-Weather-in-Barrow-Alaska-United...     AK
# 4     /y/3564/Average-Weather-in-Estes-Park-Colorado...     CO
# ...                                                 ...    ...
# 5170  /y/118/Average-Weather-in-Marine-Corps-Base-Ha...     HI
# 5171  /y/133/Average-Weather-in-Waim%C4%81nalo-Beach...     HI
# 5172  /y/187/Average-Weather-in-Kapaau-Hawaii-United...     HI
# 5173  /y/190/Average-Weather-in-H%C4%81w%C4%AB-Hawai...     HI
# 5174  /y/189/Average-Weather-in-Hana-Hawaii-United-S...     HI
#
# [5175 rows x 6 columns]

# %% [markdown]
# # Finalise the data into tabs

# %% [markdown]
# ## World Map

# %% [markdown]
# Isolate the city with the most dry days in every country.

# %%
world_map = major_places_world.loc[major_places_world.groupby('Country')['dry_days'].idxmax()]

# %%
world_map.drop(columns=['permalink', 'Abbreviation'], inplace=True)

# %%
world_map
# Out:
#                        Continent               Country    dry_days  \
# 14     Middle East & Central Asia          Afghanistan  365.000000
# 2364                       Europe              Albania  326.990000
# 382                       Africa               Algeria  361.510000
# 6584                      Africa                Angola  247.780000
# 13644               North America  Antigua And Barbuda    0.011891
# ...                           ...                  ...         ...
# 9462     Rest of Asia and Oceania              Vietnam  131.130000
# 1621                       Europe               Wales   336.810000
# 651    Middle East & Central Asia                Yemen  355.940000
# 7853                      Africa                Zambia  206.890000
# 6788                      Africa              Zimbabwe  241.780000
#
#       major_place_name                                   major_place_link
# 14           Ashkāsham  /y/107194/Average-Weather-in-Ashk%C4%81sham-Af...
# 2364            Ersekë  /y/85525/Average-Weather-in-Ersek%C3%AB-Albani...
# 382        Tamanrasset  /y/51498/Average-Weather-in-Tamanrasset-Algeri...
# 6584           Lubango  /y/74188/Average-Weather-in-Lubango-Angola-Yea...
# 13644       All Saints  /y/28731/Average-Weather-in-All-Saints-Antigua...
# ...                ...                                                ...
# 9462             Sa Pá  /y/114832/Average-Weather-in-Sa-P%C3%A1-Vietna...
# 1621           Newtown  /y/37862/Average-Weather-in-Newtown-United-Kin...
# 651              Saḩar  /y/103164/Average-Weather-in-Sa%E1%B8%A9ar-Yem...
# 7853             Choma  /y/92880/Average-Weather-in-Choma-Zambia-Year-...
# 6788          Bulawayo  /y/95282/Average-Weather-in-Bulawayo-Zimbabwe-...
#
# [199 rows x 5 columns]

# %% [markdown]
# ## States Map

# %% [markdown]
# States Map: isolate the city with the most dry days in every state

# %%
states_map = major_places_us.loc[major_places_us.groupby('State')['dry_days'].idxmax()]

# %%
states_map.drop(columns=['permalink', 'Postal'], inplace=True)

# %%
states_map
# Out:
#                      State       major_place_name  dry_days  \
# 4084               Alabama             Fort Payne    207.40
# 0                   Alaska          Sutton-Alpine    364.96
# 421                Arizona                Kayenta    358.20
# 3882              Arkansas         Siloam Springs    221.46
# 409             California              Lancaster    358.43
# 2                 Colorado                  Aspen    364.90
# 1801           Connecticut      Winchester Center    281.34
# 3325              Delaware             Greenville    241.37
# 3544  District of Columbia            Chevy Chase    233.80
# 4787               Florida            Tallahassee    138.66
# 3936               Georgia                 Canton    216.76
# 5040                Hawaii                Volcano     40.49
# 9                    Idaho             Sun Valley    364.68
# 2176              Illinois               Glenview    272.27
# 2095               Indiana                 Auburn    274.25
# 1929                  Iowa            Spirit Lake    278.16
# 1336                Kansas               Goodland    298.64
# 3327              Kentucky           Francisville    241.31
# 4666             Louisiana              Red Chute    162.92
# 1081                 Maine              Madawaska    319.55
# 3077              Maryland             Hagerstown    250.40
# 1611         Massachusetts                Gardner    288.57
# 1087              Michigan              Marquette    318.60
# 1118             Minnesota                Hibbing    314.29
# 4086           Mississippi                  Amory    207.32
# 3117              Missouri               Hannibal    249.42
# 6                  Montana                Big Sky    364.82
# 775               Nebraska                Kimball    344.79
# 15                  Nevada           Cold Springs    364.60
# 1119         New Hampshire                 Berlin    314.22
# 2354            New Jersey           West Milford    268.29
# 10              New Mexico                  Chama    364.68
# 1605              New York            Plattsburgh    288.75
# 3163        North Carolina                  Boone    248.00
# 880           North Dakota                  Beach    337.17
# 2206                  Ohio          Bowling Green    271.50
# 2004              Oklahoma                 Guymon    276.42
# 82                  Oregon  Deschutes River Woods    363.92
# 1651          Pennsylvania            Saint Marys    286.43
# 1810          Rhode Island            Harrisville    281.01
# 4042        South Carolina           Wade Hampton    209.77
# 589           South Dakota                 Custer    354.33
# 3558             Tennessee                  Erwin    233.51
# 1186                 Texas                El Paso    307.76
# 18                    Utah                 Manila    364.55
# 1175               Vermont              Guildhall    308.81
# 3226              Virginia            Brandermill    245.73
# 334             Washington              Sunnyside    359.68
# 2466         West Virginia        Weirton Heights    265.35
# 1250             Wisconsin              Marinette    303.77
# 11                 Wyoming              Marbleton    364.66
#
#                                        major_place_link
# 4084  /y/15100/Average-Weather-in-Fort-Payne-Alabama...
# 0     /y/264/Average-Weather-in-Sutton-Alpine-Alaska...
# 421   /y/2882/Average-Weather-in-Kayenta-Arizona-Uni...
# 3882  /y/9757/Average-Weather-in-Siloam-Springs-Arka...
# 409   /y/1701/Average-Weather-in-Lancaster-Californi...
# 2     /y/3360/Average-Weather-in-Aspen-Colorado-Unit...
# 1801  /y/24751/Average-Weather-in-Winchester-Center-...
# 3325  /y/22750/Average-Weather-in-Greenville-Delawar...
# 3544  /y/20953/Average-Weather-in-Chevy-Chase;-Washi...
# 4787  /y/15552/Average-Weather-in-Tallahassee-Florid...
# 3936  /y/15683/Average-Weather-in-Canton-Georgia-Uni...
# 5040  /y/176/Average-Weather-in-Volcano-Hawaii-Unite...
# 9     /y/2325/Average-Weather-in-Sun-Valley-Idaho-Un...
# 2176  /y/14246/Average-Weather-in-Glenview-Illinois-...
# 2095  /y/15323/Average-Weather-in-Auburn-Indiana-Uni...
# 1929  /y/9506/Average-Weather-in-Spirit-Lake-Iowa-Un...
# 1336  /y/4774/Average-Weather-in-Goodland-Kansas-Uni...
# 3327  /y/15830/Average-Weather-in-Francisville-Kentu...
# 4666  /y/10175/Average-Weather-in-Red-Chute-Louisian...
# 1081  /y/27464/Average-Weather-in-Madawaska-Maine-Un...
# 3077  /y/21082/Average-Weather-in-Hagerstown-Marylan...
# 1611  /y/26227/Average-Weather-in-Gardner-Massachuse...
# 1087  /y/14336/Average-Weather-in-Marquette-Michigan...
# 1118  /y/11122/Average-Weather-in-Hibbing-Minnesota-...
# 4086  /y/13152/Average-Weather-in-Amory-Mississippi-...
# 3117  /y/11481/Average-Weather-in-Hannibal-Missouri-...
# 6     /y/2771/Average-Weather-in-Big-Sky-Montana-Uni...
# 775   /y/4058/Average-Weather-in-Kimball-Nebraska-Un...
# 15    /y/1540/Average-Weather-in-Cold-Springs-Nevada...
# 1119  /y/26442/Average-Weather-in-Berlin-New-Hampshi...
# 2354  /y/23967/Average-Weather-in-West-Milford-New-J...
# 10    /y/3346/Average-Weather-in-Chama-New-Mexico-Un...
# 1605  /y/24980/Average-Weather-in-Plattsburgh-New-Yo...
# 3163  /y/17975/Average-Weather-in-Boone-North-Caroli...
# 880   /y/3775/Average-Weather-in-Beach-North-Dakota-...
# 2206  /y/16470/Average-Weather-in-Bowling-Green-Ohio...
# 2004  /y/4758/Average-Weather-in-Guymon-Oklahoma-Uni...
# 82    /y/1211/Average-Weather-in-Deschutes-River-Woo...
# 1651  /y/20353/Average-Weather-in-Saint-Marys-Pennsy...
# 1810  /y/26150/Average-Weather-in-Harrisville-Rhode-...
# 4042  /y/17101/Average-Weather-in-Wade-Hampton-South...
# 589   /y/4063/Average-Weather-in-Custer-South-Dakota...
# 3558  /y/17165/Average-Weather-in-Erwin-Tennessee-Un...
# 1186  /y/3268/Average-Weather-in-El-Paso-Texas-Unite...
# 18    /y/3015/Average-Weather-in-Manila-Utah-United-...
# 1175  /y/26455/Average-Weather-in-Guildhall-Vermont-...
# 3226  /y/20878/Average-Weather-in-Brandermill-Virgin...
# 334   /y/1395/Average-Weather-in-Sunnyside-Washingto...
# 2466  /y/19045/Average-Weather-in-Weirton-Heights-We...
# 1250  /y/14324/Average-Weather-in-Marinette-Wisconsi...
# 11    /y/2897/Average-Weather-in-Marbleton-Wyoming-U...

# %% [markdown]
# ## US

# %% [markdown]
# US: isolate the 20 cities with the most dry days in the U.S.

# %%
us = major_places_us.sort_values(by='dry_days', ascending=False).head(20)

# %%
us.drop(columns=['permalink', 'Postal'], inplace=True)

# %%
us
# Out:
#          State     major_place_name  dry_days  \
# 0       Alaska        Sutton-Alpine    364.96
# 1       Alaska        Lazy Mountain    364.94
# 2     Colorado                Aspen    364.90
# 3       Alaska               Barrow    364.87
# 4     Colorado           Estes Park    364.85
# 5     Colorado              Edwards    364.83
# 6      Montana              Big Sky    364.82
# 7       Alaska          Fritz Creek    364.82
# 8       Alaska        Diamond Ridge    364.76
# 9        Idaho           Sun Valley    364.68
# 10  New Mexico                Chama    364.68
# 11     Wyoming            Marbleton    364.66
# 12       Idaho              Ketchum    364.64
# 13      Alaska          Prudhoe Bay    364.64
# 14  New Mexico               Questa    364.63
# 16     Montana     West Yellowstone    364.60
# 15      Nevada         Cold Springs    364.60
# 17      Nevada  Topaz Ranch Estates    364.58
# 18        Utah               Manila    364.55
# 19     Wyoming   North Rock Springs    364.55
#
#                                      major_place_link
# 0   /y/264/Average-Weather-in-Sutton-Alpine-Alaska...
# 1   /y/265/Average-Weather-in-Lazy-Mountain-Alaska...
# 2   /y/3360/Average-Weather-in-Aspen-Colorado-Unit...
# 3   /y/163/Average-Weather-in-Barrow-Alaska-United...
# 4   /y/3564/Average-Weather-in-Estes-Park-Colorado...
# 5   /y/3364/Average-Weather-in-Edwards-Colorado-Un...
# 6   /y/2771/Average-Weather-in-Big-Sky-Montana-Uni...
# 7   /y/211/Average-Weather-in-Fritz-Creek-Alaska-U...
# 8   /y/210/Average-Weather-in-Diamond-Ridge-Alaska...
# 9   /y/2325/Average-Weather-in-Sun-Valley-Idaho-Un...
# 10  /y/3346/Average-Weather-in-Chama-New-Mexico-Un...
# 11  /y/2897/Average-Weather-in-Marbleton-Wyoming-U...
# 12  /y/2324/Average-Weather-in-Ketchum-Idaho-Unite...
# 13  /y/268/Average-Weather-in-Prudhoe-Bay-Alaska-U...
# 14  /y/3510/Average-Weather-in-Questa-New-Mexico-U...
# 16  /y/2769/Average-Weather-in-West-Yellowstone-Mo...
# 15  /y/1540/Average-Weather-in-Cold-Springs-Nevada...
# 17  /y/1538/Average-Weather-in-Topaz-Ranch-Estates...
# 18  /y/3015/Average-Weather-in-Manila-Utah-United-...
# 19  /y/3019/Average-Weather-in-North-Rock-Springs-...

# %% [markdown]
# ## North America

# %% [markdown]
# North America: the 10 cities with the most dry days in this continent. Country column.

# %%
north_america = major_places_world[major_places_world['Continent '] == 'North America'].reset_index(drop=True)
north_america = north_america.sort_values(by='dry_days', ascending=False).head(10)

# %%
north_america.drop(columns=['permalink', 'Abbreviation', 'Continent '], inplace=True)

# %%
north_america
# Out:
#                     Country  dry_days     major_place_name  \
# 0  United States Of America    363.91                 Reno
# 1                    Mexico    361.40           Cuajimalpa
# 2  United States Of America    360.93            Anchorage
# 3                    Canada    360.09        Prince George
# 4                    Canada    359.86              Calgary
# 5                    Mexico    359.61       Nicolás Romero
# 6                    Mexico    359.44  Ciudad López Mateos
# 7                    Mexico    357.42  Naucalpan de Juárez
# 8                    Mexico    356.95           Buenavista
# 9                    Canada    356.88             Kamloops
#
#                                     major_place_link
# 0  /y/1548/Average-Weather-in-Reno-Nevada-United-...
# 1  /y/5668/Average-Weather-in-Cuajimalpa-Mexico-Y...
# 2  /y/252/Average-Weather-in-Anchorage-Alaska-Uni...
# 3  /y/1016/Average-Weather-in-Prince-George-Canad...
# 4  /y/2349/Average-Weather-in-Calgary-Canada-Year...
# 5  /y/5641/Average-Weather-in-Nicol%C3%A1s-Romero...
# 6  /y/5685/Average-Weather-in-Ciudad-L%C3%B3pez-M...
# 7  /y/5642/Average-Weather-in-Naucalpan-de-Ju%C3%...
# 8  /y/5835/Average-Weather-in-Buenavista-Mexico-Y...
# 9  /y/1421/Average-Weather-in-Kamloops-Canada-Yea...

# %% [markdown]
# ## Europe

# %% [markdown]
# Europe: the 10 cities with the most dry days in this continent. Country column.

# %%
europe = major_places_world[major_places_world['Continent '] == 'Europe'].reset_index(drop=True)
europe = europe.sort_values(by='dry_days', ascending=False).head(10)
europe.drop(columns=['permalink', 'Abbreviation', 'Continent '], inplace=True)
europe
# Out:
#    Country  dry_days major_place_name  \
# 0  Iceland    364.86           Laugar
# 1  Iceland    364.83       Ísafjörður
# 2  Iceland    364.74    Neskaupstaður
# 3  Iceland    364.73   Vestmannaeyjar
# 4  Iceland    364.72     Sauðárkrókur
# 5  Iceland    364.71         Ólafsvík
# 6  Iceland    364.67       Hveragerði
# 7  Iceland    364.66      Þorlákshöfn
# 8  Iceland    364.65          Húsavík
# 9  Iceland    364.65        Borgarnes
#
#                                     major_place_link
# 0  /y/31553/Average-Weather-in-Laugar-Iceland-Yea...
# 1  /y/31487/Average-Weather-in-%C3%8Dsafj%C3%B6r%...
# 2  /y/31824/Average-Weather-in-Neskaupsta%C3%B0ur...
# 3  /y/31509/Average-Weather-in-Vestmannaeyjar-Ice...
# 4  /y/31511/Average-Weather-in-Sau%C3%B0%C3%A1rkr...
# 5  /y/31486/Average-Weather-in-%C3%93lafsv%C3%ADk...
# 6  /y/31505/Average-Weather-in-Hverager%C3%B0i-Ic...
# 7  /y/31500/Average-Weather-in-%C3%9Eorl%C3%A1ksh...
# 8  /y/31554/Average-Weather-in-H%C3%BAsav%C3%ADk-...
# 9  /y/31508/Average-Weather-in-Borgarnes-Iceland-...

# %% [markdown]
# ## South America

# %% [markdown]
# South America:  the 10 cities with the most dry days in this continent. Country column.

# %%
south_america = major_places_world[major_places_world['Continent '] == 'South America'].reset_index(drop=True)
south_america = south_america.sort_values(by='dry_days', ascending=False).head(10)
south_america.drop(columns=['permalink', 'Abbreviation', 'Continent '], inplace=True)
south_america
# Out:
#     Country  dry_days major_place_name  \
# 0      Peru     365.0         Ayacucho
# 24  Bolivia     365.0      Huachacalla
# 26  Bolivia     365.0          Huarina
# 27  Bolivia     365.0        Huatajata
# 28  Bolivia     365.0           La Paz
# 29  Bolivia     365.0       Lahuachaca
# 30  Bolivia     365.0        Llallagua
# 31  Bolivia     365.0     Machacamarca
# 32  Bolivia     365.0          Maragua
# 33  Bolivia     365.0       Patacamaya
#
#                                      major_place_link
# 0   /y/23257/Average-Weather-in-Ayacucho-Peru-Year...
# 24  /y/27341/Average-Weather-in-Huachacalla-Bolivi...
# 26  /y/27350/Average-Weather-in-Huarina-Bolivia-Ye...
# 27  /y/27349/Average-Weather-in-Huatajata-Bolivia-...
# 28  /y/27348/Average-Weather-in-La-Paz-Bolivia-Yea...
# 29  /y/27513/Average-Weather-in-Lahuachaca-Bolivia...
# 30  /y/27666/Average-Weather-in-Llallagua-Bolivia-...
# 31  /y/27509/Average-Weather-in-Machacamarca-Boliv...
# 32  /y/27975/Average-Weather-in-Maragua-Bolivia-Ye...
# 33  /y/27511/Average-Weather-in-Patacamaya-Bolivia...

# %% [markdown]
# ## Asia

# %% [markdown]
# Asia: the 10 cities with the most dry days in this continent. Country column.

# %%
asia = major_places_world[major_places_world['Continent '] == 'Middle East & Central Asia'].reset_index(drop=True)
asia = asia.sort_values(by='dry_days', ascending=False).head(10)
asia.drop(columns=['permalink', 'Abbreviation', 'Continent '], inplace=True)
asia
# Out:
#        Country  dry_days major_place_name  \
# 0  Afghanistan     365.0        Ashkāsham
# 6   Kyrgyzstan     365.0          Baetovo
# 9   Tajikistan     365.0          Murghob
# 8   Kyrgyzstan     365.0            Naryn
# 7   Kyrgyzstan     365.0           Chayek
# 1  Afghanistan     365.0       Fayrōz Kōh
# 5   Kyrgyzstan     365.0         At-Bashi
# 2  Afghanistan     365.0             Jurm
# 4  Afghanistan     365.0          Shahrak
# 3  Afghanistan     365.0          Khandūd
#
#                                     major_place_link
# 0  /y/107194/Average-Weather-in-Ashk%C4%81sham-Af...
# 6  /y/108093/Average-Weather-in-Baetovo-Kyrgyzsta...
# 9  /y/107776/Average-Weather-in-Murghob-Tajikista...
# 8  /y/108438/Average-Weather-in-Naryn-Kyrgyzstan-...
# 7  /y/108092/Average-Weather-in-Chayek-Kyrgyzstan...
# 1  /y/106309/Average-Weather-in-Fayr%C5%8Dz-K%C5%...
# 5  /y/108439/Average-Weather-in-At-Bashi-Kyrgyzst...
# 2  /y/107031/Average-Weather-in-Jurm-Afghanistan-...
# 4  /y/106248/Average-Weather-in-Shahrak-Afghanist...
# 3  /y/107428/Average-Weather-in-Khand%C5%ABd-Afgh...

# %% [markdown]
# ## Oceania

# %% [markdown]
# Oceania: the 10 cities with the most dry days in this continent. Country column.

# %%
oceania = major_places_world[major_places_world['Continent '] == 'Rest of Asia and Oceania'].reset_index(drop=True)
oceania = oceania.sort_values(by='dry_days', ascending=False).head(10)
oceania.drop(columns=['permalink', 'Abbreviation', 'Continent '], inplace=True)
oceania
# Out:
#     Country  dry_days major_place_name  \
# 0  Mongolia    365.00             Duut
# 4  Mongolia    365.00          Tsenher
# 5  Mongolia    365.00       Ulaan Khat
# 1  Mongolia    365.00        Jargalant
# 3  Mongolia    365.00            Tolbo
# 2  Mongolia    365.00         Rashaant
# 6  Mongolia    364.99        Chihertey
# 7  Mongolia    364.99            Uujim
# 8  Mongolia    364.98      Ulaantolgoy
# 9  Mongolia    364.98          Höshööt
#
#                                     major_place_link
# 0  /y/112029/Average-Weather-in-Duut-Mongolia-Yea...
# 4  /y/112123/Average-Weather-in-Tsenher-Mongolia-...
# 5  /y/111818/Average-Weather-in-Ulaan-Khat-Mongol...
# 1  /y/112027/Average-Weather-in-Jargalant-Mongoli...
# 3  /y/111937/Average-Weather-in-Tolbo-Mongolia-Ye...
# 2  /y/111936/Average-Weather-in-Rashaant-Mongolia...
# 6  /y/111825/Average-Weather-in-Chihertey-Mongoli...
# 7  /y/111822/Average-Weather-in-Uujim-Mongolia-Ye...
# 8  /y/112122/Average-Weather-in-Ulaantolgoy-Mongo...
# 9  /y/111824/Average-Weather-in-H%C3%B6sh%C3%B6%C...

# %% [markdown]
# ## Africa

# %% [markdown]
# Africa:  the 10 cities with the most dry days in this continent. Country column.

# %%
africa = major_places_world[major_places_world['Continent '] == 'Africa '].reset_index(drop=True)
africa = africa.sort_values(by='dry_days', ascending=False).head(10)
africa.drop(columns=['permalink', 'Abbreviation', 'Continent '], inplace=True)
africa
# Out:
#     Country  dry_days major_place_name  \
# 0      Chad    364.48            Aozou
# 1      Chad    364.20           Bardaï
# 2     Libya    363.77          Al Jawf
# 3     Libya    363.77           At Tāj
# 4     Libya    363.71        Al Qaţrūn
# 5  Ethiopia    363.53             Goba
# 6     Egypt    362.47      Al Khārijah
# 7   Morocco    361.66          Tinghir
# 8   Algeria    361.51      Tamanrasset
# 9   Algeria    360.58        El Bayadh
#
#                                     major_place_link
# 0  /y/81959/Average-Weather-in-Aozou-Chad-Year-Round
# 1  /y/81958/Average-Weather-in-Barda%C3%AF-Chad-Y...
# 2  /y/89166/Average-Weather-in-Al-Jawf-Libya-Year...
# 3  /y/89165/Average-Weather-in-At-T%C4%81j-Libya-...
# 4  /y/76267/Average-Weather-in-Al-Qa%C5%A3r%C5%AB...
# 5  /y/101145/Average-Weather-in-Goba-Ethiopia-Yea...
# 6  /y/96408/Average-Weather-in-Al-Kh%C4%81rijah-E...
# 7  /y/34028/Average-Weather-in-Tinghir-Morocco-Ye...
# 8  /y/51498/Average-Weather-in-Tamanrasset-Algeri...
# 9  /y/45818/Average-Weather-in-El-Bayadh-Algeria-...

# %% [markdown]
# # Create an Excel file

# %%
# Create an Excel writer object

writer = pd.ExcelWriter('The Global and American Cities With the Driest Air.xlsx')

# %%
# Save each DataFrame to a separate sheet in the Excel file

world_map.to_excel(writer, sheet_name='World Map', index=False)
states_map.to_excel(writer, sheet_name='States Map', index=False)
us.to_excel(writer, sheet_name='US', index=False)
north_america.to_excel(writer, sheet_name='North America', index=False)
south_america.to_excel(writer, sheet_name='South America', index=False)
europe.to_excel(writer, sheet_name='Europe', index=False)
asia.to_excel(writer, sheet_name='Middle East & Central Asia', index=False)
oceania.to_excel(writer, sheet_name='Rest of Asia & Oceania', index=False)
africa.to_excel(writer, sheet_name='Africa', index=False)
major_places_world.to_excel(writer, sheet_name='Raw Data World', index=False)
major_places_us.to_excel(writer, sheet_name='Raw Data States', index=False)

# %%
# Save the Excel file
writer.save()
