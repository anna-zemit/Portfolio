# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json
import os
import time
import random

# %% [markdown]
# # Read scraped data

# %% [markdown]
# ## Listings

# %%
data = pd.read_csv('data.csv')
data
# Out:
#       locationId                           name  \
# 0        2556749              Cafe Bella Coffee
# 1       12361344                 Coffee Central
# 2         498652                       Perugino
# 3        2343459                  Vero Espresso
# 4        1014118                  Espresso Roma
# ...          ...                            ...
# 4382    27113108      Grizzly Bean Coffee House
# 4383    10507418  Classic Rock Coffee & Kitchen
# 4384     4824290          Cappuccino On Collins
# 4385     7359734              The Bean & Bakery
# 4386    17550308              Revelstoke Coffee
#
#                                                     url  \
# 0     /Restaurant_Review-g47177-d2556749-Reviews-Caf...
# 1     /Restaurant_Review-g44028-d12361344-Reviews-Co...
# 2     /Restaurant_Review-g51862-d498652-Reviews-Peru...
# 3     /Restaurant_Review-g51862-d2343459-Reviews-Ver...
# 4     /Restaurant_Review-g51862-d1014118-Reviews-Esp...
# ...                                                 ...
# 4382  /Restaurant_Review-g29948-d27113108-Reviews-Gr...
# 4383  /Restaurant_Review-g49882-d10507418-Reviews-Cl...
# 4384  /Restaurant_Review-g49882-d4824290-Reviews-Cap...
# 4385  /Restaurant_Review-g46052-d7359734-Reviews-The...
# 4386  /Restaurant_Review-g46052-d17550308-Reviews-Re...
#
#                                 types  reviews        City          State
# 0     ['Coffee & Tea', 'Quick Bites']       37  Rio Rancho     New Mexico
# 1                    ['Coffee & Tea']        2   Southaven    Mississippi
# 2                    ['Coffee & Tea']       67      Eugene         Oregon
# 3     ['Coffee & Tea', 'Quick Bites']       54      Eugene         Oregon
# 4     ['Coffee & Tea', 'Quick Bites']       21      Eugene         Oregon
# ...                               ...      ...         ...            ...
# 4382                 ['Coffee & Tea']        1  Youngstown           Ohio
# 4383                 ['Coffee & Tea']        3      Mandan   North Dakota
# 4384                 ['Coffee & Tea']        3      Mandan   North Dakota
# 4385  ['Coffee & Tea', 'Quick Bites']       21     Concord  New Hampshire
# 4386                 ['Coffee & Tea']        9     Concord  New Hampshire
#
# [4387 rows x 7 columns]

# %% [markdown]
# ## Shops

# %%
ratings_breakdowns = pd.DataFrame(columns=['locationId', 'Excellent', 'Very_Good', 
                                           'Average', 'Poor', 'Terrible'])

json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

# %%
for file in json_files:
    with open(os.path.join(folder_path, file), 'r') as json_file:
        json_data = json.load(json_file)
        locationId = json_data[0]['data']['locations'][0]['locationId']
        Excellent = json_data[0]['data']['locations'][0]['reviewAggregations']['ratingCounts'][4]
        Very_Good = json_data[0]['data']['locations'][0]['reviewAggregations']['ratingCounts'][3]
        Average = json_data[0]['data']['locations'][0]['reviewAggregations']['ratingCounts'][2]
        Poor = json_data[0]['data']['locations'][0]['reviewAggregations']['ratingCounts'][1]
        Terrible = json_data[0]['data']['locations'][0]['reviewAggregations']['ratingCounts'][0]
    
    # Append to the DataFrame
        ratings_breakdowns = ratings_breakdowns.append({
                'locationId': locationId,
                'Excellent': Excellent,
                'Very_Good': Very_Good,
                'Average' : Average,
                'Poor': Poor,
                'Terrible': Terrible
                }, ignore_index=True)

# %%
ratings_breakdowns
# Out:
#      locationId Excellent Very_Good Average Poor Terrible
# 0        870194        23         0       0    0        0
# 1      24961448         1         1       1    0        0
# 2       7255824         8        11       1    0        0
# 3      18936591         7         3       1    1        0
# 4      17463543         7         0       0    0        0
# ...         ...       ...       ...     ...  ...      ...
# 4374   24108785         1         0       0    0        0
# 4375    4892729        24        21      11    3        2
# 4376    4947101         8         1       0    0        0
# 4377   14789744         5         2       0    0        0
# 4378   15092262         0         1       0    0        0
#
# [4379 rows x 6 columns]

# %%
data = data.merge(ratings_breakdowns, on=['locationId'], how='left')

data
# Out:
#      locationId                           name  \
# 0       2556749              Cafe Bella Coffee
# 1      12361344                 Coffee Central
# 2        498652                       Perugino
# 3       2343459                  Vero Espresso
# 4       1014118                  Espresso Roma
# ...         ...                            ...
# 4382   27113108      Grizzly Bean Coffee House
# 4383   10507418  Classic Rock Coffee & Kitchen
# 4384    4824290          Cappuccino On Collins
# 4385    7359734              The Bean & Bakery
# 4386   17550308              Revelstoke Coffee
#
#                                                     url  \
# 0     /Restaurant_Review-g47177-d2556749-Reviews-Caf...
# 1     /Restaurant_Review-g44028-d12361344-Reviews-Co...
# 2     /Restaurant_Review-g51862-d498652-Reviews-Peru...
# 3     /Restaurant_Review-g51862-d2343459-Reviews-Ver...
# 4     /Restaurant_Review-g51862-d1014118-Reviews-Esp...
# ...                                                 ...
# 4382  /Restaurant_Review-g29948-d27113108-Reviews-Gr...
# 4383  /Restaurant_Review-g49882-d10507418-Reviews-Cl...
# 4384  /Restaurant_Review-g49882-d4824290-Reviews-Cap...
# 4385  /Restaurant_Review-g46052-d7359734-Reviews-The...
# 4386  /Restaurant_Review-g46052-d17550308-Reviews-Re...
#
#                                 types  reviews        City          State  \
# 0     ['Coffee & Tea', 'Quick Bites']       37  Rio Rancho     New Mexico
# 1                    ['Coffee & Tea']        2   Southaven    Mississippi
# 2                    ['Coffee & Tea']       67      Eugene         Oregon
# 3     ['Coffee & Tea', 'Quick Bites']       54      Eugene         Oregon
# 4     ['Coffee & Tea', 'Quick Bites']       21      Eugene         Oregon
# ...                               ...      ...         ...            ...
# 4382                 ['Coffee & Tea']        1  Youngstown           Ohio
# 4383                 ['Coffee & Tea']        3      Mandan   North Dakota
# 4384                 ['Coffee & Tea']        3      Mandan   North Dakota
# 4385  ['Coffee & Tea', 'Quick Bites']       21     Concord  New Hampshire
# 4386                 ['Coffee & Tea']        9     Concord  New Hampshire
#
#      Excellent Very_Good Average Poor Terrible
# 0           18         7       3    5        4
# 1            1         0       0    1        0
# 2           41        22       2    2        0
# 3           38        12       4    0        0
# 4           12         7       2    0        0
# ...        ...       ...     ...  ...      ...
# 4382         1         0       0    0        0
# 4383         2         1       0    0        0
# 4384         1         1       1    0        0
# 4385        10        10       0    1        0
# 4386         8         0       0    1        0
#
# [4387 rows x 12 columns]

# %%
len(data.City.unique())
# Out:
# 422

# %% [markdown]
# # Calculate the weighted average score across all independent coffee shops in each city

# %%
# Assign numeric ratings
ratings = {
    'Excellent': 5,
    'Very_Good': 4,
    'Average': 3,
    'Poor': 2,
    'Terrible': 1
}

# %%
data['total_score'] = (data['Excellent'] * ratings['Excellent'] +
                     data['Very_Good'] * ratings['Very_Good'] +
                     data['Average'] * ratings['Average'] +
                     data['Poor'] * ratings['Poor'] +
                     data['Terrible'] * ratings['Terrible'])

# %%
# Calculate the weighted average rating for each shop
data['weighted_average'] = data['total_score'] / data['reviews']

# %%
# Calculate the weighted average across coffee shops in each city and state, and count the number of coffee shops
city_state_weighted_avg = data[~pd.isna(data['weighted_average'])].groupby(['City', 'State']).apply(
    lambda x: pd.Series({
        'city_state_weighted_average': (x['weighted_average'] * x['reviews']).sum() / x['reviews'].sum(),
        'coffee_shops_number': x.shape[0]
    })
).reset_index()

# %%
city_state_weighted_avg.sort_values(by='city_state_weighted_average', ascending=False)
# Out:
#                             City          State  city_state_weighted_average  \
# 167                 Grand Island       Nebraska                     5.000000
# 342                      Rexburg          Idaho                     5.000000
# 291                       Newton  Massachusetts                     5.000000
# 304                       Olathe         Kansas                     5.000000
# 399                  Springfield         Oregon                     5.000000
# ..                           ...            ...                          ...
# 351  Rockville Montgomery County       Maryland                     3.730769
# 219                    Lafayette        Indiana                     3.585366
# 112                    Dickinson   North Dakota                     3.529412
# 390                    Southaven    Mississippi                     3.500000
# 395                   Springdale       Arkansas                     3.333333
#
#      coffee_shops_number
# 167                  2.0
# 342                  1.0
# 291                  2.0
# 304                  3.0
# 399                  2.0
# ..                   ...
# 351                  3.0
# 219                  5.0
# 112                  2.0
# 390                  1.0
# 395                  1.0
#
# [447 rows x 4 columns]

# %%
city_state_weighted_avg['coffee_shops_number'].describe()
# Out:
# count    447.000000
# mean       9.794183
# std       18.874917
# min        1.000000
# 25%        2.000000
# 50%        5.000000
# 75%       10.000000
# max      232.000000
# Name: coffee_shops_number, dtype: float64

# %%
#df = city_state_weighted_avg[city_state_weighted_avg['coffee_shops_number'] >=10]

# %%
#df
# Out:
#                City                 State  city_state_weighted_average  \
# 3       Albuquerque            New Mexico                     4.300518
# 4        Alexandria              Virginia                     4.132841
# 7         Anchorage                Alaska                     4.500000
# 9         Ann Arbor              Michigan                     4.400000
# 13        Arlington              Virginia                     4.399340
# ..              ...                   ...                          ...
# 419           Tulsa              Oklahoma                     4.269231
# 423       Vancouver            Washington                     4.328904
# 424  Virginia Beach              Virginia                     4.417559
# 426   Washington DC  District of Columbia                     4.415318
# 441      Wilmington        North Carolina                     4.642667
#
#      coffee_shops_number
# 3                   30.0
# 4                   12.0
# 7                   25.0
# 9                   11.0
# 13                  10.0
# ..                   ...
# 419                 11.0
# 423                 19.0
# 424                 15.0
# 426                 45.0
# 441                 16.0
#
# [113 rows x 4 columns]

# %%
data.to_csv('data_after_parsing.csv', index=False)
city_state_weighted_avg.to_csv('city_state_weighted_avg.csv', index=False)
