# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup
from google_play_scraper import search
import time
import os
import json

# %% [markdown]
# # Build the seedlist

# %% [markdown]
# ## Communication apps

# %%
communications_apps_urls = pd.read_excel('top_50_communications_apps_for_each_country_urls.xlsx')

# %%
communications_apps_1 = pd.read_excel('Communication Apps Similarweb.xlsx')
communications_apps_2 = pd.read_excel('Communication Apps Similarweb 2.xlsx')
communications_apps = pd.concat([communications_apps_1, communications_apps_2])

# %%
communications_apps = communications_apps_urls.merge(communications_apps, on='similarweb_url', how='left')

# %%
communications_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4800 entries, 0 to 4860
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   similarweb_url  4800 non-null   object
#  1   App             4800 non-null   object
#  2   Publisher       4800 non-null   object
#  3   Category        4800 non-null   object
# dtypes: object(4)
# memory usage: 187.5+ KB

# %%
communications_apps.dropna(subset=['App'], inplace=True)

# %%
communications_apps['App'] = communications_apps['App'].apply(lambda x: x.replace('/', '-'))

# %%
seed_list_communication = communications_apps.drop_duplicates(subset='App')

# %%
seed_list_communication
# Out:
#                                          similarweb_url  \
# 0     https://www.similarweb.com/top-apps/google/alg...
# 1     https://www.similarweb.com/top-apps/google/alg...
# 2     https://www.similarweb.com/top-apps/google/alg...
# 3     https://www.similarweb.com/top-apps/google/alg...
# 4     https://www.similarweb.com/top-apps/google/alg...
# ...                                                 ...
# 4807  https://www.similarweb.com/top-apps/google/pue...
# 4815  https://www.similarweb.com/top-apps/google/ser...
# 4818  https://www.similarweb.com/top-apps/google/ser...
# 4828  https://www.similarweb.com/top-apps/google/ser...
# 4829  https://www.similarweb.com/top-apps/google/ser...
#
#                                  App             Publisher       Category
# 0                 WhatsApp Messenger          WhatsApp LLC  Communication
# 1                          Messenger  Meta Platforms, Inc.  Communication
# 2                           Telegram       Telegram FZ-LLC  Communication
# 3                           Snapchat              Snap Inc  Communication
# 4     Truecaller: Identify Caller ID            Truecaller  Communication
# ...                              ...                   ...            ...
# 4807          Boost Visual Voicemail  DISH Wireless L.L.C.  Communication
# 4815                      Yettel SRB         Yettel Serbia  Communication
# 4818                         Moj mts                   mts  Communication
# 4828                      mts Biznis                   mts  Communication
# 4829                   Moj Globaltel      Globaltel d.o.o.  Communication
#
# [714 rows x 4 columns]

# %% [markdown]
# ## Social apps

# %%
social_apps_urls = pd.read_excel('top_50_social_apps_for_each_country_urls.xlsx')

social_apps_1 = pd.read_excel('Social Apps Similarweb.xlsx')
social_apps_2 = pd.read_excel('Social Apps Similarweb 2.xlsx')
social_apps = pd.concat([social_apps_1, social_apps_2])

social_apps = social_apps_urls.merge(social_apps, on='similarweb_url', how='left')

# %%
social_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4800 entries, 0 to 4861
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   similarweb_url  4800 non-null   object
#  1   App             4800 non-null   object
#  2   Publisher       4800 non-null   object
#  3   Category        4795 non-null   object
# dtypes: object(4)
# memory usage: 187.5+ KB

# %%
social_apps.dropna(subset=['App'], inplace=True)
social_apps['App'] = social_apps['App'].apply(lambda x: x.replace('/', '-'))
seed_list_social = social_apps.drop_duplicates(subset='App')

seed_list_social
# Out:
#                                          similarweb_url  \
# 0     https://www.similarweb.com/top-apps/google/alg...
# 1     https://www.similarweb.com/top-apps/google/alg...
# 2     https://www.similarweb.com/top-apps/google/alg...
# 3     https://www.similarweb.com/top-apps/google/alg...
# 4     https://www.similarweb.com/top-apps/google/alg...
# ...                                                 ...
# 4755  https://www.similarweb.com/top-apps/google/mor...
# 4783  https://www.similarweb.com/top-apps/google/pue...
# 4797  https://www.similarweb.com/top-apps/google/pue...
# 4806  https://www.similarweb.com/top-apps/google/pue...
# 4825  https://www.similarweb.com/top-apps/google/ser...
#
#                                  App  \
# 0                      Facebook Lite
# 1                           Facebook
# 2                             TikTok
# 3            TikTok Lite - Save Data
# 4                          Instagram
# ...                              ...
# 4755     SoulChat-صديق حقيقي و قريبة
# 4783  Best Wishes: For all Occasions
# 4797   SUSH Grow cute virtual animal
# 4806    Fun Live - Online Video Chat
# 4825                        Fortecom
#
#                                       Publisher Category
# 0                          Meta Platforms, Inc.   Social
# 1                          Meta Platforms, Inc.   Social
# 2                              TikTok Pte. Ltd.   Social
# 3                              TikTok Pte. Ltd.   Social
# 4                                     Instagram   Social
# ...                                         ...      ...
# 4755  UNIVERSE ATTRACTION INTERNATIONAL LIMITED   Social
# 4783                              Silver Apps10   Social
# 4797                         Emotion Studio Inc   Social
# 4806                             GLM Technology   Social
# 4825                               HRCloud Inc.   Social
#
# [779 rows x 4 columns]

# %%
# Create an Excel writer object

writer = pd.ExcelWriter('Seedlist The Most Loved Email, Messaging and Social Media Apps by Country.xlsx')

# %%
seed_list_communication.to_excel(writer, sheet_name='communication', index=False)
seed_list_social.to_excel(writer, sheet_name='social', index=False)

# %%
# Save the Excel file
writer.save()

# %% [markdown]
# # Develop the scraper

# %% [markdown]
# ## Communication apps

# %%
folder_path = ''

# %%
# Iterate over the seed list
for _, app in scrape.iterrows():
    app_name = app['App']
    
    try: 
        # Search for the app
        result = search(
            app_name,
            lang="en",  
            country="us",  
            n_hits=10)

        # Save reviews to JSON file
        file_name = f'{app_name}.json'
        file_path = os.path.join(folder_path, file_name)
        with open(file_path, 'w') as json_file:
            json.dump(result, json_file, indent=4)
        time.sleep(3)
        print('Done ', app_name)
    except Exception as e:
        print(f'Exception {app_name}: {e}')
# Out:
# Done  Animated Stickers Maker & GIF
# Done  All Email Login
# Exception Login Mail For HotMail&Outlook: 'NoneType' object is not subscriptable

# %%
json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

# %%
for file in json_files:
    with open(os.path.join(folder_path, file), 'r') as json_file:
        json_data = json.load(json_file)
        
        file_name = file.split('.json')[0]
        appId = json_data[0]['appId']
        
        mask = communications_apps['App'] == file_name
        communications_apps.loc[mask, 'appId'] = appId

# %%
scrape = pd.DataFrame(communications_apps[pd.isna(communications_apps.appId)]['App'].unique(), columns=['App']) #.to_excel('scrape.xlsx', index=False)

# %%
scrape
# Out:
# Empty DataFrame
# Columns: [App]
# Index: []

# %%
communications_apps.loc[communications_apps['App'] == 'Login Mail For HotMail&Outlook', 'appId'] = 'com.emailonline.officemail.amoemail'

# %%
communications_apps.loc[communications_apps['App'] == 'Trulinco: Messaging & Calls', 'appId'] = 'com.inw.trulinco'

# %%
communications_apps.loc[communications_apps['App'] == 'mail.com: Mail app & Cloud', 'appId'] = 'com.mail.mobile.android.mail'

# %%
communications_apps.loc[communications_apps['App'] == 'Personal stickers StickerMaker', 'appId'] = 'com.memeandsticker.personal'

# %%
communications_apps.loc[communications_apps['App'] == 'imo beta -video calls and chat', 'appId'] = 'com.imo.android.imoim'

# %%
communications_apps.loc[communications_apps['App'] == 'Hola Browser-Private&Fast web', 'appId'] = 'com.talpa.hibrowser'

# %%
communications_apps.loc[communications_apps['App'] == 'videocall - LiveTalk Videocall', 'appId'] = 'com.videocall.videochat.video.chat.call'

# %%
communications_apps.loc[communications_apps['App'] == 'F SMS Libre Text Philippines', 'appId'] = 'free.text.sms'

# %%
communications_apps.loc[communications_apps['App'] == 'gub.uy', 'appId'] = 'uy.gub.app.perfil.release'

# %%
communications_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4800 entries, 0 to 4860
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   similarweb_url  4800 non-null   object
#  1   App             4800 non-null   object
#  2   Publisher       4800 non-null   object
#  3   Category        4800 non-null   object
#  4   appId           4800 non-null   object
# dtypes: object(5)
# memory usage: 225.0+ KB

# %%
communications_apps
# Out:
#                                          similarweb_url  \
# 0     https://www.similarweb.com/top-apps/google/alg...
# 1     https://www.similarweb.com/top-apps/google/alg...
# 2     https://www.similarweb.com/top-apps/google/alg...
# 3     https://www.similarweb.com/top-apps/google/alg...
# 4     https://www.similarweb.com/top-apps/google/alg...
# ...                                                 ...
# 4795  https://www.similarweb.com/top-apps/google/ser...
# 4796  https://www.similarweb.com/top-apps/google/ser...
# 4797  https://www.similarweb.com/top-apps/google/ser...
# 4798  https://www.similarweb.com/top-apps/google/ser...
# 4799  https://www.similarweb.com/top-apps/google/ser...
#
#                                  App  \
# 0                 WhatsApp Messenger
# 1                          Messenger
# 2                           Telegram
# 3                           Snapchat
# 4     Truecaller: Identify Caller ID
# ...                              ...
# 4795   Smart Watch app - BT notifier
# 4796    Botim - Video and Voice Call
# 4797    Opera Mini: Fast Web Browser
# 4798        Opera GX: Gaming Browser
# 4799       Mail - All Email Accounts
#
#                                      Publisher       Category  \
# 0                                 WhatsApp LLC  Communication
# 1                         Meta Platforms, Inc.  Communication
# 2                              Telegram FZ-LLC  Communication
# 3                                     Snap Inc  Communication
# 4                                   Truecaller  Communication
# ...                                        ...            ...
# 4795                            Flying Phoenix  Communication
# 4796           Algento Cloud Computing Limited  Communication
# 4797                                     Opera  Communication
# 4798                                     Opera  Communication
# 4799  Amobear Application - Diavostar PTE. LTD          Email
#
#                                             appId  Country alpha2Code  \
# 0                                    com.whatsapp  Algeria         DZ
# 1                               com.facebook.orca  Algeria         DZ
# 2                          org.telegram.messenger  Algeria         DZ
# 3                            com.snapchat.android  Algeria         DZ
# 4                                  com.truecaller  Algeria         DZ
# ...                                           ...      ...        ...
# 4795  com.smartwatch.bluetooth.sync.notifications   Serbia         RS
# 4796                          im.thebot.messenger   Serbia         RS
# 4797                        com.opera.mini.native   Serbia         RS
# 4798                                 com.opera.gx   Serbia         RS
# 4799        com.quickemail.quicklogin.emailonline   Serbia         RS
#
#                                         google_play_url    reviews  five_star  \
# 0     https://play.google.com/store/apps/details?id=...  190000000  124642625
# 1     https://play.google.com/store/apps/details?id=...   89100000   46053579
# 2     https://play.google.com/store/apps/details?id=...   13900000    9333940
# 3     https://play.google.com/store/apps/details?id=...   35200000   15467638
# 4     https://play.google.com/store/apps/details?id=...   21200000   15974108
# ...                                                 ...        ...        ...
# 4795  https://play.google.com/store/apps/details?id=...     210000     161181
# 4796  https://play.google.com/store/apps/details?id=...    1140000     798697
# 4797  https://play.google.com/store/apps/details?id=...    9130000    7209486
# 4798  https://play.google.com/store/apps/details?id=...     198000     153543
# 4799  https://play.google.com/store/apps/details?id=...       7370       5806
#
#       four_star  three_star  two_star  one_star  weighted_sum  \
# 0      15062961    10741084   7008012  29181989     758886234
# 1       4949839     3550516   2744035  27834686     294041555
# 2       1028448      697534    351536   2075800      55654966
# 3       1874281     1275746    792059  13867570     104114240
# 4       1847402     1139970    556583   1471526      93264750
# ...         ...         ...       ...       ...           ...
# 4795      23739        9995      3748      4997        943339
# 4796     156109       87130     10891     65347       4966440
# 4797     765358      274017    160630    406301      40658474
# 4798      20823        3763      5519      5519        878853
# 4799        387         774         0       387         33287
#
#       score_out_of_five
# 0              4.066115
# 1              3.453922
# 2              4.126485
# 3              3.128687
# 4              4.443381
# ...                 ...
# 4795           4.631931
# 4796           4.441563
# 4797           4.612005
# 4798           4.645911
# 4799           4.526380
#
# [4647 rows x 16 columns]

# %% [markdown]
# ## Email apps

# %%
countries = communications_apps[['Country', 'alpha2Code']].drop_duplicates(subset=['Country'])

# %%
countries
# Out:
#                      Country alpha2Code
# 0                    Algeria         DZ
# 50                Azerbaijan         AZ
# 100                Argentina         AR
# 150                Australia         AU
# 200                  Bahrain         BH
# ...                      ...        ...
# 4550              Bangladesh         BD
# 4600  Bosnia And Herzegovina         BA
# 4650                 Morocco         MA
# 4700             Puerto Rico         PR
# 4750                  Serbia         RS
#
# [96 rows x 2 columns]

# %%
email_apps = communications_apps[communications_apps.Category == 'Email']

# %%
email_apps = email_apps.drop_duplicates(subset=['appId'])

# %%
email_apps[['App', 'Publisher', 'appId']]
# Out:
#                                  App  \
# 42       Email - Fast and Smart Mail
# 44       Temp Mail - Temporary Email
# 64               Mail.ru - Email App
# 117                All Email Connect
# 151                            Gmail
# 165     Yahoo Mail – Organized Email
# 170     Proton Mail: Encrypted Email
# 187       mail.com: Mail app & Cloud
# 195               GMX - Mail & Cloud
# 198                         K-9 Mail
# 296    Email App - Manage Your Inbox
# 333        Mail - All Email Accounts
# 458                         ABV Mail
# 517                      Yandex Mail
# 638         TypeApp mail - email app
# 644   FairEmail, privacy aware email
# 956                         Email.cz
# 971                  Centrum.cz mail
# 1031    E-Mail for Outlook & Hotmail
# 1274                        SFR Mail
# 1281  Laposte.net – Votre boîte mail
# 1310             WEB.DE Mail & Cloud
# 1331                        1&1 Mail
# 1332  freenet Mail - E-Mail Postfach
# 1683                      Rediffmail
# 1861                     Libero Mail
# 1879       Virgilio Mail - Email App
# 1882                    Tiscali Mail
# 1883                       Legalmail
# 1988  App for Gmail SMS etc：CosmoSia
# 2159                      NAVER Mail
# 2175               Daum Mail - 다음 메일
# 2498                        Gmail Go
# 3171     Email for Hotmail & Outlook
# 3783                 Infomaniak Mail
# 4231                        BT Email
# 4702                 All Email Login
# 4709    All Email Access: Mail Inbox
# 4718  Login Mail For HotMail&Outlook
#
#                                        Publisher  \
# 42                      AMOBEAR TECHNOLOGY GROUP
# 44                              Privatix Limited
# 64                                 Mail.Ru Group
# 117                            AI Email & Access
# 151                                   Google LLC
# 165                                        Yahoo
# 170                                    Proton AG
# 187                         1&1 Mail & Media Inc
# 195                                          GMX
# 198                          Mozilla Thunderbird
# 296                                      Negroni
# 333     Amobear Application - Diavostar PTE. LTD
# 458                                „Нет Инфо” АД
# 517   Direct Cursus Computer Systems Trading LLC
# 638                                  TypeApp LLC
# 644                 Marcel Bokhorst, FairCode BV
# 956                              Seznam.cz, a.s.
# 971                                Economia a.s.
# 1031                                    StarPham
# 1274                                         SFR
# 1281                                    La Poste
# 1310                                      WEB.DE
# 1331                            1&1 Telecom GmbH
# 1332                             freenet.de GmbH
# 1683                                  Rediff.com
# 1861                         Italiaonline S.p.A.
# 1879                         Italiaonline S.p.A.
# 1882                          Tiscali Italia SpA
# 1883                                InfoCert SpA
# 1988                                  株式会社ACCESS
# 2159                                 NAVER Corp.
# 2175                                 Kakao Corp.
# 2498                                  Google LLC
# 3171    Amobear Application - Diavostar PTE. LTD
# 3783                                  Infomaniak
# 4231                                BT Group PLC
# 4702                             All Email Login
# 4709                              Appsbuyout Dev
# 4718                    AMOBEAR TECHNOLOGY GROUP
#
#                                           appId
# 42     com.fastsigninemail.securemail.bestemail
# 44                                 com.tempmail
# 64                              ru.mail.mailapp
# 117               com.mail.inbox.allemailaccess
# 151                       com.google.android.gm
# 165        com.yahoo.mobile.client.android.mail
# 170                       ch.protonmail.android
# 187                com.mail.mobile.android.mail
# 195                  de.gmx.mobile.android.mail
# 198                                 com.fsck.k9
# 296                           com.easilydo.mail
# 333       com.quickemail.quicklogin.emailonline
# 458                       bg.abv.andro.emailapp
# 517                              ru.yandex.mail
# 638                               com.trtf.blue
# 644                           eu.faircode.email
# 956                             cz.seznam.email
# 971                  com.nanooqit.economiaemail
# 1031              com.email.outlookmail.hotmail
# 1274                    com.sfr.android.sfrmail
# 1281                     com.laposte.lapostenet
# 1310                 de.web.mobile.android.mail
# 1331      com.oneandone.ciso.mobile.app.android
# 1332                            de.freenet.mail
# 1683                        com.rediff.mail.and
# 1861                       it.italiaonline.mail
# 1879            it.italiaonline.virgiliomailapp
# 1882                        com.tiscali.appmail
# 1883               it.infocert.mobile.legalmail
# 1988  com.access_company.android.nfcommunicator
# 2159                       com.nhn.android.mail
# 2175                      net.daum.android.mail
# 2498                 com.google.android.gm.lite
# 3171               com.microsoft.office.outlook
# 3783                        com.infomaniak.mail
# 4231                         com.bt.mail.btprod
# 4702                         com.allemail.login
# 4709                  info.myapp.allemailaccess
# 4718        com.emailonline.officemail.amoemail

# %%
# Creating a list to hold the results
results = []

# Loop through each country and email app to generate the URLs and build the final DataFrame
for _, country_row in countries.iterrows():
    for _, app_row in email_apps.iterrows():
        google_play_url = f"https://play.google.com/store/apps/details?id={app_row['appId']}&hl=en_GB&gl={country_row['alpha2Code']}"
        results.append({
            'Country': country_row['Country'],
            'alpha2Code': country_row['alpha2Code'],
            'App': app_row['App'],
            'Publisher': app_row['Publisher'],
            'appId': app_row['appId'],
            'google_play_url': google_play_url
        })

# Convert the results into a DataFrame
email_df = pd.DataFrame(results)

# %%
email_df
# Out:
#       Country alpha2Code                             App  \
# 0     Algeria         DZ     Email - Fast and Smart Mail
# 1     Algeria         DZ     Temp Mail - Temporary Email
# 2     Algeria         DZ             Mail.ru - Email App
# 3     Algeria         DZ               All Email Connect
# 4     Algeria         DZ                           Gmail
# ...       ...        ...                             ...
# 3739   Serbia         RS                 Infomaniak Mail
# 3740   Serbia         RS                        BT Email
# 3741   Serbia         RS                 All Email Login
# 3742   Serbia         RS    All Email Access: Mail Inbox
# 3743   Serbia         RS  Login Mail For HotMail&Outlook
#
#                      Publisher                                     appId  \
# 0     AMOBEAR TECHNOLOGY GROUP  com.fastsigninemail.securemail.bestemail
# 1             Privatix Limited                              com.tempmail
# 2                Mail.Ru Group                           ru.mail.mailapp
# 3            AI Email & Access             com.mail.inbox.allemailaccess
# 4                   Google LLC                     com.google.android.gm
# ...                        ...                                       ...
# 3739                Infomaniak                       com.infomaniak.mail
# 3740              BT Group PLC                        com.bt.mail.btprod
# 3741           All Email Login                        com.allemail.login
# 3742            Appsbuyout Dev                 info.myapp.allemailaccess
# 3743  AMOBEAR TECHNOLOGY GROUP       com.emailonline.officemail.amoemail
#
#                                         google_play_url
# 0     https://play.google.com/store/apps/details?id=...
# 1     https://play.google.com/store/apps/details?id=...
# 2     https://play.google.com/store/apps/details?id=...
# 3     https://play.google.com/store/apps/details?id=...
# 4     https://play.google.com/store/apps/details?id=...
# ...                                                 ...
# 3739  https://play.google.com/store/apps/details?id=...
# 3740  https://play.google.com/store/apps/details?id=...
# 3741  https://play.google.com/store/apps/details?id=...
# 3742  https://play.google.com/store/apps/details?id=...
# 3743  https://play.google.com/store/apps/details?id=...
#
# [3744 rows x 6 columns]

# %%
#email_df.to_csv('email_df.csv', index=False)

# %%
email_apps = pd.read_csv('email_apps_scraped.csv')

# %%
email_apps = email_apps.dropna(subset=['reviews']).reset_index(drop=True)

# %%
email_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2614 entries, 0 to 2613
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          2614 non-null   object
#  1   alpha2Code       2614 non-null   object
#  2   App              2614 non-null   object
#  3   Publisher        2614 non-null   object
#  4   appId            2614 non-null   object
#  5   google_play_url  2614 non-null   object
#  6   reviews          2614 non-null   object
#  7   five_star        2614 non-null   object
#  8   four_star        2614 non-null   object
#  9   three_star       2614 non-null   object
#  10  two_star         2614 non-null   object
#  11  one_star         2614 non-null   object
# dtypes: object(12)
# memory usage: 245.2+ KB

# %%
email_apps
# Out:
#       Country alpha2Code                             App  \
# 0     Algeria         DZ     Email - Fast and Smart Mail
# 1     Algeria         DZ     Temp Mail - Temporary Email
# 2     Algeria         DZ             Mail.ru - Email App
# 3     Algeria         DZ               All Email Connect
# 4     Algeria         DZ                           Gmail
# ...       ...        ...                             ...
# 2609   Serbia         RS                     Libero Mail
# 2610   Serbia         RS                        Gmail Go
# 2611   Serbia         RS     Email for Hotmail & Outlook
# 2612   Serbia         RS    All Email Access: Mail Inbox
# 2613   Serbia         RS  Login Mail For HotMail&Outlook
#
#                                      Publisher  \
# 0                     AMOBEAR TECHNOLOGY GROUP
# 1                             Privatix Limited
# 2                                Mail.Ru Group
# 3                            AI Email & Access
# 4                                   Google LLC
# ...                                        ...
# 2609                       Italiaonline S.p.A.
# 2610                                Google LLC
# 2611  Amobear Application - Diavostar PTE. LTD
# 2612                            Appsbuyout Dev
# 2613                  AMOBEAR TECHNOLOGY GROUP
#
#                                          appId  \
# 0     com.fastsigninemail.securemail.bestemail
# 1                                 com.tempmail
# 2                              ru.mail.mailapp
# 3                com.mail.inbox.allemailaccess
# 4                        com.google.android.gm
# ...                                        ...
# 2609                      it.italiaonline.mail
# 2610                com.google.android.gm.lite
# 2611              com.microsoft.office.outlook
# 2612                 info.myapp.allemailaccess
# 2613       com.emailonline.officemail.amoemail
#
#                                         google_play_url        reviews  \
# 0     https://play.google.com/store/apps/details?id=...  83.5K reviews
# 1     https://play.google.com/store/apps/details?id=...   325K reviews
# 2     https://play.google.com/store/apps/details?id=...  3.14M reviews
# 3     https://play.google.com/store/apps/details?id=...  10.6K reviews
# 4     https://play.google.com/store/apps/details?id=...    13M reviews
# ...                                                 ...            ...
# 2609  https://play.google.com/store/apps/details?id=...  99.5K reviews
# 2610  https://play.google.com/store/apps/details?id=...   145K reviews
# 2611  https://play.google.com/store/apps/details?id=...  9.48M reviews
# 2612  https://play.google.com/store/apps/details?id=...  62.3K reviews
# 2613  https://play.google.com/store/apps/details?id=...  26.5K reviews
#
#       five_star  four_star three_star two_star   one_star
# 0        55,756     11,046      3,945      789      7,890
# 1       231,420     27,484     18,983   10,554     31,734
# 2     2,135,250    386,820    154,728  139,255    201,146
# 3         4,517      4,517          0        0      1,505
# 4     8,493,138  1,030,231    636,912  372,862  1,925,536
# ...         ...        ...        ...      ...        ...
# 2609     52,183     34,789          0        0      8,697
# 2610     95,879     11,279      8,459    4,229     19,739
# 2611  7,789,110  1,056,052    115,354   71,915    144,314
# 2612     46,422     13,754          0        0      1,719
# 2613     13,702      3,425      2,283    1,141      4,567
#
# [2614 rows x 12 columns]

# %%
#communications_apps.to_csv('communications_apps.csv', index=False)

# %% [markdown]
# ## Social apps

# %%
folder_path = ''

# %%
# Iterate over the seed list
for _, app in scrape.iterrows():
    app_name = app['App']
    
    try: 
        # Search for the app
        result = search(
            app_name,
            lang="en",  
            country="us",  
            n_hits=10)

        # Save reviews to JSON file
        file_name = f'{app_name}.json'
        file_path = os.path.join(folder_path, file_name)
        with open(file_path, 'w') as json_file:
            json.dump(result, json_file, indent=4)
        time.sleep(3)
        print('Done', _, app_name)
    except Exception as e:
        print(f'Exception {app_name}: {e}')
# Out:
# Exception WeParty-Live Chat&Voice Party: 'NoneType' object is not subscriptable
# Done 1 Best Wishes: For all Occasions
# Done 2 SUSH Grow cute virtual animal

# %%
json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

for file in json_files:
    with open(os.path.join(folder_path, file), 'r') as json_file:
        json_data = json.load(json_file)
        
        file_name = file.split('.json')[0]
        appId = json_data[0]['appId']
        
        mask = social_apps['App'] == file_name
        social_apps.loc[mask, 'appId'] = appId

# %%
scrape = pd.DataFrame(social_apps[pd.isna(social_apps.appId)]['App'].unique(), columns=['App']) #.to_excel('scrape.xlsx', index=False)

# %%
scrape
# Out:
# Empty DataFrame
# Columns: [App]
# Index: []

# %%
social_apps.loc[social_apps['App'] == 'WeParty-Live Chat&Voice Party', 'appId'] = 'com.partyjoy.weparty'

# %%
social_apps.loc[social_apps['App'] == 'Ayar-Chat&Play', 'appId'] = 'com.star.ayar.android'

# %%
social_apps.loc[social_apps['App'] == 'Xviews - Video Chat&Hook Up', 'appId'] = 'com.waooolive.android'

# %%
social_apps.loc[social_apps['App'] == 'Blind Stalk See Hidden Profile', 'appId'] = 'net.instalk.app'

# %%
social_apps.loc[social_apps['App'] == 'See log - view hidden profile', 'appId'] = 'com.seelog.app'

# %%
social_apps.loc[social_apps['App'] == 'Achat- Live Chat& Make Friends', 'appId'] = 'com.ahchat.app'

# %%
social_apps.loc[social_apps['App'] == 'Scret: anonymous Q&A', 'appId'] = 'com.scretmobile'

# %%
social_apps.loc[social_apps['App'] == 'Trabajando .COM', 'appId'] = 'com.trabajando'

# %%
social_apps.loc[social_apps['App'] == 'Timehop - Memories Then & Now', 'appId'] = 'com.timehop'

# %%
social_apps.loc[social_apps['App'] == 'RandomChat - Chat in Japanese', 'appId'] = 'com.randomchat'

# %%
social_apps.loc[social_apps['App'] == 'ZonePane for Mastodon&Bluesky', 'appId'] = 'com.zonepane'

# %%
social_apps.loc[social_apps['App'] == 'My city', 'appId'] = 'mycity.home'

# %%
social_apps.loc[social_apps['App'] == 'Whats Group Links Join Groups', 'appId'] = 'com.thwhatsn.agrop.whsap'

# %%
social_apps.loc[social_apps['App'] == 'Spottd', 'appId'] = 'app.spottd'

# %%
social_apps['Category'] = social_apps['Category'].fillna('Social')

# %%
social_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4800 entries, 0 to 4861
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   similarweb_url  4800 non-null   object
#  1   App             4800 non-null   object
#  2   Publisher       4800 non-null   object
#  3   Category        4800 non-null   object
#  4   appId           4800 non-null   object
# dtypes: object(5)
# memory usage: 225.0+ KB

# %%
social_apps.to_csv('social_apps.csv', index=False)

# %%
social_apps
# Out:
#                                          similarweb_url  \
# 0     https://www.similarweb.com/top-apps/google/alg...
# 1     https://www.similarweb.com/top-apps/google/alg...
# 2     https://www.similarweb.com/top-apps/google/alg...
# 3     https://www.similarweb.com/top-apps/google/alg...
# 4     https://www.similarweb.com/top-apps/google/alg...
# ...                                                 ...
# 4857  https://www.similarweb.com/top-apps/google/ser...
# 4858  https://www.similarweb.com/top-apps/google/ser...
# 4859  https://www.similarweb.com/top-apps/google/ser...
# 4860  https://www.similarweb.com/top-apps/google/ser...
# 4861  https://www.similarweb.com/top-apps/google/ser...
#
#                                  App             Publisher Category  \
# 0                      Facebook Lite  Meta Platforms, Inc.   Social
# 1                           Facebook  Meta Platforms, Inc.   Social
# 2                             TikTok      TikTok Pte. Ltd.   Social
# 3            TikTok Lite - Save Data      TikTok Pte. Ltd.   Social
# 4                          Instagram             Instagram   Social
# ...                              ...                   ...      ...
# 4857     Xviews - Video Chat&Hook Up         Wavechat Inc.   Social
# 4858  Chat Alternative — android app        Video Chat Alt   Social
# 4859  BeReal. Your friends for real.                BeReal   Social
# 4860       FollowMeter for Instagram           Followmeter   Social
# 4861      Monkey - random video chat           Monkey.cool   Social
#
#                              appId
# 0                com.facebook.lite
# 1              com.facebook.katana
# 2         com.zhiliaoapp.musically
# 3         com.zhiliaoapp.musically
# 4            com.instagram.android
# ...                            ...
# 4857         com.waooolive.android
# 4858  com.chatroullete.alternative
# 4859                 com.bereal.ft
# 4860    com.beakerapps.instameter2
# 4861           cool.monkey.android
#
# [4800 rows x 5 columns]

# %% [markdown]
# # Scrape apps

# %% [markdown]
# ## Communications apps

# %%
communications_apps['Country'] = communications_apps['similarweb_url'].apply(lambda x: x.split('/')[5])

# %%
len(communications_apps['Country'].unique())

# %%
for country in countries:
    mask = communications_apps['Country'] == country['urlCode']
    
    if mask.any():
        communications_apps.loc[mask, 'alpha2Code'] = country['alpha2Code']

# %%
communications_apps.loc[communications_apps['Country'] == 'austria', 'alpha2Code'] = 'AT'
communications_apps.loc[communications_apps['Country'] == 'bangladesh', 'alpha2Code'] = 'BD'
communications_apps.loc[communications_apps['Country'] == 'bosnia-and-herzegovina', 'alpha2Code'] = 'BA'
communications_apps.loc[communications_apps['Country'] == 'morocco', 'alpha2Code'] = 'MA'
communications_apps.loc[communications_apps['Country'] == 'puerto-rico', 'alpha2Code'] = 'PR'
communications_apps.loc[communications_apps['Country'] == 'serbia', 'alpha2Code'] = 'RS'

# %%
communications_apps['google_play_url'] = communications_apps.apply(lambda row: f"https://play.google.com/store/apps/details?id={row['appId']}&hl=en_GB&gl={row['alpha2Code']}", axis=1)

# %%
for index, row in communications_apps[134:].iterrows():
    url = row['google_play_url']

      try:
            response = requests.get(url)
            response.raise_for_status()

            soup = BeautifulSoup(response.text)
            reviews = soup.find_all('div', 'g1rdde')[0].text
            breakdowns = [x.get('title') for x in soup.find_all('div', 'RutFAf wcB8se')]

            five_star = breakdowns[0]
            four_star = breakdowns[1]
            three_star = breakdowns[2]
            two_star = breakdowns[3]
            one_star = breakdowns[4]

            communications_apps.loc[index, 'reviews'] = reviews
            communications_apps.loc[index, 'five_star'] = five_star
            communications_apps.loc[index, 'four_star'] = four_star
            communications_apps.loc[index, 'three_star'] = three_star
            communications_apps.loc[index, 'two_star'] = two_star
            communications_apps.loc[index, 'one_star'] = one_star

            communications_apps.to_csv(folder_path + 'communications_apps_scraped.csv', index=False)
            print('Done: ', index)
            time.sleep(3)

    except Exception as e:
            print(f'Error with {index}: {e}')

# %%
communications_apps = pd.read_csv('communications_apps_scraped.csv')

# %%
communications_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4800 entries, 0 to 4799
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   similarweb_url   4800 non-null   object
#  1   App              4800 non-null   object
#  2   Publisher        4800 non-null   object
#  3   Category         4800 non-null   object
#  4   appId            4800 non-null   object
#  5   Country          4800 non-null   object
#  6   alpha2Code       4800 non-null   object
#  7   google_play_url  4800 non-null   object
#  8   reviews          4647 non-null   object
#  9   five_star        4647 non-null   object
#  10  four_star        4647 non-null   object
#  11  three_star       4647 non-null   object
#  12  two_star         4647 non-null   object
#  13  one_star         4647 non-null   object
# dtypes: object(14)
# memory usage: 525.1+ KB

# %%
for url in communications_apps[pd.isna(communications_apps.reviews)]['google_play_url'].unique():
    print(url)
# Out:
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=DZ
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=AZ
# https://play.google.com/store/apps/details?id=com.destinyitemmanager.app&hl=en_GB&gl=AZ
# https://play.google.com/store/apps/details?id=com.romanticstickers.lovestickers.wastickers.ly&hl=en_GB&gl=AZ
# https://play.google.com/store/apps/details?id=com.miclaro.app&hl=en_GB&gl=AR
# https://play.google.com/store/apps/details?id=com.telego.phone.android&hl=en_GB&gl=AR
# https://play.google.com/store/apps/details?id=com.deucetek.tokee&hl=en_GB&gl=AR
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=AU
# https://play.google.com/store/apps/details?id=com.vikingcruises.mvjapp&hl=en_GB&gl=BE
# https://play.google.com/store/apps/details?id=com.cscsw.cscservicerequest&hl=en_GB&gl=BE
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=BE
# https://play.google.com/store/apps/details?id=com.orange.esimfortravelers&hl=en_GB&gl=BE
# https://play.google.com/store/apps/details?id=andromeda.smart.softwares.com.voissy&hl=en_GB&gl=BO
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=BR
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=BR
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=BG
# https://play.google.com/store/apps/details?id=co.beeline&hl=en_GB&gl=BY
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=BY
# https://play.google.com/store/apps/details?id=com.deucetek.tokee&hl=en_GB&gl=KH
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=CA
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=LK
# https://play.google.com/store/apps/details?id=com.airtel.africa.selfcare&hl=en_GB&gl=LK
# https://play.google.com/store/apps/details?id=com.romanticstickers.lovestickers.wastickers.ly&hl=en_GB&gl=LK
# https://play.google.com/store/apps/details?id=com.monoorg.telemasgerstore&hl=en_GB&gl=LK
# https://play.google.com/store/apps/details?id=com.jio.web&hl=en_GB&gl=CL
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=TW
# https://play.google.com/store/apps/details?id=com.videocall.sweetchat&hl=en_GB&gl=CR
# https://play.google.com/store/apps/details?id=com.xxgirl.chat&hl=en_GB&gl=CR
# https://play.google.com/store/apps/details?id=com.flalottery.FLALOTTERY&hl=en_GB&gl=DO
# https://play.google.com/store/apps/details?id=com.itamazons.whatsweb.whatapps.web.whatscan.qrcode&hl=en_GB&gl=DO
# https://play.google.com/store/apps/details?id=com.arcacontal.acinforma&hl=en_GB&gl=EC
# https://play.google.com/store/apps/details?id=com.xxgirl.chat&hl=en_GB&gl=EC
# https://play.google.com/store/apps/details?id=best.recover.deleted.messages&hl=en_GB&gl=SV
# https://play.google.com/store/apps/details?id=com.fakecall.prankfriends.android2023&hl=en_GB&gl=SV
# https://play.google.com/store/apps/details?id=com.m.magictvhd&hl=en_GB&gl=SV
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=FR
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=FR
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=DE
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=DE
# https://play.google.com/store/apps/details?id=com.iserv&hl=en_GB&gl=DE
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=GH
# https://play.google.com/store/apps/details?id=com.taktak.browser&hl=en_GB&gl=GR
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=GR
# https://play.google.com/store/apps/details?id=com.videocall.sweetchat&hl=en_GB&gl=GT
# https://play.google.com/store/apps/details?id=com.fakecall.prankfriends.android2023&hl=en_GB&gl=GT
# https://play.google.com/store/apps/details?id=com.videocall.sweetchat&hl=en_GB&gl=HN
# https://play.google.com/store/apps/details?id=andromeda.smart.softwares.com.voissy&hl=en_GB&gl=HN
# https://play.google.com/store/apps/details?id=com.passmark.pt_mobile&hl=en_GB&gl=HK
# https://play.google.com/store/apps/details?id=com.taktak.browser&hl=en_GB&gl=HU
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=IN
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=IN
# https://play.google.com/store/apps/details?id=net.activote.app&hl=en_GB&gl=IN
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=ID
# https://play.google.com/store/apps/details?id=io.chatyapp&hl=en_GB&gl=ID
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=ID
# https://play.google.com/store/apps/details?id=com.lycadigital.lycamobileusa&hl=en_GB&gl=IE
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=IE
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=IL
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=IT
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=KZ
# https://play.google.com/store/apps/details?id=co.beeline&hl=en_GB&gl=KZ
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=JO
# https://play.google.com/store/apps/details?id=best.recover.deleted.messages&hl=en_GB&gl=JO
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=KE
# https://play.google.com/store/apps/details?id=com.imo.android.imous&hl=en_GB&gl=KE
# https://play.google.com/store/apps/details?id=com.videocall.videochat.video.chat.call&hl=en_GB&gl=KE
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=KR
# https://play.google.com/store/apps/details?id=com.tmobile.services.nameid&hl=en_GB&gl=KR
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=KG
# https://play.google.com/store/apps/details?id=com.itamazons.whatsweb.whatapps.web.whatscan.qrcode&hl=en_GB&gl=KG
# https://play.google.com/store/apps/details?id=co.beeline&hl=en_GB&gl=KG
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=MY
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=MY
# https://play.google.com/store/apps/details?id=io.chatyapp&hl=en_GB&gl=MY
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=MX
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=OM
# https://play.google.com/store/apps/details?id=com.romanticstickers.lovestickers.wastickers.ly&hl=en_GB&gl=OM
# https://play.google.com/store/apps/details?id=best.recover.deleted.messages&hl=en_GB&gl=OM
# https://play.google.com/store/apps/details?id=com.call.flash.sms.flash&hl=en_GB&gl=OM
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=NP
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=NL
# https://play.google.com/store/apps/details?id=br.org.ons.app&hl=en_GB&gl=NL
# https://play.google.com/store/apps/details?id=nl.twogoMobile.woerden&hl=en_GB&gl=NL
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=NL
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=NZ
# https://play.google.com/store/apps/details?id=com.Microsoft.WarehouseManagement&hl=en_GB&gl=NZ
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=NG
# https://play.google.com/store/apps/details?id=com.nice.mobileapp&hl=en_GB&gl=NO
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=NO
# https://play.google.com/store/apps/details?id=no.fagforbundet.areader&hl=en_GB&gl=NO
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=PK
# https://play.google.com/store/apps/details?id=com.videocall.sweetchat&hl=en_GB&gl=PA
# https://play.google.com/store/apps/details?id=com.fakecall.prankfriends.android2023&hl=en_GB&gl=PA
# https://play.google.com/store/apps/details?id=com.xxgirl.chat&hl=en_GB&gl=PA
# https://play.google.com/store/apps/details?id=best.recover.deleted.messages&hl=en_GB&gl=PY
# https://play.google.com/store/apps/details?id=mx.com.cfe.cfecontigo&hl=en_GB&gl=PY
# https://play.google.com/store/apps/details?id=com.itamazons.whatsweb.whatapps.web.whatscan.qrcode&hl=en_GB&gl=PY
# https://play.google.com/store/apps/details?id=best.recover.deleted.messages&hl=en_GB&gl=PE
# https://play.google.com/store/apps/details?id=com.arcacontal.acinforma&hl=en_GB&gl=PE
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=PH
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=PH
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=PL
# https://play.google.com/store/apps/details?id=com.orange.esimfortravelers&hl=en_GB&gl=PL
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=PL
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=PT
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=RO
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=RU
# https://play.google.com/store/apps/details?id=com.vzw.ecid&hl=en_GB&gl=RU
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=RU
# https://play.google.com/store/apps/details?id=com.tamtam.checkin&hl=en_GB&gl=RU
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=SA
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=SA
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=SG
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=SG
# https://play.google.com/store/apps/details?id=io.chatyapp&hl=en_GB&gl=SG
# https://play.google.com/store/apps/details?id=com.celled.webapp&hl=en_GB&gl=ZA
# https://play.google.com/store/apps/details?id=com.fca.myconnect.nafta&hl=en_GB&gl=ZA
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=ZA
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=ES
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=SE
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=CH
# https://play.google.com/store/apps/details?id=com.rosenbauer.connected.command&hl=en_GB&gl=CH
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=TH
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=TH
# https://play.google.com/store/apps/details?id=com.makeitsimplett.caribbeanstudyforums&hl=en_GB&gl=TT
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=AE
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=AE
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=TN
# https://play.google.com/store/apps/details?id=best.recover.deleted.messages&hl=en_GB&gl=TN
# https://play.google.com/store/apps/details?id=com.imo.android.imous&hl=en_GB&gl=TN
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=TR
# https://play.google.com/store/apps/details?id=com.callapp.contacts&hl=en_GB&gl=TR
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=EG
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=EG
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=GB
# https://play.google.com/store/apps/details?id=com.callassistant.android&hl=en_GB&gl=GB
# https://play.google.com/store/apps/details?id=andromeda.smart.softwares.com.voissy&hl=en_GB&gl=UY
# https://play.google.com/store/apps/details?id=com.mmcallsapp.duocall.android&hl=en_GB&gl=UY
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=UZ
# https://play.google.com/store/apps/details?id=com.emotii.emotii&hl=en_GB&gl=VE
# https://play.google.com/store/apps/details?id=com.videocall.sweetchat&hl=en_GB&gl=VE
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=AT
# https://play.google.com/store/apps/details?id=com.beeper.android&hl=en_GB&gl=AT
# https://play.google.com/store/apps/details?id=com.taktak.browser&hl=en_GB&gl=AT
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=BD
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=MA
# https://play.google.com/store/apps/details?id=best.recover.deleted.messages&hl=en_GB&gl=MA
# https://play.google.com/store/apps/details?id=com.inw.trulinco&hl=en_GB&gl=MA
# https://play.google.com/store/apps/details?id=com.innocaption.vpdp&hl=en_GB&gl=RS

# %%
communications_apps
# Out:
#                                          similarweb_url  \
# 0     https://www.similarweb.com/top-apps/google/alg...
# 1     https://www.similarweb.com/top-apps/google/alg...
# 2     https://www.similarweb.com/top-apps/google/alg...
# 3     https://www.similarweb.com/top-apps/google/alg...
# 4     https://www.similarweb.com/top-apps/google/alg...
# ...                                                 ...
# 4795  https://www.similarweb.com/top-apps/google/ser...
# 4796  https://www.similarweb.com/top-apps/google/ser...
# 4797  https://www.similarweb.com/top-apps/google/ser...
# 4798  https://www.similarweb.com/top-apps/google/ser...
# 4799  https://www.similarweb.com/top-apps/google/ser...
#
#                                  App  \
# 0                 WhatsApp Messenger
# 1                          Messenger
# 2                           Telegram
# 3                           Snapchat
# 4     Truecaller: Identify Caller ID
# ...                              ...
# 4795   Smart Watch app - BT notifier
# 4796    Botim - Video and Voice Call
# 4797    Opera Mini: Fast Web Browser
# 4798        Opera GX: Gaming Browser
# 4799       Mail - All Email Accounts
#
#                                      Publisher       Category  \
# 0                                 WhatsApp LLC  Communication
# 1                         Meta Platforms, Inc.  Communication
# 2                              Telegram FZ-LLC  Communication
# 3                                     Snap Inc  Communication
# 4                                   Truecaller  Communication
# ...                                        ...            ...
# 4795                            Flying Phoenix  Communication
# 4796           Algento Cloud Computing Limited  Communication
# 4797                                     Opera  Communication
# 4798                                     Opera  Communication
# 4799  Amobear Application - Diavostar PTE. LTD  Communication
#
#                                             appId  Country alpha2Code  \
# 0                                    com.whatsapp  algeria         DZ
# 1                               com.facebook.orca  algeria         DZ
# 2                          org.telegram.messenger  algeria         DZ
# 3                            com.snapchat.android  algeria         DZ
# 4                                  com.truecaller  algeria         DZ
# ...                                           ...      ...        ...
# 4795  com.smartwatch.bluetooth.sync.notifications   serbia         RS
# 4796                          im.thebot.messenger   serbia         RS
# 4797                        com.opera.mini.native   serbia         RS
# 4798                                 com.opera.gx   serbia         RS
# 4799        com.quickemail.quicklogin.emailonline   serbia         RS
#
#                                         google_play_url        reviews  \
# 0     https://play.google.com/store/apps/details?id=...   190M reviews
# 1     https://play.google.com/store/apps/details?id=...  89.1M reviews
# 2     https://play.google.com/store/apps/details?id=...  13.9M reviews
# 3     https://play.google.com/store/apps/details?id=...  35.2M reviews
# 4     https://play.google.com/store/apps/details?id=...  21.2M reviews
# ...                                                 ...            ...
# 4795  https://play.google.com/store/apps/details?id=...   210K reviews
# 4796  https://play.google.com/store/apps/details?id=...  1.14M reviews
# 4797  https://play.google.com/store/apps/details?id=...  9.13M reviews
# 4798  https://play.google.com/store/apps/details?id=...   198K reviews
# 4799  https://play.google.com/store/apps/details?id=...  7.37K reviews
#
#         five_star   four_star  three_star   two_star    one_star
# 0     124,642,625  15,062,961  10,741,084  7,008,012  29,181,989
# 1      46,053,579   4,949,839   3,550,516  2,744,035  27,834,686
# 2       9,333,940   1,028,448     697,534    351,536   2,075,800
# 3      15,467,638   1,874,281   1,275,746    792,059  13,867,570
# 4      15,974,108   1,847,402   1,139,970    556,583   1,471,526
# ...           ...         ...         ...        ...         ...
# 4795      161,181      23,739       9,995      3,748       4,997
# 4796      798,697     156,109      87,130     10,891      65,347
# 4797    7,209,486     765,358     274,017    160,630     406,301
# 4798      153,543      20,823       3,763      5,519       5,519
# 4799        5,806         387         774          0         387
#
# [4800 rows x 14 columns]

# %% [markdown]
# ## Social apps

# %%
social_apps['Country'] = social_apps['similarweb_url'].apply(lambda x: x.split('/')[5])

# %%
len(social_apps['Country'].unique())

# %%
for country in countries:
    mask = social_apps['Country'] == country['urlCode']
    
    if mask.any():
        social_apps.loc[mask, 'alpha2Code'] = country['alpha2Code']

# %%
social_apps.loc[social_apps['Country'] == 'austria', 'alpha2Code'] = 'AT'
social_apps.loc[social_apps['Country'] == 'bangladesh', 'alpha2Code'] = 'BD'
social_apps.loc[social_apps['Country'] == 'bosnia-and-herzegovina', 'alpha2Code'] = 'BA'
social_apps.loc[social_apps['Country'] == 'morocco', 'alpha2Code'] = 'MA'
social_apps.loc[social_apps['Country'] == 'puerto-rico', 'alpha2Code'] = 'PR'
social_apps.loc[social_apps['Country'] == 'serbia', 'alpha2Code'] = 'RS'

# %%
social_apps['google_play_url'] = social_apps.apply(lambda row: f"https://play.google.com/store/apps/details?id={row['appId']}&hl=en_GB&gl={row['alpha2Code']}", axis=1)

# %%
for index, row in social_apps[58:].iterrows():
  url = row['google_play_url']

  try:
    response = requests.get(url)
    response.raise_for_status()

    soup = BeautifulSoup(response.text)
    reviews = soup.find_all('div', 'g1rdde')[0].text
    breakdowns = [x.get('title') for x in soup.find_all('div', 'RutFAf wcB8se')]

    five_star = breakdowns[0]
    four_star = breakdowns[1]
    three_star = breakdowns[2]
    two_star = breakdowns[3]
    one_star = breakdowns[4]

    social_apps.loc[index, 'reviews'] = reviews
    social_apps.loc[index, 'five_star'] = five_star
    social_apps.loc[index, 'four_star'] = four_star
    social_apps.loc[index, 'three_star'] = three_star
    social_apps.loc[index, 'two_star'] = two_star
    social_apps.loc[index, 'one_star'] = one_star

    social_apps.to_csv(folder_path + 'social_apps_scraped.csv', index=False)
    print('Done: ', index)
    time.sleep(3)

  except Exception as e:
        print(f'Error with {index}: {e}')

# %%
social_apps = pd.read_csv('social_apps_scraped.csv')

# %%
social_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4800 entries, 0 to 4799
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   similarweb_url   4800 non-null   object
#  1   App              4800 non-null   object
#  2   Publisher        4800 non-null   object
#  3   Category         4800 non-null   object
#  4   appId            4800 non-null   object
#  5   Country          4800 non-null   object
#  6   alpha2Code       4800 non-null   object
#  7   google_play_url  4800 non-null   object
#  8   reviews          4587 non-null   object
#  9   five_star        4587 non-null   object
#  10  four_star        4587 non-null   object
#  11  three_star       4587 non-null   object
#  12  two_star         4587 non-null   object
#  13  one_star         4587 non-null   object
# dtypes: object(14)
# memory usage: 525.1+ KB

# %%
for url in social_apps[pd.isna(social_apps.reviews)]['google_play_url'].unique():
    print(url)
# Out:
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=DZ
# https://play.google.com/store/apps/details?id=com.alleote.alleote&hl=en_GB&gl=DZ
# https://play.google.com/store/apps/details?id=com.video.welive&hl=en_GB&gl=AZ
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=AZ
# https://play.google.com/store/apps/details?id=com.matchu.machat&hl=en_GB&gl=AZ
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=AR
# https://play.google.com/store/apps/details?id=sw.es.galuresa&hl=en_GB&gl=AR
# https://play.google.com/store/apps/details?id=inc.peer.app&hl=en_GB&gl=AR
# https://play.google.com/store/apps/details?id=com.goodmorningwishes.dailywishesandblessing&hl=en_GB&gl=AR
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=AM
# https://play.google.com/store/apps/details?id=com.nextdoor&hl=en_GB&gl=BE
# https://play.google.com/store/apps/details?id=com.videolite&hl=en_GB&gl=BE
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=BE
# https://play.google.com/store/apps/details?id=com.shippity&hl=en_GB&gl=BE
# https://play.google.com/store/apps/details?id=com.digitalid.soyyo&hl=en_GB&gl=BO
# https://play.google.com/store/apps/details?id=com.savestatus.whmedia.status.downloadstatus.videoimagesaver&hl=en_GB&gl=BO
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=BO
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=BO
# https://play.google.com/store/apps/details?id=com.teampeanut.peanut&hl=en_GB&gl=BO
# https://play.google.com/store/apps/details?id=com.chatroulette.android&hl=en_GB&gl=BO
# https://play.google.com/store/apps/details?id=com.live.bling.android&hl=en_GB&gl=BG
# https://play.google.com/store/apps/details?id=com.app.meego.android&hl=en_GB&gl=BG
# https://play.google.com/store/apps/details?id=com.matchu.machat&hl=en_GB&gl=BG
# https://play.google.com/store/apps/details?id=com.hotti.android&hl=en_GB&gl=BG
# https://play.google.com/store/apps/details?id=net.itoldya.app&hl=en_GB&gl=BY
# https://play.google.com/store/apps/details?id=com.myfriends.live&hl=en_GB&gl=BY
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=BY
# https://play.google.com/store/apps/details?id=com.gotrans.app&hl=en_GB&gl=BY
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=KH
# https://play.google.com/store/apps/details?id=com.goaffpro.affiliates&hl=en_GB&gl=KH
# https://play.google.com/store/apps/details?id=com.crush.ceci&hl=en_GB&gl=KH
# https://play.google.com/store/apps/details?id=com.adoraboo&hl=en_GB&gl=KH
# https://play.google.com/store/apps/details?id=chatgpt.ai.chatbot.open.chat.gpt.bot.writer.assistant&hl=en_GB&gl=LK
# https://play.google.com/store/apps/details?id=com.crush.ceci&hl=en_GB&gl=LK
# https://play.google.com/store/apps/details?id=com.maverick.meki&hl=en_GB&gl=LK
# https://play.google.com/store/apps/details?id=com.ita.plus.tel&hl=en_GB&gl=LK
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=CL
# https://play.google.com/store/apps/details?id=com.goodmorningwishes.dailywishesandblessing&hl=en_GB&gl=CL
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=TW
# https://play.google.com/store/apps/details?id=com.edisto.smartapps&hl=en_GB&gl=TW
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=CO
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=CO
# https://play.google.com/store/apps/details?id=com.goodmorningwishes.dailywishesandblessing&hl=en_GB&gl=CO
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=CR
# https://play.google.com/store/apps/details?id=com.magofi.fmuch&hl=en_GB&gl=CR
# https://play.google.com/store/apps/details?id=com.client.tenderu.android&hl=en_GB&gl=CR
# https://play.google.com/store/apps/details?id=com.savestatus.whmedia.status.downloadstatus.videoimagesaver&hl=en_GB&gl=CR
# https://play.google.com/store/apps/details?id=com.alexandreya.webapp&hl=en_GB&gl=CR
# https://play.google.com/store/apps/details?id=com.interfun.buz&hl=en_GB&gl=CZ
# https://play.google.com/store/apps/details?id=com.adoraboo&hl=en_GB&gl=CZ
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=CZ
# https://play.google.com/store/apps/details?id=com.live.bling.android&hl=en_GB&gl=CZ
# https://play.google.com/store/apps/details?id=com.adamselectric.smartapps&hl=en_GB&gl=DK
# https://play.google.com/store/apps/details?id=org.findmykids.child&hl=en_GB&gl=DK
# https://play.google.com/store/apps/details?id=com.oasisfeng.island&hl=en_GB&gl=DO
# https://play.google.com/store/apps/details?id=com.alexandreya.webapp&hl=en_GB&gl=DO
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=EC
# https://play.google.com/store/apps/details?id=com.magofi.fmuch&hl=en_GB&gl=EC
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=EC
# https://play.google.com/store/apps/details?id=online.gamers.app&hl=en_GB&gl=EC
# https://play.google.com/store/apps/details?id=com.savestatus.whmedia.status.downloadstatus.videoimagesaver&hl=en_GB&gl=EC
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=SV
# https://play.google.com/store/apps/details?id=com.client.tenderu.android&hl=en_GB&gl=SV
# https://play.google.com/store/apps/details?id=com.dogpack&hl=en_GB&gl=SV
# https://play.google.com/store/apps/details?id=fm.cappuccino&hl=en_GB&gl=SV
# https://play.google.com/store/apps/details?id=com.oasisfeng.island&hl=en_GB&gl=SV
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=SV
# https://play.google.com/store/apps/details?id=com.adp.wiselymobile&hl=en_GB&gl=FR
# https://play.google.com/store/apps/details?id=com.dogpack&hl=en_GB&gl=DE
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=GR
# https://play.google.com/store/apps/details?id=com.adoraboo&hl=en_GB&gl=GR
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=GT
# https://play.google.com/store/apps/details?id=com.savestatus.whmedia.status.downloadstatus.videoimagesaver&hl=en_GB&gl=GT
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=GT
# https://play.google.com/store/apps/details?id=com.dogpack&hl=en_GB&gl=GT
# https://play.google.com/store/apps/details?id=fm.cappuccino&hl=en_GB&gl=GT
# https://play.google.com/store/apps/details?id=com.alexandreya.webapp&hl=en_GB&gl=HN
# https://play.google.com/store/apps/details?id=com.dogpack&hl=en_GB&gl=HN
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=HN
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=HN
# https://play.google.com/store/apps/details?id=com.live.bling.android&hl=en_GB&gl=HN
# https://play.google.com/store/apps/details?id=com.neeya.poros&hl=en_GB&gl=HK
# https://play.google.com/store/apps/details?id=com.vk.im&hl=en_GB&gl=HK
# https://play.google.com/store/apps/details?id=com.lguplus.diggerz&hl=en_GB&gl=HK
# https://play.google.com/store/apps/details?id=com.continental.ContiBeat&hl=en_GB&gl=HU
# https://play.google.com/store/apps/details?id=com.adoraboo&hl=en_GB&gl=HU
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=HU
# https://play.google.com/store/apps/details?id=com.livpub.beebee&hl=en_GB&gl=HU
# https://play.google.com/store/apps/details?id=com.zhiliaoapp.musically&hl=en_GB&gl=IN
# https://play.google.com/store/apps/details?id=com.alleote.alleote&hl=en_GB&gl=IN
# https://play.google.com/store/apps/details?id=com.falnesc.statussaver&hl=en_GB&gl=IN
# https://play.google.com/store/apps/details?id=com.storysaver.saveig&hl=en_GB&gl=IN
# https://play.google.com/store/apps/details?id=com.blued.international&hl=en_GB&gl=ID
# https://play.google.com/store/apps/details?id=com.livpub.beebee&hl=en_GB&gl=IE
# https://play.google.com/store/apps/details?id=com.adoraboo&hl=en_GB&gl=IE
# https://play.google.com/store/apps/details?id=com.videolite&hl=en_GB&gl=IE
# https://play.google.com/store/apps/details?id=com.skool.skoolcommunities&hl=en_GB&gl=IE
# https://play.google.com/store/apps/details?id=org.joinmastodon.android.sk&hl=en_GB&gl=IL
# https://play.google.com/store/apps/details?id=it.mirko.transcriber&hl=en_GB&gl=IT
# https://play.google.com/store/apps/details?id=com.markets.manifold&hl=en_GB&gl=IT
# https://play.google.com/store/apps/details?id=gov.fema.mobile.android&hl=en_GB&gl=JP
# https://play.google.com/store/apps/details?id=com.live.poco&hl=en_GB&gl=JP
# https://play.google.com/store/apps/details?id=com.myfriends.live&hl=en_GB&gl=KZ
# https://play.google.com/store/apps/details?id=com.star.ayar.android&hl=en_GB&gl=JO
# https://play.google.com/store/apps/details?id=com.alleote.alleote&hl=en_GB&gl=KE
# https://play.google.com/store/apps/details?id=com.myngly.myngly&hl=en_GB&gl=KE
# https://play.google.com/store/apps/details?id=com.everystudio.timetable&hl=en_GB&gl=KR
# https://play.google.com/store/apps/details?id=com.myfriends.live&hl=en_GB&gl=KG
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=KG
# https://play.google.com/store/apps/details?id=com.rs.myskynet&hl=en_GB&gl=KG
# https://play.google.com/store/apps/details?id=com.alleote.alleote&hl=en_GB&gl=MY
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=MY
# https://play.google.com/store/apps/details?id=de.appack.project.elisabeth_verein&hl=en_GB&gl=MY
# https://play.google.com/store/apps/details?id=ru.moydevice.whizz.android&hl=en_GB&gl=MY
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=MD
# https://play.google.com/store/apps/details?id=com.wepartytt&hl=en_GB&gl=OM
# https://play.google.com/store/apps/details?id=com.nuriworks.nuritopia&hl=en_GB&gl=NP
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=NP
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=NZ
# https://play.google.com/store/apps/details?id=com.skool.skoolcommunities&hl=en_GB&gl=NZ
# https://play.google.com/store/apps/details?id=com.adoraboo&hl=en_GB&gl=NZ
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=NG
# https://play.google.com/store/apps/details?id=io.venly.wallet&hl=en_GB&gl=NO
# https://play.google.com/store/apps/details?id=com.nextdoor&hl=en_GB&gl=NO
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=NO
# https://play.google.com/store/apps/details?id=io.lightbooth.hand&hl=en_GB&gl=NO
# https://play.google.com/store/apps/details?id=com.videolite&hl=en_GB&gl=NO
# https://play.google.com/store/apps/details?id=com.live.bling.android&hl=en_GB&gl=NO
# https://play.google.com/store/apps/details?id=com.livpub.beebee&hl=en_GB&gl=NO
# https://play.google.com/store/apps/details?id=com.alleote.alleote&hl=en_GB&gl=PK
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=PA
# https://play.google.com/store/apps/details?id=com.teampeanut.peanut&hl=en_GB&gl=PA
# https://play.google.com/store/apps/details?id=com.alexandreya.webapp&hl=en_GB&gl=PA
# https://play.google.com/store/apps/details?id=com.magofi.fmuch&hl=en_GB&gl=PA
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=PY
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=PY
# https://play.google.com/store/apps/details?id=com.magofi.fmuch&hl=en_GB&gl=PY
# https://play.google.com/store/apps/details?id=com.alexandreya.webapp&hl=en_GB&gl=PY
# https://play.google.com/store/apps/details?id=com.client.tenderu.android&hl=en_GB&gl=PY
# https://play.google.com/store/apps/details?id=sw.es.galuresa&hl=en_GB&gl=PE
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=PE
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=PE
# https://play.google.com/store/apps/details?id=com.qbmobile.treevent&hl=en_GB&gl=PL
# https://play.google.com/store/apps/details?id=co.fellow.app&hl=en_GB&gl=PL
# https://play.google.com/store/apps/details?id=com.dogpack&hl=en_GB&gl=PT
# https://play.google.com/store/apps/details?id=com.adoraboo&hl=en_GB&gl=PT
# https://play.google.com/store/apps/details?id=com.client.tenderu.android&hl=en_GB&gl=PT
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=PT
# https://play.google.com/store/apps/details?id=com.adoraboo&hl=en_GB&gl=RO
# https://play.google.com/store/apps/details?id=com.readyeducation.dsu&hl=en_GB&gl=RO
# https://play.google.com/store/apps/details?id=com.wam.wallet&hl=en_GB&gl=RO
# https://play.google.com/store/apps/details?id=com.live.bling.android&hl=en_GB&gl=RO
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=RO
# https://play.google.com/store/apps/details?id=com.app.meego.android&hl=en_GB&gl=RO
# https://play.google.com/store/apps/details?id=ru.mos.app&hl=en_GB&gl=RU
# https://play.google.com/store/apps/details?id=ru.mos.polls&hl=en_GB&gl=RU
# https://play.google.com/store/apps/details?id=com.plato.android&hl=en_GB&gl=SA
# https://play.google.com/store/apps/details?id=org.kp.m&hl=en_GB&gl=SG
# https://play.google.com/store/apps/details?id=com.skool.skoolcommunities&hl=en_GB&gl=SG
# https://play.google.com/store/apps/details?id=au.com.etax.mobileapp&hl=en_GB&gl=VN
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=VN
# https://play.google.com/store/apps/details?id=com.whistle.bolt&hl=en_GB&gl=VN
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=VN
# https://play.google.com/store/apps/details?id=anim.dqh.tvw&hl=en_GB&gl=ZA
# https://play.google.com/store/apps/details?id=com.alleote.alleote&hl=en_GB&gl=ZA
# https://play.google.com/store/apps/details?id=org.roubkal.tem&hl=en_GB&gl=SE
# https://play.google.com/store/apps/details?id=com.adoraboo&hl=en_GB&gl=SE
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=SE
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=CH
# https://play.google.com/store/apps/details?id=com.mottoaligners.monitoring&hl=en_GB&gl=CH
# https://play.google.com/store/apps/details?id=com.PerfectAppsFree.frasesbonitasdebuenosdias&hl=en_GB&gl=CH
# https://play.google.com/store/apps/details?id=com.goodmorningwishes.dailywishesandblessing&hl=en_GB&gl=CH
# https://play.google.com/store/apps/details?id=com.skool.skoolcommunities&hl=en_GB&gl=CH
# https://play.google.com/store/apps/details?id=com.client.tenderu.android&hl=en_GB&gl=CH
# https://play.google.com/store/apps/details?id=com.official.rnapp&hl=en_GB&gl=TH
# https://play.google.com/store/apps/details?id=com.uprtek.uspectrum.HatoOne&hl=en_GB&gl=TH
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=TN
# https://play.google.com/store/apps/details?id=com.star.ayar.android&hl=en_GB&gl=TN
# https://play.google.com/store/apps/details?id=com.alleote.alleote&hl=en_GB&gl=TN
# https://play.google.com/store/apps/details?id=com.myfriends.live&hl=en_GB&gl=UA
# https://play.google.com/store/apps/details?id=com.newandromo.dev1124786.app2854967&hl=en_GB&gl=UA
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=UA
# https://play.google.com/store/apps/details?id=com.qmee.mobile&hl=en_GB&gl=UA
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=MK
# https://play.google.com/store/apps/details?id=com.alleote.alleote&hl=en_GB&gl=EG
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=TZ
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=UY
# https://play.google.com/store/apps/details?id=com.adoraboo&hl=en_GB&gl=UY
# https://play.google.com/store/apps/details?id=com.magofi.fmuch&hl=en_GB&gl=UY
# https://play.google.com/store/apps/details?id=fm.cappuccino&hl=en_GB&gl=UY
# https://play.google.com/store/apps/details?id=com.teampeanut.peanut&hl=en_GB&gl=UY
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=UZ
# https://play.google.com/store/apps/details?id=com.welovepranks.lovetester&hl=en_GB&gl=UZ
# https://play.google.com/store/apps/details?id=com.alleote.alleote&hl=en_GB&gl=UZ
# https://play.google.com/store/apps/details?id=com.myfriends.live&hl=en_GB&gl=UZ
# https://play.google.com/store/apps/details?id=cz.patria.mtv2&hl=en_GB&gl=VE
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=VE
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=VE
# https://play.google.com/store/apps/details?id=com.alexandreya.webapp&hl=en_GB&gl=VE
# https://play.google.com/store/apps/details?id=io.barpeak.barpeakapp&hl=en_GB&gl=AT
# https://play.google.com/store/apps/details?id=com.goodmorningwishes.dailywishesandblessing&hl=en_GB&gl=AT
# https://play.google.com/store/apps/details?id=com.tiktok.tv&hl=en_GB&gl=BD
# https://play.google.com/store/apps/details?id=com.falnesc.statussaver&hl=en_GB&gl=BD
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=BA
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=MA
# https://play.google.com/store/apps/details?id=com.oasisfeng.island&hl=en_GB&gl=PR
# https://play.google.com/store/apps/details?id=com.hrcloud.Fortecom&hl=en_GB&gl=RS
# https://play.google.com/store/apps/details?id=app.salo&hl=en_GB&gl=RS
# https://play.google.com/store/apps/details?id=com.tigo.flower&hl=en_GB&gl=RS
# https://play.google.com/store/apps/details?id=com.star.ayar.android&hl=en_GB&gl=RS
# https://play.google.com/store/apps/details?id=app.nicegram&hl=en_GB&gl=RS
# https://play.google.com/store/apps/details?id=com.livpub.beebee&hl=en_GB&gl=RS

# %%
social_apps
# Out:
#                                          similarweb_url  \
# 0     https://www.similarweb.com/top-apps/google/alg...
# 1     https://www.similarweb.com/top-apps/google/alg...
# 2     https://www.similarweb.com/top-apps/google/alg...
# 3     https://www.similarweb.com/top-apps/google/alg...
# 4     https://www.similarweb.com/top-apps/google/alg...
# ...                                                 ...
# 4795  https://www.similarweb.com/top-apps/google/ser...
# 4796  https://www.similarweb.com/top-apps/google/ser...
# 4797  https://www.similarweb.com/top-apps/google/ser...
# 4798  https://www.similarweb.com/top-apps/google/ser...
# 4799  https://www.similarweb.com/top-apps/google/ser...
#
#                                  App             Publisher Category  \
# 0                      Facebook Lite  Meta Platforms, Inc.   Social
# 1                           Facebook  Meta Platforms, Inc.   Social
# 2                             TikTok      TikTok Pte. Ltd.   Social
# 3            TikTok Lite - Save Data      TikTok Pte. Ltd.   Social
# 4                          Instagram             Instagram   Social
# ...                              ...                   ...      ...
# 4795     Xviews - Video Chat&Hook Up         Wavechat Inc.   Social
# 4796  Chat Alternative — android app        Video Chat Alt   Social
# 4797  BeReal. Your friends for real.                BeReal   Social
# 4798       FollowMeter for Instagram           Followmeter   Social
# 4799      Monkey - random video chat           Monkey.cool   Social
#
#                              appId  Country alpha2Code  \
# 0                com.facebook.lite  algeria         DZ
# 1              com.facebook.katana  algeria         DZ
# 2         com.zhiliaoapp.musically  algeria         DZ
# 3         com.zhiliaoapp.musically  algeria         DZ
# 4            com.instagram.android  algeria         DZ
# ...                            ...      ...        ...
# 4795         com.waooolive.android   serbia         RS
# 4796  com.chatroullete.alternative   serbia         RS
# 4797                 com.bereal.ft   serbia         RS
# 4798    com.beakerapps.instameter2   serbia         RS
# 4799           cool.monkey.android   serbia         RS
#
#                                         google_play_url        reviews  \
# 0     https://play.google.com/store/apps/details?id=...  26.3M reviews
# 1     https://play.google.com/store/apps/details?id=...   145M reviews
# 2     https://play.google.com/store/apps/details?id=...  62.7M reviews
# 3     https://play.google.com/store/apps/details?id=...  62.7M reviews
# 4     https://play.google.com/store/apps/details?id=...   153M reviews
# ...                                                 ...            ...
# 4795  https://play.google.com/store/apps/details?id=...  12.7K reviews
# 4796  https://play.google.com/store/apps/details?id=...   135K reviews
# 4797  https://play.google.com/store/apps/details?id=...   291K reviews
# 4798  https://play.google.com/store/apps/details?id=...   144K reviews
# 4799  https://play.google.com/store/apps/details?id=...  59.4K reviews
#
#        five_star  four_star three_star   two_star    one_star
# 0      7,437,778    784,400    631,995    569,459  16,228,483
# 1     39,286,109  3,968,185  2,898,191  1,885,699  91,294,973
# 2     40,186,720  4,186,403  2,742,211  1,753,926  10,945,611
# 3     40,186,486  4,186,378  2,742,195  1,753,916  10,945,548
# 4     40,835,101  4,352,180  2,569,074  1,721,891  98,732,195
# ...          ...        ...        ...        ...         ...
# 4795      10,892        907          0          0         907
# 4796      53,523      7,646      6,241      4,993      54,772
# 4797     202,393     40,333      8,357     14,171      22,891
# 4798      73,741     17,470      3,860      3,860      38,801
# 4799      36,122      7,224          0      2,408      12,040
#
# [4800 rows x 14 columns]

# %% [markdown]
# # Clean data

# %% [markdown]
# ## Communications apps

# %%
communications_apps.dropna(subset=['reviews'], inplace=True)

# %%
# Assign "Email" category to apps containing "mail" or "email"
communications_apps.loc[communications_apps['App'].str.contains('mail|email', case=False), 'Category'] = 'Email'

# %%
communications_apps.loc[communications_apps['App'].str.contains('Voicemail', case=False), 'Category'] = 'Communication'

# %%
communications_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4647 entries, 0 to 4799
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   similarweb_url   4647 non-null   object
#  1   App              4647 non-null   object
#  2   Publisher        4647 non-null   object
#  3   Category         4647 non-null   object
#  4   appId            4647 non-null   object
#  5   Country          4647 non-null   object
#  6   alpha2Code       4647 non-null   object
#  7   google_play_url  4647 non-null   object
#  8   reviews          4647 non-null   object
#  9   five_star        4647 non-null   object
#  10  four_star        4647 non-null   object
#  11  three_star       4647 non-null   object
#  12  two_star         4647 non-null   object
#  13  one_star         4647 non-null   object
# dtypes: object(14)
# memory usage: 544.6+ KB

# %%
communications_apps[communications_apps.Category=='Email']['App'].unique()
# Out:
# array(['Email - Fast and Smart Mail', 'Temp Mail - Temporary Email',
#        'Mail.ru - Email App', 'All Email Connect', 'Gmail',
#        'Yahoo Mail – Organized Email', 'Proton Mail: Encrypted Email',
#        'mail.com: Mail app & Cloud', 'GMX - Mail & Cloud', 'K-9 Mail',
#        'Email App - Manage Your Inbox', 'Mail - All Email Accounts',
#        'ABV Mail', 'Yandex Mail', 'TypeApp mail - email app',
#        'FairEmail, privacy aware email', 'Email.cz', 'Centrum.cz mail',
#        'E-Mail for Outlook & Hotmail', 'SFR Mail',
#        'Laposte.net – Votre boîte mail', 'WEB.DE Mail & Cloud',
#        'Telekom Mail - E-Mail-Programm', '1&1 Mail',
#        'freenet Mail - E-Mail Postfach', 'freemail', 'Rediffmail',
#        'Libero Mail', 'Virgilio Mail - Email App', 'Tiscali Mail',
#        'Legalmail', 'Yahoo! Mail', 'App for Gmail SMS etc：CosmoSia',
#        'NAVER Mail', 'Daum Mail - 다음 메일', 'Gmail Go',
#        'Email for Hotmail & Outlook', 'Infomaniak Mail', 'BT Email',
#        'All Email Login', 'All Email Access: Mail Inbox',
#        'Login Mail For HotMail&Outlook'], dtype=object)

# %%
communications_apps['reviews'] = communications_apps['reviews'].apply(lambda x: x.replace(' reviews', '').replace('info', ''))

# %%
def convert_to_int(value):
    if 'M' in value:
        return int(float(value.replace('M', '')) * 1000000)
    elif 'K' in value:
        return int(float(value.replace('K', '')) * 1000)
    else:
        return int(value)

# %%
communications_apps['reviews'] = communications_apps['reviews'].apply(convert_to_int)

# %%
#communications_apps[communications_apps.reviews ==7]['google_play_url'][1244]
# Out:
# 'https://play.google.com/store/apps/details?id=lu.vii.mobile&hl=en_GB&gl=FI'

# %%
communications_apps['five_star'] = communications_apps['five_star'].apply(lambda x: int(x.replace(',', '')))
communications_apps['four_star'] = communications_apps['four_star'].apply(lambda x: int(x.replace(',', '')))
communications_apps['three_star'] = communications_apps['three_star'].apply(lambda x: int(x.replace(',', '')))
communications_apps['two_star'] = communications_apps['two_star'].apply(lambda x: int(x.replace(',', '')))
communications_apps['one_star'] = communications_apps['one_star'].apply(lambda x: int(x.replace(',', '')))

# %%
communications_apps['Country'] = communications_apps['Country'].apply(lambda x: x.replace('-', ' '))

# %%
communications_apps['Country'] = communications_apps['Country'].apply(lambda x: x.title())

# %%
communications_apps['Country'].unique()
# Out:
# array(['Algeria', 'Azerbaijan', 'Argentina', 'Australia', 'Bahrain',
#        'Armenia', 'Belgium', 'Bolivia Plurinational State Of', 'Brazil',
#        'Bulgaria', 'Belarus', 'Cambodia', 'Canada', 'Sri Lanka', 'Chile',
#        'Taiwan', 'Colombia', 'Costa Rica', 'Croatia', 'Czech Republic',
#        'Denmark', 'Dominican Republic', 'Ecuador', 'El Salvador',
#        'Finland', 'France', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Honduras', 'Hong Kong', 'Hungary', 'India', 'Indonesia',
#        'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Kazakhstan',
#        'Jordan', 'Kenya', 'Korea Republic Of', 'Kuwait', 'Kyrgyzstan',
#        'Latvia', 'Lithuania', 'Malaysia', 'Mexico', 'Moldova Republic Of',
#        'Oman', 'Nepal', 'Netherlands', 'New Zealand', 'Nigeria', 'Norway',
#        'Pakistan', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Qatar', 'Romania', 'Russian Federation',
#        'Saudi Arabia', 'Singapore', 'Slovakia', 'Vietnam', 'Slovenia',
#        'South Africa', 'Spain', 'Sweden', 'Switzerland', 'Thailand',
#        'Trinidad And Tobago', 'United Arab Emirates', 'Tunisia', 'Turkey',
#        'Ukraine', 'Macedonia The Former Yugoslav Republic Of', 'Egypt',
#        'United Kingdom', 'Tanzania United Republic Of', 'United States',
#        'Uruguay', 'Uzbekistan', 'Venezuela Bolivarian Republic Of',
#        'Austria', 'Bangladesh', 'Bosnia And Herzegovina', 'Morocco',
#        'Puerto Rico', 'Serbia'], dtype=object)

# %%
weights = {
    'five_star': 5,
    'four_star': 4,
    'three_star': 3,
    'two_star': 2,
    'one_star': 1
}

# %%
star_rating_columns = ['five_star', 'four_star', 'three_star', 'two_star', 'one_star']

# Calculate the weighted sum for each row based on star rating columns
communications_apps['weighted_sum'] = communications_apps.apply(lambda row: sum(row[star] * weights[star] for star in star_rating_columns), axis=1)

# %%
# Calculate the total number of reviews
total_reviews = communications_apps[star_rating_columns].sum(axis=1)

# %%
# Calculate the score out of five
communications_apps['score_out_of_five'] = communications_apps['weighted_sum'] / total_reviews

# %%
communications_apps
# Out:
#                                          similarweb_url  \
# 0     https://www.similarweb.com/top-apps/google/alg...
# 1     https://www.similarweb.com/top-apps/google/alg...
# 2     https://www.similarweb.com/top-apps/google/alg...
# 3     https://www.similarweb.com/top-apps/google/alg...
# 4     https://www.similarweb.com/top-apps/google/alg...
# ...                                                 ...
# 4795  https://www.similarweb.com/top-apps/google/ser...
# 4796  https://www.similarweb.com/top-apps/google/ser...
# 4797  https://www.similarweb.com/top-apps/google/ser...
# 4798  https://www.similarweb.com/top-apps/google/ser...
# 4799  https://www.similarweb.com/top-apps/google/ser...
#
#                                  App  \
# 0                 WhatsApp Messenger
# 1                          Messenger
# 2                           Telegram
# 3                           Snapchat
# 4     Truecaller: Identify Caller ID
# ...                              ...
# 4795   Smart Watch app - BT notifier
# 4796    Botim - Video and Voice Call
# 4797    Opera Mini: Fast Web Browser
# 4798        Opera GX: Gaming Browser
# 4799       Mail - All Email Accounts
#
#                                      Publisher       Category  \
# 0                                 WhatsApp LLC  Communication
# 1                         Meta Platforms, Inc.  Communication
# 2                              Telegram FZ-LLC  Communication
# 3                                     Snap Inc  Communication
# 4                                   Truecaller  Communication
# ...                                        ...            ...
# 4795                            Flying Phoenix  Communication
# 4796           Algento Cloud Computing Limited  Communication
# 4797                                     Opera  Communication
# 4798                                     Opera  Communication
# 4799  Amobear Application - Diavostar PTE. LTD          Email
#
#                                             appId  Country alpha2Code  \
# 0                                    com.whatsapp  Algeria         DZ
# 1                               com.facebook.orca  Algeria         DZ
# 2                          org.telegram.messenger  Algeria         DZ
# 3                            com.snapchat.android  Algeria         DZ
# 4                                  com.truecaller  Algeria         DZ
# ...                                           ...      ...        ...
# 4795  com.smartwatch.bluetooth.sync.notifications   Serbia         RS
# 4796                          im.thebot.messenger   Serbia         RS
# 4797                        com.opera.mini.native   Serbia         RS
# 4798                                 com.opera.gx   Serbia         RS
# 4799        com.quickemail.quicklogin.emailonline   Serbia         RS
#
#                                         google_play_url    reviews  five_star  \
# 0     https://play.google.com/store/apps/details?id=...  190000000  124642625
# 1     https://play.google.com/store/apps/details?id=...   89100000   46053579
# 2     https://play.google.com/store/apps/details?id=...   13900000    9333940
# 3     https://play.google.com/store/apps/details?id=...   35200000   15467638
# 4     https://play.google.com/store/apps/details?id=...   21200000   15974108
# ...                                                 ...        ...        ...
# 4795  https://play.google.com/store/apps/details?id=...     210000     161181
# 4796  https://play.google.com/store/apps/details?id=...    1140000     798697
# 4797  https://play.google.com/store/apps/details?id=...    9130000    7209486
# 4798  https://play.google.com/store/apps/details?id=...     198000     153543
# 4799  https://play.google.com/store/apps/details?id=...       7370       5806
#
#       four_star  three_star  two_star  one_star  weighted_sum  \
# 0      15062961    10741084   7008012  29181989     758886234
# 1       4949839     3550516   2744035  27834686     294041555
# 2       1028448      697534    351536   2075800      55654966
# 3       1874281     1275746    792059  13867570     104114240
# 4       1847402     1139970    556583   1471526      93264750
# ...         ...         ...       ...       ...           ...
# 4795      23739        9995      3748      4997        943339
# 4796     156109       87130     10891     65347       4966440
# 4797     765358      274017    160630    406301      40658474
# 4798      20823        3763      5519      5519        878853
# 4799        387         774         0       387         33287
#
#       score_out_of_five
# 0              4.066115
# 1              3.453922
# 2              4.126485
# 3              3.128687
# 4              4.443381
# ...                 ...
# 4795           4.631931
# 4796           4.441563
# 4797           4.612005
# 4798           4.645911
# 4799           4.526380
#
# [4647 rows x 16 columns]

# %% [markdown]
# ## Social apps

# %%
social_apps.dropna(subset=['reviews'], inplace=True)

# %%
social_apps['reviews'] = social_apps['reviews'].apply(lambda x: x.replace(' reviews', '').replace('info', ''))

# %%
social_apps['reviews'] = social_apps['reviews'].apply(convert_to_int)

# %%
social_apps['five_star'] = social_apps['five_star'].apply(lambda x: int(x.replace(',', '')))
social_apps['four_star'] = social_apps['four_star'].apply(lambda x: int(x.replace(',', '')))
social_apps['three_star'] = social_apps['three_star'].apply(lambda x: int(x.replace(',', '')))
social_apps['two_star'] = social_apps['two_star'].apply(lambda x: int(x.replace(',', '')))
social_apps['one_star'] = social_apps['one_star'].apply(lambda x: int(x.replace(',', '')))

# %%
social_apps['Country'] = social_apps['Country'].apply(lambda x: x.replace('-', ' '))

social_apps['Country'] = social_apps['Country'].apply(lambda x: x.title())

# %%
# Calculate the weighted sum for each row based on star rating columns
social_apps['weighted_sum'] = social_apps.apply(lambda row: sum(row[star] * weights[star] for star in star_rating_columns), axis=1)


# Calculate the total number of reviews
total_reviews = social_apps[star_rating_columns].sum(axis=1)

# Calculate the score out of five
social_apps['score_out_of_five'] = social_apps['weighted_sum'] / total_reviews

# %%
social_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4587 entries, 0 to 4799
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   similarweb_url     4587 non-null   object
#  1   App                4587 non-null   object
#  2   Publisher          4587 non-null   object
#  3   Category           4587 non-null   object
#  4   appId              4587 non-null   object
#  5   Country            4587 non-null   object
#  6   alpha2Code         4587 non-null   object
#  7   google_play_url    4587 non-null   object
#  8   reviews            4587 non-null   int64
#  9   five_star          4587 non-null   int64
#  10  four_star          4587 non-null   int64
#  11  three_star         4587 non-null   int64
#  12  two_star           4587 non-null   int64
#  13  one_star           4587 non-null   int64
#  14  weighted_sum       4587 non-null   int64
#  15  score_out_of_five  4587 non-null   float64
# dtypes: float64(1), int64(7), object(8)
# memory usage: 609.2+ KB

# %%
social_apps
# Out:
#                                          similarweb_url  \
# 0     https://www.similarweb.com/top-apps/google/alg...
# 1     https://www.similarweb.com/top-apps/google/alg...
# 2     https://www.similarweb.com/top-apps/google/alg...
# 3     https://www.similarweb.com/top-apps/google/alg...
# 4     https://www.similarweb.com/top-apps/google/alg...
# ...                                                 ...
# 4795  https://www.similarweb.com/top-apps/google/ser...
# 4796  https://www.similarweb.com/top-apps/google/ser...
# 4797  https://www.similarweb.com/top-apps/google/ser...
# 4798  https://www.similarweb.com/top-apps/google/ser...
# 4799  https://www.similarweb.com/top-apps/google/ser...
#
#                                  App             Publisher Category  \
# 0                      Facebook Lite  Meta Platforms, Inc.   Social
# 1                           Facebook  Meta Platforms, Inc.   Social
# 2                             TikTok      TikTok Pte. Ltd.   Social
# 3            TikTok Lite - Save Data      TikTok Pte. Ltd.   Social
# 4                          Instagram             Instagram   Social
# ...                              ...                   ...      ...
# 4795     Xviews - Video Chat&Hook Up         Wavechat Inc.   Social
# 4796  Chat Alternative — android app        Video Chat Alt   Social
# 4797  BeReal. Your friends for real.                BeReal   Social
# 4798       FollowMeter for Instagram           Followmeter   Social
# 4799      Monkey - random video chat           Monkey.cool   Social
#
#                              appId  Country alpha2Code  \
# 0                com.facebook.lite  Algeria         DZ
# 1              com.facebook.katana  Algeria         DZ
# 2         com.zhiliaoapp.musically  Algeria         DZ
# 3         com.zhiliaoapp.musically  Algeria         DZ
# 4            com.instagram.android  Algeria         DZ
# ...                            ...      ...        ...
# 4795         com.waooolive.android   Serbia         RS
# 4796  com.chatroullete.alternative   Serbia         RS
# 4797                 com.bereal.ft   Serbia         RS
# 4798    com.beakerapps.instameter2   Serbia         RS
# 4799           cool.monkey.android   Serbia         RS
#
#                                         google_play_url    reviews  five_star  \
# 0     https://play.google.com/store/apps/details?id=...   26300000    7437778
# 1     https://play.google.com/store/apps/details?id=...  145000000   39286109
# 2     https://play.google.com/store/apps/details?id=...   62700000   40186720
# 3     https://play.google.com/store/apps/details?id=...   62700000   40186486
# 4     https://play.google.com/store/apps/details?id=...  153000000   40835101
# ...                                                 ...        ...        ...
# 4795  https://play.google.com/store/apps/details?id=...      12700      10892
# 4796  https://play.google.com/store/apps/details?id=...     135000      53523
# 4797  https://play.google.com/store/apps/details?id=...     291000     202393
# 4798  https://play.google.com/store/apps/details?id=...     144000      73741
# 4799  https://play.google.com/store/apps/details?id=...      59400      36122
#
#       four_star  three_star  two_star  one_star  weighted_sum  \
# 0        784400      631995    569459  16228483      59589876
# 1       3968185     2898191   1885699  91294973     316064229
# 2       4186403     2742211   1753926  10945611     240359308
# 3       4186378     2742195   1753916  10945548     240357907
# 4       4352180     2569074   1721891  98732195     331467424
# ...         ...         ...       ...       ...           ...
# 4795        907           0         0       907         58995
# 4796       7646        6241      4993     54772        381680
# 4797      40333        8357     14171     22891       1249601
# 4798      17470        3860      3860     38801        496686
# 4799       7224           0      2408     12040        226362
#
#       score_out_of_five
# 0              2.323001
# 1              2.268406
# 2              4.018387
# 3              4.018387
# 4              2.236465
# ...                 ...
# 4795           4.643082
# 4796           3.001219
# 4797           4.336709
# 4798           3.606177
# 4799           3.916704
#
# [4587 rows x 16 columns]

# %% [markdown]
# ## Email apps

# %%
email_apps['reviews'] = email_apps['reviews'].apply(lambda x: x.replace(' reviews', '').replace('info', ''))

email_apps['reviews'] = email_apps['reviews'].apply(convert_to_int)

# %%
email_apps['five_star'] = email_apps['five_star'].apply(lambda x: int(x.replace(',', '')))
email_apps['four_star'] = email_apps['four_star'].apply(lambda x: int(x.replace(',', '')))
email_apps['three_star'] = email_apps['three_star'].apply(lambda x: int(x.replace(',', '')))
email_apps['two_star'] = email_apps['two_star'].apply(lambda x: int(x.replace(',', '')))
email_apps['one_star'] = email_apps['one_star'].apply(lambda x: int(x.replace(',', '')))

# %%
email_apps['Country'] = email_apps['Country'].apply(lambda x: x.replace('-', ' '))

email_apps['Country'] = email_apps['Country'].apply(lambda x: x.title())

# %%
# Calculate the weighted sum for each row based on star rating columns
email_apps['weighted_sum'] = email_apps.apply(lambda row: sum(row[star] * weights[star] for star in star_rating_columns), axis=1)


# Calculate the total number of reviews
total_reviews = email_apps[star_rating_columns].sum(axis=1)

# Calculate the score out of five
email_apps['score_out_of_five'] = email_apps['weighted_sum'] / total_reviews

# %%
email_apps
# Out:
#       Country alpha2Code                             App  \
# 0     Algeria         DZ     Email - Fast and Smart Mail
# 1     Algeria         DZ     Temp Mail - Temporary Email
# 2     Algeria         DZ             Mail.ru - Email App
# 3     Algeria         DZ               All Email Connect
# 4     Algeria         DZ                           Gmail
# ...       ...        ...                             ...
# 2609   Serbia         RS                     Libero Mail
# 2610   Serbia         RS                        Gmail Go
# 2611   Serbia         RS     Email for Hotmail & Outlook
# 2612   Serbia         RS    All Email Access: Mail Inbox
# 2613   Serbia         RS  Login Mail For HotMail&Outlook
#
#                                      Publisher  \
# 0                     AMOBEAR TECHNOLOGY GROUP
# 1                             Privatix Limited
# 2                                Mail.Ru Group
# 3                            AI Email & Access
# 4                                   Google LLC
# ...                                        ...
# 2609                       Italiaonline S.p.A.
# 2610                                Google LLC
# 2611  Amobear Application - Diavostar PTE. LTD
# 2612                            Appsbuyout Dev
# 2613                  AMOBEAR TECHNOLOGY GROUP
#
#                                          appId  \
# 0     com.fastsigninemail.securemail.bestemail
# 1                                 com.tempmail
# 2                              ru.mail.mailapp
# 3                com.mail.inbox.allemailaccess
# 4                        com.google.android.gm
# ...                                        ...
# 2609                      it.italiaonline.mail
# 2610                com.google.android.gm.lite
# 2611              com.microsoft.office.outlook
# 2612                 info.myapp.allemailaccess
# 2613       com.emailonline.officemail.amoemail
#
#                                         google_play_url   reviews  five_star  \
# 0     https://play.google.com/store/apps/details?id=...     83500      55756
# 1     https://play.google.com/store/apps/details?id=...    325000     231420
# 2     https://play.google.com/store/apps/details?id=...   3140000    2135250
# 3     https://play.google.com/store/apps/details?id=...     10600       4517
# 4     https://play.google.com/store/apps/details?id=...  13000000    8493138
# ...                                                 ...       ...        ...
# 2609  https://play.google.com/store/apps/details?id=...     99500      52183
# 2610  https://play.google.com/store/apps/details?id=...    145000      95879
# 2611  https://play.google.com/store/apps/details?id=...   9480000    7789110
# 2612  https://play.google.com/store/apps/details?id=...     62300      46422
# 2613  https://play.google.com/store/apps/details?id=...     26500      13702
#
#       four_star  three_star  two_star  one_star  weighted_sum  \
# 0         11046        3945       789      7890        344267
# 1         27484       18983     10554     31734       1376827
# 2        386820      154728    139255    201146      13167370
# 3          4517           0         0      1505         42158
# 4       1030231      636912    372862   1925536      51168610
# ...         ...         ...       ...       ...           ...
# 2609      34789           0         0      8697        408768
# 2610      11279        8459      4229     19739        578085
# 2611    1056052      115354     71915    144314      43803964
# 2612      13754           0         0      1719        288845
# 2613       3425        2283      1141      4567         95908
#
#       score_out_of_five
# 0              4.334437
# 1              4.300233
# 2              4.364104
# 3              4.000190
# 4              4.107065
# ...                 ...
# 2609           4.272732
# 2610           4.141455
# 2611           4.773366
# 2612           4.666694
# 2613           3.818298
#
# [2614 rows x 14 columns]

# %% [markdown]
# # Finalise the data into tabs

# %% [markdown]
# ## World Map - Loved Email

# %% [markdown]
# World Map - Loved Email: isolate the highest rated email app by country

# %%
# Filter the dataframe to include only rows where Category is 'Email'
loved_email = email_apps.copy()

# Group by 'Country' and find the index of the row with the highest 'score_out_of_five' in each group
idx = loved_email.groupby('Country')['score_out_of_five'].idxmax()

# Use the index to get the corresponding rows
loved_email = loved_email.loc[idx]

# %%
loved_email
# Out:
#                                Country alpha2Code  \
# 19                             Algeria         DZ
# 56                           Argentina         AR
# 142                            Armenia         AM
# 84                           Australia         AU
# 2453                           Austria         AT
# ...                                ...        ...
# 2359                     United States         US
# 2395                           Uruguay         UY
# 2411                        Uzbekistan         UZ
# 2429  Venezuela Bolivarian Republic Of         VE
# 1869                           Vietnam         VN
#
#                                  App  \
# 19                        NAVER Mail
# 56                       Yandex Mail
# 142              Mail.ru - Email App
# 84    FairEmail, privacy aware email
# 2453  FairEmail, privacy aware email
# ...                              ...
# 2359  FairEmail, privacy aware email
# 2395                        1&1 Mail
# 2411                     Yandex Mail
# 2429                     Yandex Mail
# 1869  freenet Mail - E-Mail Postfach
#
#                                        Publisher  \
# 19                                   NAVER Corp.
# 56    Direct Cursus Computer Systems Trading LLC
# 142                                Mail.Ru Group
# 84                  Marcel Bokhorst, FairCode BV
# 2453                Marcel Bokhorst, FairCode BV
# ...                                          ...
# 2359                Marcel Bokhorst, FairCode BV
# 2395                            1&1 Telecom GmbH
# 2411  Direct Cursus Computer Systems Trading LLC
# 2429  Direct Cursus Computer Systems Trading LLC
# 1869                             freenet.de GmbH
#
#                                       appId  \
# 19                     com.nhn.android.mail
# 56                           ru.yandex.mail
# 142                         ru.mail.mailapp
# 84                        eu.faircode.email
# 2453                      eu.faircode.email
# ...                                     ...
# 2359                      eu.faircode.email
# 2395  com.oneandone.ciso.mobile.app.android
# 2411                         ru.yandex.mail
# 2429                         ru.yandex.mail
# 1869                        de.freenet.mail
#
#                                         google_play_url  reviews  five_star  \
# 19    https://play.google.com/store/apps/details?id=...    22000      21370
# 56    https://play.google.com/store/apps/details?id=...   552000     455929
# 142   https://play.google.com/store/apps/details?id=...  3140000    2706779
# 84    https://play.google.com/store/apps/details?id=...    26500      21238
# 2453  https://play.google.com/store/apps/details?id=...    26500      23150
# ...                                                 ...      ...        ...
# 2359  https://play.google.com/store/apps/details?id=...    26500      20365
# 2395  https://play.google.com/store/apps/details?id=...    10100       7872
# 2411  https://play.google.com/store/apps/details?id=...   552000     492925
# 2429  https://play.google.com/store/apps/details?id=...   552000     460464
# 1869  https://play.google.com/store/apps/details?id=...    22300      20317
#
#       four_star  three_star  two_star  one_star  weighted_sum  \
# 19            0           0         0         0        106850
# 56        61859           0         0      4582       2531663
# 142      187470       45758     15849     62889      14515636
# 84         1639         213         0       712        114097
# 2453          0         230         0       461        116901
# ...         ...         ...       ...       ...           ...
# 2359       1793         660       188       849        112202
# 2395       1574           0         0         0         45656
# 2411      16720        6137         0      8254       2558170
# 2429      51366        3669      3669         0       2526129
# 1869          0           0         0         0        101585
#
#       score_out_of_five
# 19             5.000000
# 56             4.846494
# 142            4.808500
# 84             4.793589
# 2453           4.903360
# ...                 ...
# 2359           4.703500
# 2395           4.833369
# 2411           4.881668
# 2429           4.865726
# 1869           5.000000
#
# [96 rows x 14 columns]

# %% [markdown]
# ## World Map - Hated Email

# %% [markdown]
# World Map - Hated Email: isolate the lowest rated email app by country

# %%
hated_email = email_apps.copy()

idx = hated_email.groupby('Country')['score_out_of_five'].idxmin()

hated_email = hated_email.loc[idx]

# %%
hated_email
# Out:
#                                Country alpha2Code  \
# 17                             Algeria         DZ
# 60                           Argentina         AR
# 162                            Armenia         AM
# 90                           Australia         AU
# 2450                           Austria         AT
# ...                                ...        ...
# 2381                     United States         US
# 2385                           Uruguay         UY
# 2410                        Uzbekistan         UZ
# 2432  Venezuela Bolivarian Republic Of         VE
# 1871                           Vietnam         VN
#
#                                  App  \
# 17                          1&1 Mail
# 60                          1&1 Mail
# 162   freenet Mail - E-Mail Postfach
# 90    freenet Mail - E-Mail Postfach
# 2450                        ABV Mail
# ...                              ...
# 2381  Login Mail For HotMail&Outlook
# 2385               All Email Connect
# 2410       Mail - All Email Accounts
# 2432                     Libero Mail
# 1871                     Libero Mail
#
#                                      Publisher  \
# 17                            1&1 Telecom GmbH
# 60                            1&1 Telecom GmbH
# 162                            freenet.de GmbH
# 90                             freenet.de GmbH
# 2450                             „Нет Инфо” АД
# ...                                        ...
# 2381                  AMOBEAR TECHNOLOGY GROUP
# 2385                         AI Email & Access
# 2410  Amobear Application - Diavostar PTE. LTD
# 2432                       Italiaonline S.p.A.
# 1871                       Italiaonline S.p.A.
#
#                                       appId  \
# 17    com.oneandone.ciso.mobile.app.android
# 60    com.oneandone.ciso.mobile.app.android
# 162                         de.freenet.mail
# 90                          de.freenet.mail
# 2450                  bg.abv.andro.emailapp
# ...                                     ...
# 2381    com.emailonline.officemail.amoemail
# 2385          com.mail.inbox.allemailaccess
# 2410  com.quickemail.quicklogin.emailonline
# 2432                   it.italiaonline.mail
# 1871                   it.italiaonline.mail
#
#                                         google_play_url  reviews  five_star  \
# 17    https://play.google.com/store/apps/details?id=...    10100       4408
# 60    https://play.google.com/store/apps/details?id=...    10100       4723
# 162   https://play.google.com/store/apps/details?id=...    22300       2097
# 90    https://play.google.com/store/apps/details?id=...    22300       2539
# 2450  https://play.google.com/store/apps/details?id=...    14100       5132
# ...                                                 ...      ...        ...
# 2381  https://play.google.com/store/apps/details?id=...    26500       7095
# 2385  https://play.google.com/store/apps/details?id=...    10600       6626
# 2410  https://play.google.com/store/apps/details?id=...     7590       3311
# 2432  https://play.google.com/store/apps/details?id=...    99500      19134
# 1871  https://play.google.com/store/apps/details?id=...    99500      31890
#
#       four_star  three_star  two_star  one_star  weighted_sum  \
# 17         1889         629         0      2519         34002
# 60          787           0       787      3149         31486
# 162         900        1366      2150     13802         36285
# 90            0        2539         0     12698         33010
# 2450        810         540       810      5942         38082
# ...         ...         ...       ...       ...           ...
# 2381       1493        2040      2451     12013         64482
# 2385       1204        1204         0      1506         43064
# 2410       1419         946       946       946         27907
# 2432      19134       19134     19134     19134        287010
# 1871      10630       10630         0     42520        276380
#
#       score_out_of_five
# 17             3.600000
# 60             3.333263
# 162            1.786119
# 90             1.856998
# 2450           2.877588
# ...                 ...
# 2381           2.569823
# 2385           4.085769
# 2410           3.687500
# 2432           3.000000
# 1871           2.888889
#
# [96 rows x 14 columns]

# %% [markdown]
# ## World Map - Loved Communications

# %%
# Filter the dataframe to include only rows where Category is 'Email'
loved_communication = communications_apps[communications_apps['Category'] == 'Communication']

# Group by 'Country' and find the index of the row with the highest 'score_out_of_five' in each group
idx = loved_communication.groupby('Country')['score_out_of_five'].idxmax()

# Use the index to get the corresponding rows
loved_communication = loved_communication.loc[idx]
loved_communication
# Out:
#                                          similarweb_url  \
# 21    https://www.similarweb.com/top-apps/google/alg...
# 125   https://www.similarweb.com/top-apps/google/arg...
# 270   https://www.similarweb.com/top-apps/google/arm...
# 161   https://www.similarweb.com/top-apps/google/aus...
# 4510  https://www.similarweb.com/top-apps/google/aus...
# ...                                                 ...
# 4323  https://www.similarweb.com/top-apps/google/uni...
# 4371  https://www.similarweb.com/top-apps/google/uru...
# 4422  https://www.similarweb.com/top-apps/google/uzb...
# 4471  https://www.similarweb.com/top-apps/google/ven...
# 3520  https://www.similarweb.com/top-apps/google/vie...
#
#                                  App       Publisher       Category  \
# 21    Brave Private Web Browser, VPN  Brave Software  Communication
# 125       Sticker Maker for WhatsApp   Trusted Tools  Communication
# 270    Speak and Translate Languages   Learning Easy  Communication
# 161   Brave Private Web Browser, VPN  Brave Software  Communication
# 4510                           spusu   Mass Response  Communication
# ...                              ...             ...            ...
# 4323           Opera browser with AI           Opera  Communication
# 4371      Sticker Maker for WhatsApp   Trusted Tools  Communication
# 4422  imo HD - Video Calls and Chats          imo.im  Communication
# 4471       Whats Dual - Whatscan App        360 Tool  Communication
# 3520  Truecaller: Identify Caller ID      Truecaller  Communication
#
#                                                   appId  \
# 21                                    com.brave.browser
# 125   customstickermaker.whatsappstickers.personalst...
# 270                     com.translate.talkingtranslator
# 161                                   com.brave.browser
# 4510                           com.massresponse.spusuuk
# ...                                                 ...
# 4323                                  com.opera.browser
# 4371  customstickermaker.whatsappstickers.personalst...
# 4422                              com.imo.android.imous
# 4471              whatsapp.web.whatscan.whatsweb.qrscan
# 3520                                     com.truecaller
#
#                                Country alpha2Code  \
# 21                             Algeria         DZ
# 125                          Argentina         AR
# 270                            Armenia         AM
# 161                          Australia         AU
# 4510                           Austria         AT
# ...                                ...        ...
# 4323                     United States         US
# 4371                           Uruguay         UY
# 4422                        Uzbekistan         UZ
# 4471  Venezuela Bolivarian Republic Of         VE
# 3520                           Vietnam         VN
#
#                                         google_play_url   reviews  five_star  \
# 21    https://play.google.com/store/apps/details?id=...   1850000    1338242
# 125   https://play.google.com/store/apps/details?id=...    273000     249763
# 270   https://play.google.com/store/apps/details?id=...     99600      79887
# 161   https://play.google.com/store/apps/details?id=...   1850000    1457490
# 4510  https://play.google.com/store/apps/details?id=...        24         24
# ...                                                 ...       ...        ...
# 4323  https://play.google.com/store/apps/details?id=...   4660000    3773521
# 4371  https://play.google.com/store/apps/details?id=...    273000     243608
# 4422  https://play.google.com/store/apps/details?id=...    130000     127319
# 4471  https://play.google.com/store/apps/details?id=...    104000      93085
# 3520  https://play.google.com/store/apps/details?id=...  21200000   18441942
#
#       four_star  three_star  two_star  one_star  weighted_sum  \
# 21       290965      102926     15834     37607       8233123
# 125       12358        3821       731      1544       1312716
# 270       11085        3032       785      2664        457105
# 161      248063       29922     18124     32066       8437782
# 4510          0           0         0         0           120
# ...         ...         ...       ...       ...           ...
# 4323     240542       68895     51675    172262      20312070
# 4371      15743        2485      2485      2485       1295922
# 4422          0           0         0         0        636595
# 4471       4621        1760       880       880        491829
# 3520    1746874      354106    109623    338333     100817103
#
#       score_out_of_five
# 21             4.610911
# 125            4.894231
# 270            4.690517
# 161            4.725288
# 4510           5.000000
# ...                 ...
# 4323           4.716175
# 4371           4.857170
# 4422           5.000000
# 4471           4.858722
# 3520           4.802901
#
# [96 rows x 16 columns]

# %% [markdown]
# ## World Map - Hated Communications

# %%
# Filter the dataframe to include only rows where Category is 'Email'
hated_communication = communications_apps[communications_apps['Category'] == 'Communication']

# Group by 'Country' and find the index of the row with the highest 'score_out_of_five' in each group
idx = hated_communication.groupby('Country')['score_out_of_five'].idxmin()

# Use the index to get the corresponding rows
hated_communication = hated_communication.loc[idx]
hated_communication
# Out:
#                                          similarweb_url  \
# 3     https://www.similarweb.com/top-apps/google/alg...
# 134   https://www.similarweb.com/top-apps/google/arg...
# 264   https://www.similarweb.com/top-apps/google/arm...
# 180   https://www.similarweb.com/top-apps/google/aus...
# 4534  https://www.similarweb.com/top-apps/google/aus...
# ...                                                 ...
# 4320  https://www.similarweb.com/top-apps/google/uni...
# 4361  https://www.similarweb.com/top-apps/google/uru...
# 4441  https://www.similarweb.com/top-apps/google/uzb...
# 4466  https://www.similarweb.com/top-apps/google/ven...
# 3509  https://www.similarweb.com/top-apps/google/vie...
#
#                             App                  Publisher       Category  \
# 3                      Snapchat                   Snap Inc  Communication
# 134                      Voissy  Andromeda Smart Softwares  Communication
# 264                      WeChat       WeChat International  Communication
# 180                  ALDImobile           MEDION_Australia  Communication
# 4534          Mein MTEL Austria                   MTEL APP  Communication
# ...                         ...                        ...            ...
# 4320  T-Mobile Visual Voicemail               T-Mobile USA  Communication
# 4361                 Magic TVHD                alex nicole  Communication
# 4441           4G LTE Mode only     AlphaBrain Apps Studio  Communication
# 4466                     Voissy  Andromeda Smart Softwares  Communication
# 3509                   Snapchat                   Snap Inc  Communication
#
#                                      appId                           Country  \
# 3                     com.snapchat.android                           Algeria
# 134   andromeda.smart.softwares.com.voissy                         Argentina
# 264                         com.tencent.mm                           Armenia
# 180                    au.com.aldi.android                         Australia
# 4534                      at.mtel.selfcare                           Austria
# ...                                    ...                               ...
# 4320           com.tmobile.vvm.application                     United States
# 4361                       com.m.magictvhd                           Uruguay
# 4441        com.four4glte.only.networkmode                        Uzbekistan
# 4466  andromeda.smart.softwares.com.voissy  Venezuela Bolivarian Republic Of
# 3509                  com.snapchat.android                           Vietnam
#
#      alpha2Code                                    google_play_url   reviews  \
# 3            DZ  https://play.google.com/store/apps/details?id=...  35200000
# 134          AR  https://play.google.com/store/apps/details?id=...      1910
# 264          AM  https://play.google.com/store/apps/details?id=...   6210000
# 180          AU  https://play.google.com/store/apps/details?id=...      3410
# 4534         AT  https://play.google.com/store/apps/details?id=...       353
# ...         ...                                                ...       ...
# 4320         US  https://play.google.com/store/apps/details?id=...     86500
# 4361         UY  https://play.google.com/store/apps/details?id=...      1120
# 4441         UZ  https://play.google.com/store/apps/details?id=...      7370
# 4466         VE  https://play.google.com/store/apps/details?id=...      1910
# 3509         VN  https://play.google.com/store/apps/details?id=...  35200000
#
#       five_star  four_star  three_star  two_star  one_star  weighted_sum  \
# 3      15467638    1874281     1275746    792059  13867570     104114240
# 134         439         48          97        97      1171          4043
# 264     3199228     402682      290857    210738   1828608      20729523
# 180         884        273         168       299      1639          8253
# 4534         96         17           9        13       208           809
# ...         ...        ...         ...       ...       ...           ...
# 4320      30064       6138        4922      5763     39116        240280
# 4361         55          0          55         0       221           661
# 4441       4011        200         300       401      2406         24963
# 4466        421         42          84       168      1138          3999
# 3509    3501283     769641      599304    281290  28126687      51072158
#
#       score_out_of_five
# 3              3.128687
# 134            2.183045
# 264            3.494459
# 180            2.529268
# 4534           2.358601
# ...                 ...
# 4320           2.793856
# 4361           1.996979
# 4441           3.411178
# 4466           2.158122
# 3509           1.534703
#
# [96 rows x 16 columns]

# %% [markdown]
# ## World Map - Loved Social Media

# %% [markdown]
# World Map - Loved Social Media: isolate the highest rated social media app by country

# %%
# Group by 'Country' and find the index of the row with the highest 'score_out_of_five' in each group
idx = social_apps.groupby('Country')['score_out_of_five'].idxmax()

# Use the index to get the corresponding rows
loved_social = social_apps.loc[idx]
loved_social
# Out:
#                                          similarweb_url  \
# 47    https://www.similarweb.com/top-apps/google/alg...
# 141   https://www.similarweb.com/top-apps/google/arg...
# 277   https://www.similarweb.com/top-apps/google/arm...
# 184   https://www.similarweb.com/top-apps/google/aus...
# 4549  https://www.similarweb.com/top-apps/google/aus...
# ...                                                 ...
# 4319  https://www.similarweb.com/top-apps/google/uni...
# 4379  https://www.similarweb.com/top-apps/google/uru...
# 4429  https://www.similarweb.com/top-apps/google/uzb...
# 4483  https://www.similarweb.com/top-apps/google/ven...
# 3532  https://www.similarweb.com/top-apps/google/vie...
#
#                                  App             Publisher Category  \
# 47                 MeYo : be friends           MeYo Studio   Social
# 141           Zeetok - Meet and Chat          ZeetokSocial   Social
# 277   Video downloader - Story Saver  ETM Video Downloader   Social
# 184         Harmonic for Hacker News     Simon Halvdansson   Social
# 4549         My TEDi Mitarbeiter-App    TEDi GmbH & Co. KG   Social
# ...                              ...                   ...      ...
# 4319                          sendit   iconic hearts, inc.   Social
# 4379  Status Saver: Video Downloader        BlueLine. Tech   Social
# 4429  Video downloader - Story Saver  ETM Video Downloader   Social
# 4483  Video downloader - Story Saver  ETM Video Downloader   Social
# 3532  Golike - Kiếm Tiền Online Từ M               mSocial   Social
#
#                                           appId  \
# 47                                com.pita.oyem
# 141                        com.zeetok.videochat
# 277   instagram.video.downloader.story.saver.ig
# 184                com.simon.harmonichackernews
# 4549               com.tediinternal.employeeapp
# ...                                         ...
# 4319                     com.fullsenders.sendit
# 4379           video.downloader.videodownloader
# 4429  instagram.video.downloader.story.saver.ig
# 4483  instagram.video.downloader.story.saver.ig
# 3532          com.google.android.apps.paidtasks
#
#                                Country alpha2Code  \
# 47                             Algeria         DZ
# 141                          Argentina         AR
# 277                            Armenia         AM
# 184                          Australia         AU
# 4549                           Austria         AT
# ...                                ...        ...
# 4319                     United States         US
# 4379                           Uruguay         UY
# 4429                        Uzbekistan         UZ
# 4483  Venezuela Bolivarian Republic Of         VE
# 3532                           Vietnam         VN
#
#                                         google_play_url  reviews  five_star  \
# 47    https://play.google.com/store/apps/details?id=...   388000     345446
# 141   https://play.google.com/store/apps/details?id=...    94800      91417
# 277   https://play.google.com/store/apps/details?id=...   174000     159919
# 184   https://play.google.com/store/apps/details?id=...      779        620
# 4549  https://play.google.com/store/apps/details?id=...      111        107
# ...                                                 ...      ...        ...
# 4319  https://play.google.com/store/apps/details?id=...   616000     507266
# 4379  https://play.google.com/store/apps/details?id=...  2029999    1830865
# 4429  https://play.google.com/store/apps/details?id=...   174000     169617
# 4483  https://play.google.com/store/apps/details?id=...   174000     167492
# 3532  https://play.google.com/store/apps/details?id=...  3570000    3148808
#
#       four_star  three_star  two_star  one_star  weighted_sum  \
# 47        12563       10452      4117     10452       1827524
# 141         517        1409       695       160        464930
# 277        7535        1736       908      2674        839433
# 184         124           0         0         0          3596
# 4549          0           0         0         0           535
# ...         ...         ...       ...       ...           ...
# 4319      59207       19459      5217      7138       2849107
# 4379     101670       14974         0     14974       9620901
# 4429       1511        1511         0         0        858662
# 4483       3912        1548         0         0        857752
# 3532     202428       38252      7138     49234      16732018
#
#       score_out_of_five
# 47             4.771229
# 141            4.935667
# 277            4.858617
# 184            4.833333
# 4549           5.000000
# ...                 ...
# 4319           4.762107
# 4379           4.902412
# 4429           4.973743
# 4483           4.959480
# 3532           4.855687
#
# [96 rows x 16 columns]

# %% [markdown]
# ## World Map - Hated Social Media

# %%
# Group by 'Country' and find the index of the row with the highest 'score_out_of_five' in each group
idx = social_apps.groupby('Country')['score_out_of_five'].idxmin()

# Use the index to get the corresponding rows
hated_social = social_apps.loc[idx]
hated_social
# Out:
#                                          similarweb_url  \
# 4     https://www.similarweb.com/top-apps/google/alg...
# 140   https://www.similarweb.com/top-apps/google/arg...
# 283   https://www.similarweb.com/top-apps/google/arm...
# 152   https://www.similarweb.com/top-apps/google/aus...
# 4504  https://www.similarweb.com/top-apps/google/aus...
# ...                                                 ...
# 4325  https://www.similarweb.com/top-apps/google/uni...
# 4367  https://www.similarweb.com/top-apps/google/uru...
# 4440  https://www.similarweb.com/top-apps/google/uzb...
# 4486  https://www.similarweb.com/top-apps/google/ven...
# 3539  https://www.similarweb.com/top-apps/google/vie...
#
#                                  App                     Publisher Category  \
# 4                          Instagram                     Instagram   Social
# 140                         Adoraboo  Happeny Technology Pte. Ltd.   Social
# 283   WorldTalk-Date with foreigners               Zero Technology   Social
# 152                           Reddit                   reddit Inc.   Social
# 4504                          Reddit                   reddit Inc.   Social
# ...                              ...                           ...      ...
# 4325  MobilePatrol Public Safety App                      Vinelink   Social
# 4367  OmeTV – Video Chat Alternative        Video Chat Alternative   Social
# 4440    TenChat: больше, чем соцсеть                   VBClab, LLC   Social
# 4486            Chikii-Play PC Games             Chikii Cloud Game   Social
# 3539   J&T Express - Giao Hàng Nhanh           J&T Express Vietnam   Social
#
#                          appId                           Country alpha2Code  \
# 4        com.instagram.android                           Algeria         DZ
# 140               com.adoraboo                         Argentina         AR
# 283     com.zerophil.worldtalk                           Armenia         AM
# 152       com.reddit.frontpage                         Australia         AU
# 4504      com.reddit.frontpage                           Austria         AT
# ...                        ...                               ...        ...
# 4325  com.appriss.mobilepatrol                     United States         US
# 4367                 omegle.tv                           Uruguay         UY
# 4440               co.vero.app                        Uzbekistan         UZ
# 4486        com.dianyun.chikii  Venezuela Bolivarian Republic Of         VE
# 3539   com.msd.VIPyueNanClient                           Vietnam         VN
#
#                                         google_play_url    reviews  five_star  \
# 4     https://play.google.com/store/apps/details?id=...  153000000   40835101
# 140   https://play.google.com/store/apps/details?id=...        159         12
# 283   https://play.google.com/store/apps/details?id=...      16000       5927
# 152   https://play.google.com/store/apps/details?id=...    3090000    1011082
# 4504  https://play.google.com/store/apps/details?id=...    3090000     906225
# ...                                                 ...        ...        ...
# 4325  https://play.google.com/store/apps/details?id=...      37200      12477
# 4367  https://play.google.com/store/apps/details?id=...     561000     243295
# 4440  https://play.google.com/store/apps/details?id=...      34700      13253
# 4486  https://play.google.com/store/apps/details?id=...     183000      67936
# 3539  https://play.google.com/store/apps/details?id=...      11200       1688
#
#       four_star  three_star  two_star  one_star  weighted_sum  \
# 4       4352180     2569074   1721891  98732195     331467424
# 140          51          25        12        51           414
# 283        1414        1703      1414      4911         48139
# 152      306408       88524     93107   1519355       8252183
# 4504     170667       93551    106193   1741445       7448277
# ...         ...         ...       ...       ...           ...
# 4325       3019        2799      2567     15183        103175
# 4367      31024       37555      9797    215536       1688366
# 4440       2650        5301      2650     10602        108670
# 4486      19121       12147     13947     62762        543261
# 3539        151         252       242      8816         19100
#
#       score_out_of_five
# 4              2.236465
# 140            2.741722
# 283            3.132214
# 152            2.733891
# 4504           2.467885
# ...                 ...
# 4325           2.862394
# 4367           3.142859
# 4440           3.153877
# 4486           3.088237
# 3539           1.713158
#
# [96 rows x 16 columns]

# %% [markdown]
# # Create an Excel file

# %%
# Create an Excel writer object

writer = pd.ExcelWriter('The Most Loved Email, Messaging and Social Media Apps by Country.xlsx')

# %%
loved_email.to_excel(writer, sheet_name='Loved Email', index=False)
hated_email.to_excel(writer, sheet_name='Hated Email', index=False)
loved_communication.to_excel(writer, sheet_name='Loved Communications', index=False)
hated_communication.to_excel(writer, sheet_name='Hated Communications', index=False)
loved_social.to_excel(writer, sheet_name='Loved Social Media', index=False)
hated_social.to_excel(writer, sheet_name='Hated Social Media', index=False)
communications_apps.to_excel(writer, sheet_name='Raw Communications Apps', index=False)
social_apps.to_excel(writer, sheet_name='Raw Social Media Apps', index=False)
email_apps.to_excel(writer, sheet_name='Raw Email Apps', index=False)

# %%
# Save the Excel file
writer.save()

# %%
email_apps['Category'] = 'Email'

# %%
communications_apps[communications_apps.Category!='Email']
# Out:
#                                          similarweb_url  \
# 0     https://www.similarweb.com/top-apps/google/alg...
# 1     https://www.similarweb.com/top-apps/google/alg...
# 2     https://www.similarweb.com/top-apps/google/alg...
# 3     https://www.similarweb.com/top-apps/google/alg...
# 4     https://www.similarweb.com/top-apps/google/alg...
# ...                                                 ...
# 4794  https://www.similarweb.com/top-apps/google/ser...
# 4795  https://www.similarweb.com/top-apps/google/ser...
# 4796  https://www.similarweb.com/top-apps/google/ser...
# 4797  https://www.similarweb.com/top-apps/google/ser...
# 4798  https://www.similarweb.com/top-apps/google/ser...
#
#                                  App                             Publisher  \
# 0                 WhatsApp Messenger                          WhatsApp LLC
# 1                          Messenger                  Meta Platforms, Inc.
# 2                           Telegram                       Telegram FZ-LLC
# 3                           Snapchat                              Snap Inc
# 4     Truecaller: Identify Caller ID                            Truecaller
# ...                              ...                                   ...
# 4794        Phone Dialer & Caller ID  Share File Technologies by 090 Bravo
# 4795   Smart Watch app - BT notifier                        Flying Phoenix
# 4796    Botim - Video and Voice Call       Algento Cloud Computing Limited
# 4797    Opera Mini: Fast Web Browser                                 Opera
# 4798        Opera GX: Gaming Browser                                 Opera
#
#            Category                                              appId  \
# 0     Communication                                       com.whatsapp
# 1     Communication                                  com.facebook.orca
# 2     Communication                             org.telegram.messenger
# 3     Communication                               com.snapchat.android
# 4     Communication                                     com.truecaller
# ...             ...                                                ...
# 4794  Communication  call.color.flash.phone.callerscreen.flashlight...
# 4795  Communication        com.smartwatch.bluetooth.sync.notifications
# 4796  Communication                                im.thebot.messenger
# 4797  Communication                              com.opera.mini.native
# 4798  Communication                                       com.opera.gx
#
#       Country alpha2Code                                    google_play_url  \
# 0     Algeria         DZ  https://play.google.com/store/apps/details?id=...
# 1     Algeria         DZ  https://play.google.com/store/apps/details?id=...
# 2     Algeria         DZ  https://play.google.com/store/apps/details?id=...
# 3     Algeria         DZ  https://play.google.com/store/apps/details?id=...
# 4     Algeria         DZ  https://play.google.com/store/apps/details?id=...
# ...       ...        ...                                                ...
# 4794   Serbia         RS  https://play.google.com/store/apps/details?id=...
# 4795   Serbia         RS  https://play.google.com/store/apps/details?id=...
# 4796   Serbia         RS  https://play.google.com/store/apps/details?id=...
# 4797   Serbia         RS  https://play.google.com/store/apps/details?id=...
# 4798   Serbia         RS  https://play.google.com/store/apps/details?id=...
#
#         reviews  five_star  four_star  three_star  two_star  one_star  \
# 0     190000000  124642625   15062961    10741084   7008012  29181989
# 1      89100000   46053579    4949839     3550516   2744035  27834686
# 2      13900000    9333940    1028448      697534    351536   2075800
# 3      35200000   15467638    1874281     1275746    792059  13867570
# 4      21200000   15974108    1847402     1139970    556583   1471526
# ...         ...        ...        ...         ...       ...       ...
# 4794       2540       1503          0           0       250       751
# 4795     210000     161181      23739        9995      3748      4997
# 4796    1140000     798697     156109       87130     10891     65347
# 4797    9130000    7209486     765358      274017    160630    406301
# 4798     198000     153543      20823        3763      5519      5519
#
#       weighted_sum  score_out_of_five
# 0        758886234           4.066115
# 1        294041555           3.453922
# 2         55654966           4.126485
# 3        104114240           3.128687
# 4         93264750           4.443381
# ...            ...                ...
# 4794          8766           3.500799
# 4795        943339           4.631931
# 4796       4966440           4.441563
# 4797      40658474           4.612005
# 4798        878853           4.645911
#
# [4413 rows x 16 columns]

# %%
raw_data = pd.concat([communications_apps[communications_apps.Category!='Email'], social_apps, email_apps])

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11614 entries, 0 to 2613
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   similarweb_url     9000 non-null   object
#  1   App                11614 non-null  object
#  2   Publisher          11614 non-null  object
#  3   Category           11614 non-null  object
#  4   appId              11614 non-null  object
#  5   Country            11614 non-null  object
#  6   alpha2Code         11614 non-null  object
#  7   google_play_url    11614 non-null  object
#  8   reviews            11614 non-null  int64
#  9   five_star          11614 non-null  int64
#  10  four_star          11614 non-null  int64
#  11  three_star         11614 non-null  int64
#  12  two_star           11614 non-null  int64
#  13  one_star           11614 non-null  int64
#  14  weighted_sum       11614 non-null  int64
#  15  score_out_of_five  11614 non-null  float64
# dtypes: float64(1), int64(7), object(8)
# memory usage: 1.5+ MB

# %%
raw_data.to_csv('raw_data.csv')
